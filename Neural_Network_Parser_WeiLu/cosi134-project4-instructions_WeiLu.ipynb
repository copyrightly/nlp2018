# %% [markdown]
# #  COSI134 Project 4: Train a neural network parser
#
# Due: December 18, 2018
#
# In the fourth and final project, you are asked to train a neural network parser using the Penn TreeBank data. You have the choice of using either the encoder-decoder framework or the span scoring approach that we have discussed in class. You're also free to consult any open source code that you can find on the internet. If you choose the encoder-decoder framework, the bulk of the work would involve preparing the input data.
#
# Like the POS tagging project, it's advisable to start small and make sure your code works on a smaller data sample. You also need to make sure the output of your parser needs to be well-formed, that is, has matching parentheses, among other things. The output of your parser needs to be evaluated with a standard software called "evalb". The original version of the software can be found here: https://nlp.cs.nyu.edu/evalb/. There are also java reimplementations of the software at the Stanford Core NLP. The software outputs many metrics, but the main metrics are labeled precision and labeled recall, which are based on counting the number of matching constituents between the gold parser tree and the system output.
#
# In your writeup:
# - give a brief description on your code structure.
# - give a description on your model, including input feature design, model architecture, hyperparameters you experimented with, etc.
# - report experiments and results with different training data sizes at 5000, 15000, and all sentences.
# - report your best experimental performances.
#
# ### Use nltk.corpus to access the data:

# %%
import nltk.corpus
reader_train = nltk.corpus.BracketParseCorpusReader(r'./train/', r'.*/wsj_.*\.mrg')
reader_dev = nltk.corpus.BracketParseCorpusReader(r'./dev/', r'.*/wsj_.*\.mrg')
reader_test = nltk.corpus.BracketParseCorpusReader(r'./testhttps://github.com/tensorflow/nmt/', r'.*/wsj_.*\.mrg')

# %%
reader_train.sents()    # gives you plain sentences
# Out:
# [['In', 'an', 'Oct.', '19', 'review', 'of', '``', 'The', 'Misanthrope', "''", 'at', 'Chicago', "'s", 'Goodman', 'Theatre', '-LRB-', '``', 'Revitalized', 'Classics', 'Take', 'the', 'Stage', 'in', 'Windy', 'City', ',', "''", 'Leisure', '&', 'Arts', '-RRB-', ',', 'the', 'role', 'of', 'Celimene', ',', 'played', '*', 'by', 'Kim', 'Cattrall', ',', 'was', 'mistakenly', 'attributed', '*-2', 'to', 'Christina', 'Haag', '.'], ['Ms.', 'Haag', 'plays', 'Elianti', '.'], ...]

# %%
reader_train.parsed_sents()    # gives you gold parsed trees
# Out:
# [Tree('S', [Tree('PP-LOC', [Tree('IN', ['In']), Tree('NP', [Tree('NP', [Tree('DT', ['an']), Tree('NNP', ['Oct.']), Tree('CD', ['19']), Tree('NN', ['review'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('``', ['``']), Tree('NP-TTL', [Tree('DT', ['The']), Tree('NN', ['Misanthrope'])]), Tree("''", ["''"]), Tree('PP-LOC', [Tree('IN', ['at']), Tree('NP', [Tree('NP', [Tree('NNP', ['Chicago']), Tree('POS', ["'s"])]), Tree('NNP', ['Goodman']), Tree('NNP', ['Theatre'])])])])]), Tree('PRN', [Tree('-LRB-', ['-LRB-']), Tree('``', ['``']), Tree('S-HLN', [Tree('NP-SBJ', [Tree('VBN', ['Revitalized']), Tree('NNS', ['Classics'])]), Tree('VP', [Tree('VBP', ['Take']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['Stage'])]), Tree('PP-LOC', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Windy']), Tree('NNP', ['City'])])])])]), Tree(',', [',']), Tree("''", ["''"]), Tree('NP-TMP', [Tree('NN', ['Leisure']), Tree('CC', ['&']), Tree('NNS', ['Arts'])]), Tree('-RRB-', ['-RRB-'])])])]), Tree(',', [',']), Tree('NP-SBJ-2', [Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['role'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNP', ['Celimene'])])])]), Tree(',', [',']), Tree('VP', [Tree('VBN', ['played']), Tree('NP', [Tree('-NONE-', ['*'])]), Tree('PP', [Tree('IN', ['by']), Tree('NP-LGS', [Tree('NNP', ['Kim']), Tree('NNP', ['Cattrall'])])])]), Tree(',', [','])]), Tree('VP', [Tree('VBD', ['was']), Tree('VP', [Tree('ADVP-MNR', [Tree('RB', ['mistakenly'])]), Tree('VBN', ['attributed']), Tree('NP', [Tree('-NONE-', ['*-2'])]), Tree('PP-CLR', [Tree('TO', ['to']), Tree('NP', [Tree('NNP', ['Christina']), Tree('NNP', ['Haag'])])])])]), Tree('.', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NNP', ['Ms.']), Tree('NNP', ['Haag'])]), Tree('VP', [Tree('VBZ', ['plays']), Tree('NP', [Tree('NNP', ['Elianti'])])]), Tree('.', ['.'])]), ...]

# %%
reader_train.parsed_sents()[0].__str__()    # gives you the tree represented in a string. Make sure to remove the newline signs before training.
# Out:
# "(S\n  (PP-LOC\n    (IN In)\n    (NP\n      (NP (DT an) (NNP Oct.) (CD 19) (NN review))\n      (PP\n        (IN of)\n        (NP\n          (`` ``)\n          (NP-TTL (DT The) (NN Misanthrope))\n          ('' '')\n          (PP-LOC\n            (IN at)\n            (NP\n              (NP (NNP Chicago) (POS 's))\n              (NNP Goodman)\n              (NNP Theatre)))))\n      (PRN\n        (-LRB- -LRB-)\n        (`` ``)\n        (S-HLN\n          (NP-SBJ (VBN Revitalized) (NNS Classics))\n          (VP\n            (VBP Take)\n            (NP (DT the) (NN Stage))\n            (PP-LOC (IN in) (NP (NNP Windy) (NNP City)))))\n        (, ,)\n        ('' '')\n        (NP-TMP (NN Leisure) (CC &) (NNS Arts))\n        (-RRB- -RRB-))))\n  (, ,)\n  (NP-SBJ-2\n    (NP (NP (DT the) (NN role)) (PP (IN of) (NP (NNP Celimene))))\n    (, ,)\n    (VP\n      (VBN played)\n      (NP (-NONE- *))\n      (PP (IN by) (NP-LGS (NNP Kim) (NNP Cattrall))))\n    (, ,))\n  (VP\n    (VBD was)\n    (VP\n      (ADVP-MNR (RB mistakenly))\n      (VBN attributed)\n      (NP (-NONE- *-2))\n      (PP-CLR (TO to) (NP (NNP Christina) (NNP Haag)))))\n  (. .))"

# %%
reader_test.parsed_sents()[0].__str__().replace('\n', '')
# Out:
# "(S  (INTJ (RB No))  (, ,)  (NP-SBJ (PRP it))  (VP (VBD was) (RB n't) (NP-PRD (NNP Black) (NNP Monday)))  (. .))"

# %%
def count_right_parentheses(tag):
    return len(tag.split(')'))-1

# %%
count_right_parentheses('))))NP-TMP')
# Out:
# 4

# %%
# drop terminal words and parentheses
def preprosessing(sent):
    tag_stack = []
    result = []
    for tag in sent:
        if '(' in list(tag):
            tag_stack.append(tag)
            result.append(tag)
        else:
            count = count_right_parentheses(tag)
            result[-1] = tag_stack.pop().split('(')[-1]
            if count > 1:
                for i in range(count-1):
                    result.append(')'+tag_stack.pop().split('(')[-1])
    return ' '.join(result)

# %%
preprosessing(reader_test.parsed_sents()[0].__str__().replace('\n', '').split())
# Out:
# '(S (INTJ RB )INTJ , (NP-SBJ PRP )NP-SBJ (VP VBD RB (NP-PRD NNP NNP )NP-PRD )VP . )S'

# %%
# match parentheses of the output
def parentheses_match(sent):
    tag_stack = []
    result = []
    for tag in sent:
        if '(' in list(tag):
            tag_stack.append(tag)
            result.append(tag)
        elif ')' in list(tag):
            if len(tag_stack) > 0:
                tag_stack.pop()
                result.append(tag)
        else:
            result.append(tag)
    if len(tag_stack) > 0:
        for i in range(len(tag_stack)):
            result.append(')')
    return ' '.join(result)

# %%
s='(S CC (SBAR-ADV IN (S (NP-SBJ DT NNP NNP NNP NNP )NP-SBJ (VP VBD RB (VP VB (PRT RP )PRT (NP-TMP NNP )NP-TMP (SBAR-TMP IN (S (NP-SBJ DT NNP NNP NNP NNP )NP-SBJ (VP VBD (NP-EXT CD NNS )NP-EXT )VP )S )SBAR-TMP )VP )VP )S )SBAR-ADV : (NP-SBJ (NP JJS )NP (PP IN (NP PRP )NP )PP (PP-TMP IN (NP DT JJ NN )NP )PP-TMP )NP-SBJ (VP VBD'
parentheses_match(s.split())
# Out:
# '(S CC (SBAR-ADV IN (S (NP-SBJ DT NNP NNP NNP NNP )NP-SBJ (VP VBD RB (VP VB (PRT RP )PRT (NP-TMP NNP )NP-TMP (SBAR-TMP IN (S (NP-SBJ DT NNP NNP NNP NNP )NP-SBJ (VP VBD (NP-EXT CD NNS )NP-EXT )VP )S )SBAR-TMP )VP )VP )S )SBAR-ADV : (NP-SBJ (NP JJS )NP (PP IN (NP PRP )NP )PP (PP-TMP IN (NP DT JJ NN )NP )PP-TMP )NP-SBJ (VP VBD ) )'

# %%
# when the number of words is equal to the that of tags
def put_back_equal_words(sent, terminal_words):
    result = []
    for tag in sent:
        if '(' in list(tag):
            result.append(tag)
        elif ')' in list(tag):
            result[-1] += ')'
        else:
            result.append('(' + tag)
            result.append(terminal_words.pop(0) + ')')
    return ' '.join(result)

# %%
# count the number of open and close parentheses, and the number of POS tags
def count_parentheses(sent):
    left = 0
    right = 0
    pos_tag = 0
    for tag in sent:
        if '(' in list(tag):
            left += 1
        elif ')' in list(tag):
            right += 1
        else:
            pos_tag += 1
    return left, right, pos_tag

# %%
# when the number of words is less the that of tags
def put_back_less_words(sent, terminal_words):
    tag_stack = []
    result = []
    for tag in sent:
        if '(' in list(tag):
            tag_stack.append(tag)
            result.append(tag)
        elif ')' in list(tag):
            tag_stack.pop()
            result[-1] += ')'
        else:
            result.append('(' + tag)
            result.append(terminal_words.pop(0) + ')')
            if len(terminal_words) == 0:
                result[-1] += (')' * len(tag_stack))
                break
    return ' '.join(result)

# %%
# add the terminal words back into the output parsing tree
def post_process(sent, terminal_words):
    new_sent = parentheses_match(sent).split()
    left, right, pos_tag = count_parentheses(new_sent)
#     print(left, right, pos_tag)
#     print("pos_tag, len of sent:", pos_tag, len(terminal_words))
    if pos_tag > len(terminal_words):
        result = put_back_less_words(new_sent, terminal_words)
    elif pos_tag < len(terminal_words):
        new_sent.append('(NNP')
        for i in range(len(terminal_words)-pos_tag-1):
            new_sent.append('NNP')
        new_sent.append('.')
        new_sent.append(')')
        result = put_back_equal_words(new_sent, terminal_words)
    else:
        result = put_back_equal_words(new_sent, terminal_words)
    return result

# %%
post_process(ssss.split(), reader_test.sents()[1])
# Out:
# 20 20 45
# pos_tag, len of sent: 45 41
# "(S (CC But) (SBAR-ADV (IN while) (S (NP-SBJ (DT the) (NNP New) (NNP York) (NNP Stock) (NN Exchange) (NN did) (NN n't) (NN fall) (N apart) (N Friday) (N as) (N the) (N Dow) (n Jones) (n Industrial) (n Average) (n plunged) (n 190.58) (n points) (NNP --)) (VP (VBD most) (RB of) (VP (VB it) (PRT (RP in)) (NP-TMP (NNP the)) (SBAR-TMP (IN final) (S (NP-SBJ (DT hour) (NNP --) (NNP it) (NNP barely) (NNP managed)) (VP (VBD *-2) (NP-EXT (CD to) (NNS stay))))))))) (: this) (NP-SBJ (NP (JJS side)) (PP (IN of) (NP (PRP chaos))) (PP-TMP (IN .))))"

# %%
# write the post-processed output into a file for EVALB
i = 0
f_read = open('./output/output_attention_bilstm_test', 'r')
with open('evalb_output_attention_bilstm_test.txt' ,'a') as f_write:
    for sent in f_read:
        f_write.write(post_process(sent.split(), reader_test.sents()[i]))
        f_write.write('\n')
        i += 1
f_read.close()
print(i, len(reader_test.sents()))
# Out:
# 5 5 8
# pos_tag, len of sent: 8 8
# 20 20 30
# pos_tag, len of sent: 30 41
# 22 22 31
# pos_tag, len of sent: 31 36
# 22 22 28
# pos_tag, len of sent: 28 37
# 24 24 25
# pos_tag, len of sent: 25 31
# 12 12 17
# pos_tag, len of sent: 17 17
# 20 20 34
# pos_tag, len of sent: 34 31
# 5 5 6
# pos_tag, len of sent: 6 6
# 4 4 7
# pos_tag, len of sent: 7 7
# 27 27 31
# pos_tag, len of sent: 31 38
# 30 30 29
# pos_tag, len of sent: 29 30
# 13 13 17
# pos_tag, len of sent: 17 17
# 18 18 18
# pos_tag, len of sent: 18 18
# 11 11 20
# pos_tag, len of sent: 20 28
# 21 21 30
# pos_tag, len of sent: 30 43
# 10 10 15
# pos_tag, len of sent: 15 15
# 11 11 14
# pos_tag, len of sent: 14 14
# 5 5 8
# pos_tag, len of sent: 8 8
# 17 17 24
# pos_tag, len of sent: 24 24
# 21 21 30
# pos_tag, len of sent: 30 33
# 6 6 9
# pos_tag, len of sent: 9 9
# 28 28 34
# pos_tag, len of sent: 34 39
# 16 16 24
# pos_tag, len of sent: 24 28
# 15 15 24
# pos_tag, len of sent: 24 24
# 21 21 24
# pos_tag, len of sent: 24 29
# 8 8 8
# pos_tag, len of sent: 8 15
# 22 22 27
# pos_tag, len of sent: 27 28
# 19 19 23
# pos_tag, len of sent: 23 22
# 8 8 12
# pos_tag, len of sent: 12 12
# 3 3 4
# pos_tag, len of sent: 4 4
# 23 23 29
# pos_tag, len of sent: 29 24
# 28 28 26
# pos_tag, len of sent: 26 52
# 4 4 5
# pos_tag, len of sent: 5 5
# 22 22 24
# pos_tag, len of sent: 24 26
# 27 27 27
# pos_tag, len of sent: 27 31
# 26 26 26
# pos_tag, len of sent: 26 27
# 11 11 17
# pos_tag, len of sent: 17 17
# 13 13 18
# pos_tag, len of sent: 18 18
# 18 18 28
# pos_tag, len of sent: 28 38
# 17 17 23
# pos_tag, len of sent: 23 23
# 23 23 25
# pos_tag, len of sent: 25 35
# 9 9 15
# pos_tag, len of sent: 15 15
# 31 31 30
# pos_tag, len of sent: 30 39
# 8 8 13
# pos_tag, len of sent: 13 13
# 9 9 13
# pos_tag, len of sent: 13 13
# 26 26 33
# pos_tag, len of sent: 33 38
# 19 19 29
# pos_tag, len of sent: 29 31
# 21 21 20
# pos_tag, len of sent: 20 35
# 22 22 22
# pos_tag, len of sent: 22 22
# 6 6 6
# pos_tag, len of sent: 6 6
# 9 9 15
# pos_tag, len of sent: 15 15
# 14 14 20
# pos_tag, len of sent: 20 22
# 21 21 27
# pos_tag, len of sent: 27 28
# 9 9 16
# pos_tag, len of sent: 16 17
# 26 26 28
# pos_tag, len of sent: 28 28
# 24 24 36
# pos_tag, len of sent: 36 48
# 26 26 29
# pos_tag, len of sent: 29 29
# 21 21 28
# pos_tag, len of sent: 28 30
# 6 6 8
# pos_tag, len of sent: 8 8
# 21 21 22
# pos_tag, len of sent: 22 24
# 15 15 24
# pos_tag, len of sent: 24 25
# 16 16 19
# pos_tag, len of sent: 19 19
# 17 17 20
# pos_tag, len of sent: 20 20
# 23 23 24
# pos_tag, len of sent: 24 28
# 26 26 30
# pos_tag, len of sent: 30 36
# 17 17 20
# pos_tag, len of sent: 20 19
# 24 24 23
# pos_tag, len of sent: 23 32
# 20 20 31
# pos_tag, len of sent: 31 31
# 19 19 28
# pos_tag, len of sent: 28 34
# 24 24 30
# pos_tag, len of sent: 30 39
# 13 13 14
# pos_tag, len of sent: 14 14
# 12 12 15
# pos_tag, len of sent: 15 15
# 12 12 23
# pos_tag, len of sent: 23 23
# 25 25 30
# pos_tag, len of sent: 30 31
# 4 4 6
# pos_tag, len of sent: 6 6
# 18 18 20
# pos_tag, len of sent: 20 28
# 11 11 16
# pos_tag, len of sent: 16 16
# 23 23 22
# pos_tag, len of sent: 22 38
# 12 12 15
# pos_tag, len of sent: 15 15
# 21 21 26
# pos_tag, len of sent: 26 26
# 9 9 17
# pos_tag, len of sent: 17 17
# 11 11 16
# pos_tag, len of sent: 16 16
# 23 23 23
# pos_tag, len of sent: 23 29
# 17 17 17
# pos_tag, len of sent: 17 22
# 30 30 34
# pos_tag, len of sent: 34 43
# 23 23 23
# pos_tag, len of sent: 23 26
# 21 21 24
# pos_tag, len of sent: 24 27
# 15 15 23
# pos_tag, len of sent: 23 30
# 13 13 11
# pos_tag, len of sent: 11 11
# 31 31 31
# pos_tag, len of sent: 31 2
# 22 22 21
# pos_tag, len of sent: 21 22
# 26 26 26
# pos_tag, len of sent: 26 27
# 30 30 33
# pos_tag, len of sent: 33 38
# 16 16 21
# pos_tag, len of sent: 21 21
# 20 20 28
# pos_tag, len of sent: 28 34
# 20 20 30
# pos_tag, len of sent: 30 30
# 17 17 23
# pos_tag, len of sent: 23 33
# 26 26 34
# pos_tag, len of sent: 34 35
# 35 35 47
# pos_tag, len of sent: 47 37
# 8 8 10
# pos_tag, len of sent: 10 10
# 7 7 9
# pos_tag, len of sent: 9 9
# 19 19 23
# pos_tag, len of sent: 23 24
# 16 16 22
# pos_tag, len of sent: 22 22
# 29 29 33
# pos_tag, len of sent: 33 39
# 23 23 28
# pos_tag, len of sent: 28 29
# 16 16 23
# pos_tag, len of sent: 23 22
# 20 20 29
# pos_tag, len of sent: 29 37
# 19 19 26
# pos_tag, len of sent: 26 26
# 27 27 30
# pos_tag, len of sent: 30 57
# 20 20 25
# pos_tag, len of sent: 25 25
# 18 18 21
# pos_tag, len of sent: 21 35
# 7 7 11
# pos_tag, len of sent: 11 11
# 28 28 32
# pos_tag, len of sent: 32 51
# 39 39 37
# pos_tag, len of sent: 37 28
# 18 18 23
# pos_tag, len of sent: 23 29
# 21 21 31
# pos_tag, len of sent: 31 58
# 22 22 26
# pos_tag, len of sent: 26 27
# 23 23 31
# pos_tag, len of sent: 31 32
# 21 21 24
# pos_tag, len of sent: 24 28
# 12 12 15
# pos_tag, len of sent: 15 15
# 21 21 24
# pos_tag, len of sent: 24 24
# 31 31 30
# pos_tag, len of sent: 30 25
# 13 13 19
# pos_tag, len of sent: 19 19
# 26 26 37
# pos_tag, len of sent: 37 38
# 10 10 15
# pos_tag, len of sent: 15 15
# 10 10 17
# pos_tag, len of sent: 17 17
# 21 21 25
# pos_tag, len of sent: 25 35
# 12 12 16
# pos_tag, len of sent: 16 16
# 10 10 12
# pos_tag, len of sent: 12 12
# 13 13 21
# pos_tag, len of sent: 21 21
# 24 24 29
# pos_tag, len of sent: 29 32
# 11 11 18
# pos_tag, len of sent: 18 18
# 15 15 20
# pos_tag, len of sent: 20 20
# 24 24 32
# pos_tag, len of sent: 32 35
# 13 13 19
# pos_tag, len of sent: 19 19
# 19 19 29
# pos_tag, len of sent: 29 29
# 26 26 32
# pos_tag, len of sent: 32 39
# 6 6 9
# pos_tag, len of sent: 9 9
# 4 4 6
# pos_tag, len of sent: 6 6
# 5 5 6
# pos_tag, len of sent: 6 6
# 9 9 14
# pos_tag, len of sent: 14 14
# 22 22 25
# pos_tag, len of sent: 25 26
# 12 12 18
# pos_tag, len of sent: 18 22
# 8 8 9
# pos_tag, len of sent: 9 9
# 16 16 17
# pos_tag, len of sent: 17 17
# 13 13 17
# pos_tag, len of sent: 17 19
# 16 16 28
# pos_tag, len of sent: 28 34
# 16 16 27
# pos_tag, len of sent: 27 34
# 21 21 23
# pos_tag, len of sent: 23 26
# 24 24 23
# pos_tag, len of sent: 23 32
# 7 7 11
# pos_tag, len of sent: 11 11
# 24 24 28
# pos_tag, len of sent: 28 28
# 17 17 20
# pos_tag, len of sent: 20 20
# 15 15 17
# pos_tag, len of sent: 17 17
# 15 15 20
# pos_tag, len of sent: 20 21
# 17 17 20
# pos_tag, len of sent: 20 20
# 15 15 21
# pos_tag, len of sent: 21 22
# 18 18 23
# pos_tag, len of sent: 23 31
# 18 18 18
# pos_tag, len of sent: 18 15
# 19 19 28
# pos_tag, len of sent: 28 28
# 27 27 30
# pos_tag, len of sent: 30 32
# 15 15 22
# pos_tag, len of sent: 22 22
# 18 18 20
# pos_tag, len of sent: 20 22
# 24 24 26
# pos_tag, len of sent: 26 32
# 11 11 17
# pos_tag, len of sent: 17 17
# 7 7 11
# pos_tag, len of sent: 11 11
# 8 8 9
# pos_tag, len of sent: 9 9
# 6 6 10
# pos_tag, len of sent: 10 10
# 19 19 21
# pos_tag, len of sent: 21 22
# 9 9 13
# pos_tag, len of sent: 13 13
# 7 7 9
# pos_tag, len of sent: 9 9
# 12 12 21
# pos_tag, len of sent: 21 21
# 15 15 18
# pos_tag, len of sent: 18 18
# 12 12 16
# pos_tag, len of sent: 16 16
# 19 19 30
# pos_tag, len of sent: 30 30
# 21 21 23
# pos_tag, len of sent: 23 23
# 15 15 20
# pos_tag, len of sent: 20 20
# 23 23 33
# pos_tag, len of sent: 33 34
# 7 7 10
# pos_tag, len of sent: 10 10
# 10 10 13
# pos_tag, len of sent: 13 13
# 25 25 25
# pos_tag, len of sent: 25 26
# 13 13 20
# pos_tag, len of sent: 20 20
# 21 21 30
# pos_tag, len of sent: 30 40
# 26 26 31
# pos_tag, len of sent: 31 33
# 8 8 13
# pos_tag, len of sent: 13 13
# 18 18 21
# pos_tag, len of sent: 21 21
# 23 23 22
# pos_tag, len of sent: 22 31
# 14 14 17
# pos_tag, len of sent: 17 18
# 16 16 18
# pos_tag, len of sent: 18 23
# 13 13 17
# pos_tag, len of sent: 17 28
# 21 21 31
# pos_tag, len of sent: 31 47
# 11 11 16
# pos_tag, len of sent: 16 16
# 16 16 16
# pos_tag, len of sent: 16 34
# 14 14 18
# pos_tag, len of sent: 18 18
# 28 28 35
# pos_tag, len of sent: 35 44
# 23 23 25
# pos_tag, len of sent: 25 44
# 20 20 25
# pos_tag, len of sent: 25 69
# 23 23 18
# pos_tag, len of sent: 18 61
# 11 11 13
# pos_tag, len of sent: 13 13
# 20 20 23
# pos_tag, len of sent: 23 24
# 10 10 12
# pos_tag, len of sent: 12 12
# 27 27 38
# pos_tag, len of sent: 38 40
# 20 20 26
# pos_tag, len of sent: 26 27
# 16 16 16
# pos_tag, len of sent: 16 16
# 24 24 30
# pos_tag, len of sent: 30 39
# 11 11 15
# pos_tag, len of sent: 15 15
# 22 22 29
# pos_tag, len of sent: 29 30
# 17 17 22
# pos_tag, len of sent: 22 37
# 22 22 25
# pos_tag, len of sent: 25 26
# 21 21 24
# pos_tag, len of sent: 24 25
# 22 22 27
# pos_tag, len of sent: 27 28
# 21 21 23
# pos_tag, len of sent: 23 24
# 22 22 27
# pos_tag, len of sent: 27 28
# 18 18 21
# pos_tag, len of sent: 21 41
# 23 23 29
# pos_tag, len of sent: 29 43
# 25 25 31
# pos_tag, len of sent: 31 32
# 19 19 18
# pos_tag, len of sent: 18 19
# 20 20 15
# pos_tag, len of sent: 15 42
# 8 8 14
# pos_tag, len of sent: 14 14
# 26 26 32
# pos_tag, len of sent: 32 33
# 23 23 31
# pos_tag, len of sent: 31 47
# 12 12 16
# pos_tag, len of sent: 16 25
# 29 29 27
# pos_tag, len of sent: 27 42
# 19 19 19
# pos_tag, len of sent: 19 19
# 8 8 12
# pos_tag, len of sent: 12 12
# 21 21 36
# pos_tag, len of sent: 36 41
# 22 22 31
# pos_tag, len of sent: 31 33
# 21 21 24
# pos_tag, len of sent: 24 26
# 19 19 24
# pos_tag, len of sent: 24 25
# 11 11 14
# pos_tag, len of sent: 14 14
# 16 16 19
# pos_tag, len of sent: 19 19
# 30 30 30
# pos_tag, len of sent: 30 51
# 4 4 5
# pos_tag, len of sent: 5 5
# 18 18 16
# pos_tag, len of sent: 16 33
# 13 13 22
# pos_tag, len of sent: 22 22
# 7 7 11
# pos_tag, len of sent: 11 11
# 7 7 8
# pos_tag, len of sent: 8 8
# 20 20 23
# pos_tag, len of sent: 23 32
# 5 5 7
# pos_tag, len of sent: 7 7
# 20 20 27
# pos_tag, len of sent: 27 39
# 22 22 32
# pos_tag, len of sent: 32 62
# 4 4 6
# pos_tag, len of sent: 6 6
# 10 10 14
# pos_tag, len of sent: 14 15
# 19 19 26
# pos_tag, len of sent: 26 26
# 14 14 17
# pos_tag, len of sent: 17 22
# 15 15 19
# pos_tag, len of sent: 19 19
# 24 24 26
# pos_tag, len of sent: 26 50
# 25 25 30
# pos_tag, len of sent: 30 35
# 25 25 32
# pos_tag, len of sent: 32 33
# 21 21 23
# pos_tag, len of sent: 23 32
# 24 24 32
# pos_tag, len of sent: 32 32
# 30 30 29
# pos_tag, len of sent: 29 37
# 19 19 22
# pos_tag, len of sent: 22 34
# 17 17 21
# pos_tag, len of sent: 21 21
# 19 19 25
# pos_tag, len of sent: 25 43
# 27 27 24
# pos_tag, len of sent: 24 39
# 37 37 51
# pos_tag, len of sent: 51 30
# 22 22 39
# pos_tag, len of sent: 39 39
# 21 21 21
# pos_tag, len of sent: 21 21
# 9 9 16
# pos_tag, len of sent: 16 16
# 8 8 14
# pos_tag, len of sent: 14 14
# 9 9 13
# pos_tag, len of sent: 13 13
# 19 19 26
# pos_tag, len of sent: 26 28
# 10 10 15
# pos_tag, len of sent: 15 15
# 14 14 24
# pos_tag, len of sent: 24 24
# 24 24 28
# pos_tag, len of sent: 28 29
# 24 24 37
# pos_tag, len of sent: 37 56
# 10 10 17
# pos_tag, len of sent: 17 17
# 25 25 23
# pos_tag, len of sent: 23 41
# 36 36 37
# pos_tag, len of sent: 37 54
# 24 24 24
# pos_tag, len of sent: 24 25
# 20 20 26
# pos_tag, len of sent: 26 41
# 6 6 10
# pos_tag, len of sent: 10 10
# 19 19 22
# pos_tag, len of sent: 22 41
# 25 25 29
# pos_tag, len of sent: 29 30
# 39 39 28
# pos_tag, len of sent: 28 37
# 18 18 20
# pos_tag, len of sent: 20 20
# 26 26 32
# pos_tag, len of sent: 32 33
# 9 9 12
# pos_tag, len of sent: 12 17
# 24 24 24
# pos_tag, len of sent: 24 26
# 8 8 12
# pos_tag, len of sent: 12 12
# 28 28 35
# pos_tag, len of sent: 35 44
# 19 19 34
# pos_tag, len of sent: 34 37
# 25 25 25
# pos_tag, len of sent: 25 26
# 21 21 23
# pos_tag, len of sent: 23 23
# 13 13 15
# pos_tag, len of sent: 15 15
# 21 21 22
# pos_tag, len of sent: 22 22
# 16 16 21
# pos_tag, len of sent: 21 21
# 9 9 12
# pos_tag, len of sent: 12 12
# 23 23 26
# pos_tag, len of sent: 26 26
# 23 23 29
# pos_tag, len of sent: 29 39
# 23 23 24
# pos_tag, len of sent: 24 48
# 34 34 32
# pos_tag, len of sent: 32 33
# 10 10 17
# pos_tag, len of sent: 17 17
# 19 19 32
# pos_tag, len of sent: 32 32
# 20 20 23
# pos_tag, len of sent: 23 33
# 19 19 25
# pos_tag, len of sent: 25 22
# 19 19 25
# pos_tag, len of sent: 25 28
# 13 13 21
# pos_tag, len of sent: 21 21
# 16 16 20
# pos_tag, len of sent: 20 19
# 16 16 22
# pos_tag, len of sent: 22 22
# 17 17 17
# pos_tag, len of sent: 17 17
# 22 22 23
# pos_tag, len of sent: 23 35
# 24 24 23
# pos_tag, len of sent: 23 33
# 9 9 12
# pos_tag, len of sent: 12 12
# 10 10 9
# pos_tag, len of sent: 9 9
# 19 19 21
# pos_tag, len of sent: 21 21
# 18 18 21
# pos_tag, len of sent: 21 22
# 14 14 20
# pos_tag, len of sent: 20 20
# 26 26 23
# pos_tag, len of sent: 23 24
# 4 4 4
# pos_tag, len of sent: 4 4
# 4 4 5
# pos_tag, len of sent: 5 5
# 24 24 22
# pos_tag, len of sent: 22 23
# 11 11 14
# pos_tag, len of sent: 14 14
# 12 12 18
# pos_tag, len of sent: 18 22
# 24 24 33
# pos_tag, len of sent: 33 46
# 25 25 33
# pos_tag, len of sent: 33 34
# 13 13 15
# pos_tag, len of sent: 15 15
# 20 20 27
# pos_tag, len of sent: 27 52
# 22 22 22
# pos_tag, len of sent: 22 23
# 18 18 18
# pos_tag, len of sent: 18 18
# 16 16 27
# pos_tag, len of sent: 27 27
# 18 18 18
# pos_tag, len of sent: 18 18
# 24 24 26
# pos_tag, len of sent: 26 29
# 4 4 6
# pos_tag, len of sent: 6 6
# 5 5 9
# pos_tag, len of sent: 9 10
# 12 12 18
# pos_tag, len of sent: 18 18
# 12 12 20
# pos_tag, len of sent: 20 20
# 11 11 17
# pos_tag, len of sent: 17 17
# 23 23 21
# pos_tag, len of sent: 21 28
# 26 26 25
# pos_tag, len of sent: 25 21
# 28 28 31
# pos_tag, len of sent: 31 46
# 9 9 11
# pos_tag, len of sent: 11 11
# 22 22 24
# pos_tag, len of sent: 24 26
# 13 13 16
# pos_tag, len of sent: 16 24
# 6 6 7
# pos_tag, len of sent: 7 7
# 20 20 25
# pos_tag, len of sent: 25 26
# 12 12 18
# pos_tag, len of sent: 18 18
# 13 13 17
# pos_tag, len of sent: 17 17
# 24 24 31
# pos_tag, len of sent: 31 32
# 7 7 10
# pos_tag, len of sent: 10 10
# 8 8 13
# pos_tag, len of sent: 13 13
# 15 15 15
# pos_tag, len of sent: 15 15
# 10 10 13
# pos_tag, len of sent: 13 13
# 22 22 23
# pos_tag, len of sent: 23 24
# 25 25 28
# pos_tag, len of sent: 28 39
# 27 27 33
# pos_tag, len of sent: 33 34
# 25 25 40
# pos_tag, len of sent: 40 58
# 14 14 23
# pos_tag, len of sent: 23 23
# 32 32 37
# pos_tag, len of sent: 37 48
# 22 22 33
# pos_tag, len of sent: 33 34
# 25 25 34
# pos_tag, len of sent: 34 30
# 20 20 24
# pos_tag, len of sent: 24 34
# 26 26 27
# pos_tag, len of sent: 27 32
# 22 22 26
# pos_tag, len of sent: 26 27
# 25 25 30
# pos_tag, len of sent: 30 37
# 19 19 22
# pos_tag, len of sent: 22 23
# 12 12 18
# pos_tag, len of sent: 18 19
# 27 27 29
# pos_tag, len of sent: 29 34
# 17 17 30
# pos_tag, len of sent: 30 30
# 24 24 26
# pos_tag, len of sent: 26 39
# 21 21 26
# pos_tag, len of sent: 26 27
# 21 21 25
# pos_tag, len of sent: 25 25
# 29 29 34
# pos_tag, len of sent: 34 40
# 22 22 27
# pos_tag, len of sent: 27 27
# 21 21 21
# pos_tag, len of sent: 21 21
# 17 17 27
# pos_tag, len of sent: 27 27
# 31 31 31
# pos_tag, len of sent: 31 41
# 15 15 25
# pos_tag, len of sent: 25 23
# 30 30 28
# pos_tag, len of sent: 28 41
# 21 21 25
# pos_tag, len of sent: 25 26
# 14 14 23
# pos_tag, len of sent: 23 23
# 22 22 22
# pos_tag, len of sent: 22 24
# 12 12 23
# pos_tag, len of sent: 23 23
# 26 26 32
# pos_tag, len of sent: 32 34
# 24 24 23
# pos_tag, len of sent: 23 24
# 18 18 28
# pos_tag, len of sent: 28 28
# 11 11 13
# pos_tag, len of sent: 13 13
# 16 16 20
# pos_tag, len of sent: 20 20
# 17 17 23
# pos_tag, len of sent: 23 28
# 13 13 18
# pos_tag, len of sent: 18 18
# 21 21 26
# pos_tag, len of sent: 26 26
# 21 21 25
# pos_tag, len of sent: 25 26
# 26 26 28
# pos_tag, len of sent: 28 33
# 26 26 33
# pos_tag, len of sent: 33 49
# 19 19 30
# pos_tag, len of sent: 30 31
# 17 17 26
# pos_tag, len of sent: 26 30
# 5 5 7
# pos_tag, len of sent: 7 7
# 22 22 27
# pos_tag, len of sent: 27 37
# 25 25 30
# pos_tag, len of sent: 30 28
# 25 25 23
# pos_tag, len of sent: 23 29
# 16 16 21
# pos_tag, len of sent: 21 21
# 28 28 35
# pos_tag, len of sent: 35 36
# 12 12 12
# pos_tag, len of sent: 12 20
# 18 18 23
# pos_tag, len of sent: 23 23
# 23 23 21
# pos_tag, len of sent: 21 30
# 24 24 30
# pos_tag, len of sent: 30 26
# 18 18 20
# pos_tag, len of sent: 20 35
# 16 16 25
# pos_tag, len of sent: 25 25
# 22 22 28
# pos_tag, len of sent: 28 29
# 22 22 22
# pos_tag, len of sent: 22 39
# 21 21 26
# pos_tag, len of sent: 26 27
# 20 20 27
# pos_tag, len of sent: 27 33
# 12 12 14
# pos_tag, len of sent: 14 14
# 23 23 25
# pos_tag, len of sent: 25 26
# 22 22 20
# pos_tag, len of sent: 20 21
# 19 19 25
# pos_tag, len of sent: 25 25
# 15 15 19
# pos_tag, len of sent: 19 36
# 15 15 19
# pos_tag, len of sent: 19 19
# 20 20 21
# pos_tag, len of sent: 21 36
# 11 11 13
# pos_tag, len of sent: 13 13
# 18 18 17
# pos_tag, len of sent: 17 17
# 6 6 8
# pos_tag, len of sent: 8 8
# 15 15 17
# pos_tag, len of sent: 17 17
# 22 22 27
# pos_tag, len of sent: 27 27
# 18 18 19
# pos_tag, len of sent: 19 19
# 27 27 34
# pos_tag, len of sent: 34 45
# 21 21 26
# pos_tag, len of sent: 26 38
# 29 29 26
# pos_tag, len of sent: 26 51
# 22 22 25
# pos_tag, len of sent: 25 26
# 22 22 27
# pos_tag, len of sent: 27 27
# 21 21 17
# pos_tag, len of sent: 17 31
# 27 27 23
# pos_tag, len of sent: 23 25
# 18 18 21
# pos_tag, len of sent: 21 21
# 20 20 23
# pos_tag, len of sent: 23 23
# 11 11 16
# pos_tag, len of sent: 16 16
# 18 18 19
# pos_tag, len of sent: 19 25
# 14 14 19
# pos_tag, len of sent: 19 20
# 19 19 17
# pos_tag, len of sent: 17 18
# 28 28 32
# pos_tag, len of sent: 32 33
# 34 34 42
# pos_tag, len of sent: 42 43
# 8 8 9
# pos_tag, len of sent: 9 9
# 15 15 18
# pos_tag, len of sent: 18 18
# 19 19 21
# pos_tag, len of sent: 21 20
# 14 14 25
# pos_tag, len of sent: 25 25
# 23 23 22
# pos_tag, len of sent: 22 22
# 20 20 27
# pos_tag, len of sent: 27 26
# 27 27 36
# pos_tag, len of sent: 36 30
# 20 20 22
# pos_tag, len of sent: 22 23
# 22 22 23
# pos_tag, len of sent: 23 24
# 27 27 32
# pos_tag, len of sent: 32 50
# 22 22 19
# pos_tag, len of sent: 19 36
# 13 13 14
# pos_tag, len of sent: 14 14
# 16 16 19
# pos_tag, len of sent: 19 19
# 10 10 9
# pos_tag, len of sent: 9 9
# 6 6 10
# pos_tag, len of sent: 10 10
# 24 24 24
# pos_tag, len of sent: 24 20
# 18 18 18
# pos_tag, len of sent: 18 25
# 30 30 29
# pos_tag, len of sent: 29 52
# 24 24 24
# pos_tag, len of sent: 24 31
# 16 16 23
# pos_tag, len of sent: 23 23
# 25 25 23
# pos_tag, len of sent: 23 24
# 5 5 7
# pos_tag, len of sent: 7 7
# 5 5 9
# pos_tag, len of sent: 9 9
# 12 12 12
# pos_tag, len of sent: 12 15
# 22 22 28
# pos_tag, len of sent: 28 51
# 12 12 13
# pos_tag, len of sent: 13 13
# 11 11 15
# pos_tag, len of sent: 15 18
# 20 20 24
# pos_tag, len of sent: 24 24
# 13 13 19
# pos_tag, len of sent: 19 19
# 19 19 27
# pos_tag, len of sent: 27 28
# 17 17 23
# pos_tag, len of sent: 23 23
# 18 18 24
# pos_tag, len of sent: 24 32
# 13 13 17
# pos_tag, len of sent: 17 17
# 26 26 29
# pos_tag, len of sent: 29 30
# 20 20 26
# pos_tag, len of sent: 26 26
# 9 9 12
# pos_tag, len of sent: 12 12
# 17 17 17
# pos_tag, len of sent: 17 17
# 23 23 28
# pos_tag, len of sent: 28 28
# 24 24 26
# pos_tag, len of sent: 26 27
# 22 22 22
# pos_tag, len of sent: 22 26
# 17 17 26
# pos_tag, len of sent: 26 26
# 6 6 10
# pos_tag, len of sent: 10 10
# 17 17 28
# pos_tag, len of sent: 28 28
# 16 16 26
# pos_tag, len of sent: 26 26
# 20 20 22
# pos_tag, len of sent: 22 22
# 18 18 21
# pos_tag, len of sent: 21 43
# 27 27 30
# pos_tag, len of sent: 30 31
# 15 15 17
# pos_tag, len of sent: 17 52
# 22 22 23
# pos_tag, len of sent: 23 23
# 10 10 12
# pos_tag, len of sent: 12 12
# 13 13 16
# pos_tag, len of sent: 16 16
# 12 12 23
# pos_tag, len of sent: 23 23
# 5 5 6
# pos_tag, len of sent: 6 6
# 26 26 30
# pos_tag, len of sent: 30 39
# 15 15 17
# pos_tag, len of sent: 17 17
# 6 6 10
# pos_tag, len of sent: 10 10
# 10 10 15
# pos_tag, len of sent: 15 15
# 22 22 28
# pos_tag, len of sent: 28 38
# 22 22 25
# pos_tag, len of sent: 25 36
# 24 24 26
# pos_tag, len of sent: 26 34
# 17 17 23
# pos_tag, len of sent: 23 23
# 6 6 8
# pos_tag, len of sent: 8 8
# 25 25 29
# pos_tag, len of sent: 29 26
# 24 24 32
# pos_tag, len of sent: 32 22
# 21 21 21
# pos_tag, len of sent: 21 26
# 12 12 14
# pos_tag, len of sent: 14 14
# 21 21 24
# pos_tag, len of sent: 24 18
# 7 7 11
# pos_tag, len of sent: 11 11
# 13 13 18
# pos_tag, len of sent: 18 20
# 4 4 5
# pos_tag, len of sent: 5 5
# 21 21 28
# pos_tag, len of sent: 28 23
# 7 7 7
# pos_tag, len of sent: 7 7
# 22 22 33
# pos_tag, len of sent: 33 35
# 19 19 24
# pos_tag, len of sent: 24 25
# 7 7 11
# pos_tag, len of sent: 11 11
# 15 15 19
# pos_tag, len of sent: 19 19
# 25 25 27
# pos_tag, len of sent: 27 34
# 8 8 15
# pos_tag, len of sent: 15 15
# 16 16 20
# pos_tag, len of sent: 20 20
# 27 27 31
# pos_tag, len of sent: 31 29
# 18 18 19
# pos_tag, len of sent: 19 19
# 15 15 22
# pos_tag, len of sent: 22 22
# 24 24 31
# pos_tag, len of sent: 31 32
# 17 17 18
# pos_tag, len of sent: 18 18
# 14 14 17
# pos_tag, len of sent: 17 18
# 4 4 6
# pos_tag, len of sent: 6 6
# 24 24 22
# pos_tag, len of sent: 22 30
# 9 9 14
# pos_tag, len of sent: 14 14
# 17 17 24
# pos_tag, len of sent: 24 24
# 16 16 22
# pos_tag, len of sent: 22 22
# 17 17 25
# pos_tag, len of sent: 25 25
# 23 23 36
# pos_tag, len of sent: 36 43
# 24 24 25
# pos_tag, len of sent: 25 45
# 36 36 43
# pos_tag, len of sent: 43 56
# 22 22 22
# pos_tag, len of sent: 22 23
# 27 27 29
# pos_tag, len of sent: 29 30
# 34 34 33
# pos_tag, len of sent: 33 42
# 27 27 36
# pos_tag, len of sent: 36 47
# 10 10 10
# pos_tag, len of sent: 10 10
# 20 20 24
# pos_tag, len of sent: 24 27
# 10 10 15
# pos_tag, len of sent: 15 15
# 12 12 18
# pos_tag, len of sent: 18 18
# 21 21 23
# pos_tag, len of sent: 23 24
# 25 25 26
# pos_tag, len of sent: 26 36
# 24 24 28
# pos_tag, len of sent: 28 32
# 15 15 21
# pos_tag, len of sent: 21 21
# 23 23 28
# pos_tag, len of sent: 28 38
# 23 23 29
# pos_tag, len of sent: 29 29
# 13 13 17
# pos_tag, len of sent: 17 17
# 28 28 32
# pos_tag, len of sent: 32 29
# 20 20 26
# pos_tag, len of sent: 26 26
# 14 14 18
# pos_tag, len of sent: 18 20
# 17 17 25
# pos_tag, len of sent: 25 49
# 25 25 29
# pos_tag, len of sent: 29 30
# 16 16 20
# pos_tag, len of sent: 20 20
# 31 31 30
# pos_tag, len of sent: 30 27
# 28 28 32
# pos_tag, len of sent: 32 33
# 20 20 22
# pos_tag, len of sent: 22 30
# 24 24 25
# pos_tag, len of sent: 25 40
# 31 31 34
# pos_tag, len of sent: 34 41
# 25 25 30
# pos_tag, len of sent: 30 51
# 26 26 28
# pos_tag, len of sent: 28 32
# 22 22 24
# pos_tag, len of sent: 24 39
# 18 18 21
# pos_tag, len of sent: 21 21
# 15 15 17
# pos_tag, len of sent: 17 17
# 14 14 21
# pos_tag, len of sent: 21 21
# 16 16 23
# pos_tag, len of sent: 23 23
# 6 6 8
# pos_tag, len of sent: 8 8
# 21 21 24
# pos_tag, len of sent: 24 40
# 26 26 32
# pos_tag, len of sent: 32 34
# 8 8 11
# pos_tag, len of sent: 11 11
# 23 23 28
# pos_tag, len of sent: 28 33
# 18 18 21
# pos_tag, len of sent: 21 47
# 18 18 28
# pos_tag, len of sent: 28 45
# 13 13 20
# pos_tag, len of sent: 20 20
# 23 23 26
# pos_tag, len of sent: 26 17
# 10 10 14
# pos_tag, len of sent: 14 14
# 10 10 14
# pos_tag, len of sent: 14 14
# 8 8 14
# pos_tag, len of sent: 14 14
# 13 13 14
# pos_tag, len of sent: 14 14
# 15 15 21
# pos_tag, len of sent: 21 21
# 23 23 19
# pos_tag, len of sent: 19 21
# 25 25 25
# pos_tag, len of sent: 25 37
# 21 21 25
# pos_tag, len of sent: 25 35
# 17 17 22
# pos_tag, len of sent: 22 21
# 22 22 25
# pos_tag, len of sent: 25 42
# 8 8 11
# pos_tag, len of sent: 11 11
# 9 9 12
# pos_tag, len of sent: 12 12
# 31 31 33
# pos_tag, len of sent: 33 43
# 13 13 18
# pos_tag, len of sent: 18 18
# 17 17 23
# pos_tag, len of sent: 23 30
# 17 17 22
# pos_tag, len of sent: 22 27
# 23 23 22
# pos_tag, len of sent: 22 23
# 17 17 22
# pos_tag, len of sent: 22 22
# 22 22 30
# pos_tag, len of sent: 30 35
# 21 21 22
# pos_tag, len of sent: 22 31
# 6 6 11
# pos_tag, len of sent: 11 25
# 28 28 27
# pos_tag, len of sent: 27 47
# 14 14 15
# pos_tag, len of sent: 15 15
# 24 24 35
# pos_tag, len of sent: 35 52
# 14 14 20
# pos_tag, len of sent: 20 20
# 16 16 18
# pos_tag, len of sent: 18 18
# 20 20 27
# pos_tag, len of sent: 27 38
# 25 25 31
# pos_tag, len of sent: 31 32
# 7 7 10
# pos_tag, len of sent: 10 10
# 23 23 20
# pos_tag, len of sent: 20 25
# 23 23 31
# pos_tag, len of sent: 31 32
# 31 31 43
# pos_tag, len of sent: 43 23
# 16 16 19
# pos_tag, len of sent: 19 39
# 17 17 25
# pos_tag, len of sent: 25 37
# 13 13 15
# pos_tag, len of sent: 15 15
# 22 22 26
# pos_tag, len of sent: 26 30
# 37 37 29
# pos_tag, len of sent: 29 21
# 28 28 28
# pos_tag, len of sent: 28 30
# 19 19 24
# pos_tag, len of sent: 24 24
# 11 11 18
# pos_tag, len of sent: 18 18
# 27 27 25
# pos_tag, len of sent: 25 44
# 10 10 6
# pos_tag, len of sent: 6 1
# 27 27 30
# pos_tag, len of sent: 30 31
# 22 22 33
# pos_tag, len of sent: 33 34
# 15 15 26
# pos_tag, len of sent: 26 17
# 15 15 29
# pos_tag, len of sent: 29 29
# 14 14 21
# pos_tag, len of sent: 21 21
# 18 18 26
# pos_tag, len of sent: 26 26
# 15 15 23
# pos_tag, len of sent: 23 23
# 16 16 17
# pos_tag, len of sent: 17 17
# 14 14 18
# pos_tag, len of sent: 18 24
# 25 25 28
# pos_tag, len of sent: 28 37
# 20 20 26
# pos_tag, len of sent: 26 26
# 27 27 34
# pos_tag, len of sent: 34 34
# 21 21 25
# pos_tag, len of sent: 25 26
# 22 22 29
# pos_tag, len of sent: 29 37
# 21 21 30
# pos_tag, len of sent: 30 31
# 22 22 31
# pos_tag, len of sent: 31 40
# 9 9 12
# pos_tag, len of sent: 12 12
# 28 28 30
# pos_tag, len of sent: 30 47
# 13 13 17
# pos_tag, len of sent: 17 16
# 30 30 32
# pos_tag, len of sent: 32 35
# 17 17 25
# pos_tag, len of sent: 25 25
# 20 20 23
# pos_tag, len of sent: 23 24
# 25 25 30
# pos_tag, len of sent: 30 31
# 23 23 24
# pos_tag, len of sent: 24 34
# 22 22 32
# pos_tag, len of sent: 32 39
# 21 21 21
# pos_tag, len of sent: 21 44
# 12 12 13
# pos_tag, len of sent: 13 13
# 18 18 23
# pos_tag, len of sent: 23 23
# 24 24 28
# pos_tag, len of sent: 28 35
# 28 28 28
# pos_tag, len of sent: 28 45
# 14 14 16
# pos_tag, len of sent: 16 16
# 16 16 27
# pos_tag, len of sent: 27 26
# 17 17 20
# pos_tag, len of sent: 20 20
# 21 21 25
# pos_tag, len of sent: 25 31
# 1 1 4
# pos_tag, len of sent: 4 4
# 1 1 3
# pos_tag, len of sent: 3 3
# 12 12 27
# pos_tag, len of sent: 27 28
# 11 11 20
# pos_tag, len of sent: 20 20
# 25 25 42
# pos_tag, len of sent: 42 3
# 14 14 20
# pos_tag, len of sent: 20 21
# 11 11 18
# pos_tag, len of sent: 18 18
# 2 2 3
# pos_tag, len of sent: 3 3
# 32 32 25
# pos_tag, len of sent: 25 38
# 16 16 21
# pos_tag, len of sent: 21 21
# 18 18 25
# pos_tag, len of sent: 25 42
# 2 2 3
# pos_tag, len of sent: 3 3
# 10 10 19
# pos_tag, len of sent: 19 19
# 28 28 30
# pos_tag, len of sent: 30 36
# 12 12 16
# pos_tag, len of sent: 16 14
# 12 12 15
# pos_tag, len of sent: 15 17
# 22 22 27
# pos_tag, len of sent: 27 31
# 27 27 36
# pos_tag, len of sent: 36 37
# 9 9 13
# pos_tag, len of sent: 13 13
# 31 31 30
# pos_tag, len of sent: 30 38
# 18 18 20
# pos_tag, len of sent: 20 20
# 18 18 24
# pos_tag, len of sent: 24 25
# 21 21 21
# pos_tag, len of sent: 21 21
# 23 23 42
# pos_tag, len of sent: 42 34
# 9 9 13
# pos_tag, len of sent: 13 13
# 22 22 31
# pos_tag, len of sent: 31 31
# 12 12 21
# pos_tag, len of sent: 21 21
# 21 21 26
# pos_tag, len of sent: 26 33
# 25 25 33
# pos_tag, len of sent: 33 41
# 14 14 18
# pos_tag, len of sent: 18 18
# 17 17 16
# pos_tag, len of sent: 16 24
# 21 21 25
# pos_tag, len of sent: 25 33
# 20 20 20
# pos_tag, len of sent: 20 24
# 29 29 42
# pos_tag, len of sent: 42 19
# 21 21 29
# pos_tag, len of sent: 29 29
# 18 18 19
# pos_tag, len of sent: 19 19
# 28 28 30
# pos_tag, len of sent: 30 35
# 24 24 27
# pos_tag, len of sent: 27 28
# 13 13 17
# pos_tag, len of sent: 17 17
# 22 22 25
# pos_tag, len of sent: 25 25
# 20 20 24
# pos_tag, len of sent: 24 26
# 20 20 30
# pos_tag, len of sent: 30 30
# 18 18 22
# pos_tag, len of sent: 22 33
# 21 21 24
# pos_tag, len of sent: 24 24
# 26 26 29
# pos_tag, len of sent: 29 33
# 24 24 20
# pos_tag, len of sent: 20 28
# 28 28 36
# pos_tag, len of sent: 36 29
# 26 26 30
# pos_tag, len of sent: 30 31
# 20 20 35
# pos_tag, len of sent: 35 48
# 14 14 16
# pos_tag, len of sent: 16 25
# 21 21 28
# pos_tag, len of sent: 28 29
# 16 16 20
# pos_tag, len of sent: 20 20
# 29 29 29
# pos_tag, len of sent: 29 44
# 6 6 8
# pos_tag, len of sent: 8 8
# 22 22 30
# pos_tag, len of sent: 30 38
# 26 26 29
# pos_tag, len of sent: 29 21
# 25 25 33
# pos_tag, len of sent: 33 39
# 25 25 33
# pos_tag, len of sent: 33 34
# 20 20 24
# pos_tag, len of sent: 24 44
# 27 27 47
# pos_tag, len of sent: 47 37
# 10 10 15
# pos_tag, len of sent: 15 15
# 8 8 17
# pos_tag, len of sent: 17 17
# 28 28 44
# pos_tag, len of sent: 44 26
# 12 12 19
# pos_tag, len of sent: 19 19
# 10 10 15
# pos_tag, len of sent: 15 15
# 19 19 24
# pos_tag, len of sent: 24 24
# 9 9 13
# pos_tag, len of sent: 13 13
# 4 4 11
# pos_tag, len of sent: 11 11
# 31 31 41
# pos_tag, len of sent: 41 43
# 27 27 31
# pos_tag, len of sent: 31 32
# 23 23 26
# pos_tag, len of sent: 26 30
# 26 26 29
# pos_tag, len of sent: 29 39
# 18 18 22
# pos_tag, len of sent: 22 22
# 23 23 32
# pos_tag, len of sent: 32 37
# 14 14 19
# pos_tag, len of sent: 19 28
# 22 22 30
# pos_tag, len of sent: 30 40
# 20 20 26
# pos_tag, len of sent: 26 40
# 22 22 31
# pos_tag, len of sent: 31 32
# 13 13 16
# pos_tag, len of sent: 16 16
# 11 11 18
# pos_tag, len of sent: 18 18
# 16 16 25
# pos_tag, len of sent: 25 38
# 17 17 27
# pos_tag, len of sent: 27 27
# 24 24 31
# pos_tag, len of sent: 31 44
# 34 34 41
# pos_tag, len of sent: 41 48
# 21 21 32
# pos_tag, len of sent: 32 33
# 22 22 26
# pos_tag, len of sent: 26 28
# 25 25 31
# pos_tag, len of sent: 31 30
# 25 25 31
# pos_tag, len of sent: 31 32
# 22 22 23
# pos_tag, len of sent: 23 24
# 19 19 23
# pos_tag, len of sent: 23 34
# 25 25 31
# pos_tag, len of sent: 31 32
# 25 25 19
# pos_tag, len of sent: 19 25
# 34 34 31
# pos_tag, len of sent: 31 41
# 22 22 31
# pos_tag, len of sent: 31 39
# 19 19 24
# pos_tag, len of sent: 24 48
# 20 20 24
# pos_tag, len of sent: 24 29
# 25 25 23
# pos_tag, len of sent: 23 32
# 10 10 16
# pos_tag, len of sent: 16 16
# 21 21 40
# pos_tag, len of sent: 40 31
# 17 17 23
# pos_tag, len of sent: 23 23
# 28 28 33
# pos_tag, len of sent: 33 43
# 20 20 24
# pos_tag, len of sent: 24 28
# 12 12 16
# pos_tag, len of sent: 16 16
# 21 21 22
# pos_tag, len of sent: 22 25
# 28 28 26
# pos_tag, len of sent: 26 48
# 22 22 33
# pos_tag, len of sent: 33 55
# 21 21 19
# pos_tag, len of sent: 19 20
# 26 26 26
# pos_tag, len of sent: 26 34
# 23 23 24
# pos_tag, len of sent: 24 30
# 8 8 11
# pos_tag, len of sent: 11 11
# 11 11 17
# pos_tag, len of sent: 17 17
# 20 20 26
# pos_tag, len of sent: 26 33
# 25 25 28
# pos_tag, len of sent: 28 36
# 12 12 15
# pos_tag, len of sent: 15 12
# 52 52 38
# pos_tag, len of sent: 38 27
# 6 6 12
# pos_tag, len of sent: 12 12
# 5 5 7
# pos_tag, len of sent: 7 7
# 29 29 32
# pos_tag, len of sent: 32 46
# 23 23 26
# pos_tag, len of sent: 26 27
# 30 30 35
# pos_tag, len of sent: 35 40
# 8 8 13
# pos_tag, len of sent: 13 13
# 23 23 25
# pos_tag, len of sent: 25 40
# 12 12 14
# pos_tag, len of sent: 14 14
# 17 17 28
# pos_tag, len of sent: 28 28
# 15 15 27
# pos_tag, len of sent: 27 27
# 27 27 23
# pos_tag, len of sent: 23 34
# 35 35 31
# pos_tag, len of sent: 31 32
# 10 10 12
# pos_tag, len of sent: 12 12
# 20 20 25
# pos_tag, len of sent: 25 33
# 25 25 34
# pos_tag, len of sent: 34 39
# 22 22 25
# pos_tag, len of sent: 25 26
# 7 7 10
# pos_tag, len of sent: 10 10
# 22 22 22
# pos_tag, len of sent: 22 37
# 21 21 23
# pos_tag, len of sent: 23 27
# 6 6 8
# pos_tag, len of sent: 8 8
# 12 12 14
# pos_tag, len of sent: 14 14
# 18 18 23
# pos_tag, len of sent: 23 23
# 31 31 34
# pos_tag, len of sent: 34 40
# 21 21 26
# pos_tag, len of sent: 26 35
# 20 20 26
# pos_tag, len of sent: 26 43
# 11 11 13
# pos_tag, len of sent: 13 13
# 8 8 10
# pos_tag, len of sent: 10 10
# 21 21 22
# pos_tag, len of sent: 22 35
# 19 19 28
# pos_tag, len of sent: 28 30
# 22 22 31
# pos_tag, len of sent: 31 41
# 33 33 35
# pos_tag, len of sent: 35 33
# 20 20 32
# pos_tag, len of sent: 32 43
# 18 18 29
# pos_tag, len of sent: 29 29
# 22 22 26
# pos_tag, len of sent: 26 31
# 22 22 26
# pos_tag, len of sent: 26 40
# 13 13 15
# pos_tag, len of sent: 15 56
# 20 20 25
# pos_tag, len of sent: 25 32
# 14 14 20
# pos_tag, len of sent: 20 20
# 14 14 19
# pos_tag, len of sent: 19 18
# 23 23 28
# pos_tag, len of sent: 28 29
# 18 18 23
# pos_tag, len of sent: 23 23
# 14 14 18
# pos_tag, len of sent: 18 18
# 12 12 21
# pos_tag, len of sent: 21 21
# 6 6 7
# pos_tag, len of sent: 7 7
# 16 16 20
# pos_tag, len of sent: 20 41
# 22 22 24
# pos_tag, len of sent: 24 25
# 16 16 24
# pos_tag, len of sent: 24 26
# 17 17 24
# pos_tag, len of sent: 24 24
# 17 17 24
# pos_tag, len of sent: 24 24
# 22 22 28
# pos_tag, len of sent: 28 61
# 9 9 13
# pos_tag, len of sent: 13 13
# 7 7 6
# pos_tag, len of sent: 6 6
# 23 23 34
# pos_tag, len of sent: 34 45
# 39 39 54
# pos_tag, len of sent: 54 35
# 31 31 36
# pos_tag, len of sent: 36 42
# 37 37 39
# pos_tag, len of sent: 39 29
# 27 27 29
# pos_tag, len of sent: 29 30
# 20 20 27
# pos_tag, len of sent: 27 27
# 11 11 18
# pos_tag, len of sent: 18 19
# 12 12 21
# pos_tag, len of sent: 21 21
# 6 6 9
# pos_tag, len of sent: 9 9
# 32 32 42
# pos_tag, len of sent: 42 46
# 8 8 17
# pos_tag, len of sent: 17 16
# 23 23 29
# pos_tag, len of sent: 29 30
# 21 21 36
# pos_tag, len of sent: 36 52
# 8 8 9
# pos_tag, len of sent: 9 9
# 28 28 30
# pos_tag, len of sent: 30 39
# 14 14 24
# pos_tag, len of sent: 24 24
# 12 12 14
# pos_tag, len of sent: 14 14
# 13 13 17
# pos_tag, len of sent: 17 22
# 14 14 22
# pos_tag, len of sent: 22 22
# 19 19 29
# pos_tag, len of sent: 29 29
# 19 19 24
# pos_tag, len of sent: 24 24
# 23 23 27
# pos_tag, len of sent: 27 28
# 11 11 16
# pos_tag, len of sent: 16 16
# 9 9 14
# pos_tag, len of sent: 14 14
# 15 15 31
# pos_tag, len of sent: 31 22
# 9 9 13
# pos_tag, len of sent: 13 13
# 17 17 27
# pos_tag, len of sent: 27 27
# 16 16 31
# pos_tag, len of sent: 31 30
# 26 26 33
# pos_tag, len of sent: 33 49
# 11 11 18
# pos_tag, len of sent: 18 18
# 24 24 37
# pos_tag, len of sent: 37 54
# 12 12 18
# pos_tag, len of sent: 18 18
# 25 25 24
# pos_tag, len of sent: 24 43
# 24 24 30
# pos_tag, len of sent: 30 52
# 21 21 26
# pos_tag, len of sent: 26 40
# 28 28 35
# pos_tag, len of sent: 35 29
# 15 15 18
# pos_tag, len of sent: 18 18
# 36 36 34
# pos_tag, len of sent: 34 44
# 24 24 28
# pos_tag, len of sent: 28 28
# 24 24 24
# pos_tag, len of sent: 24 29
# 26 26 26
# pos_tag, len of sent: 26 39
# 14 14 19
# pos_tag, len of sent: 19 19
# 6 6 8
# pos_tag, len of sent: 8 8
# 28 28 29
# pos_tag, len of sent: 29 36
# 16 16 22
# pos_tag, len of sent: 22 22
# 27 27 22
# pos_tag, len of sent: 22 20
# 21 21 20
# pos_tag, len of sent: 20 21
# 11 11 16
# pos_tag, len of sent: 16 16
# 26 26 25
# pos_tag, len of sent: 25 64
# 6 6 7
# pos_tag, len of sent: 7 7
# 16 16 26
# pos_tag, len of sent: 26 32
# 21 21 25
# pos_tag, len of sent: 25 27
# 17 17 25
# pos_tag, len of sent: 25 25
# 19 19 24
# pos_tag, len of sent: 24 24
# 16 16 30
# pos_tag, len of sent: 30 30
# 22 22 27
# pos_tag, len of sent: 27 24
# 31 31 38
# pos_tag, len of sent: 38 25
# 27 27 30
# pos_tag, len of sent: 30 37
# 6 6 11
# pos_tag, len of sent: 11 11
# 20 20 22
# pos_tag, len of sent: 22 47
# 31 31 30
# pos_tag, len of sent: 30 46
# 12 12 14
# pos_tag, len of sent: 14 14
# 4 4 5
# pos_tag, len of sent: 5 5
# 21 21 26
# pos_tag, len of sent: 26 43
# 26 26 24
# pos_tag, len of sent: 24 36
# 9 9 13
# pos_tag, len of sent: 13 13
# 18 18 21
# pos_tag, len of sent: 21 34
# 22 22 24
# pos_tag, len of sent: 24 32
# 27 27 31
# pos_tag, len of sent: 31 47
# 11 11 17
# pos_tag, len of sent: 17 17
# 41 41 40
# pos_tag, len of sent: 40 37
# 17 17 25
# pos_tag, len of sent: 25 25
# 14 14 20
# pos_tag, len of sent: 20 20
# 27 27 27
# pos_tag, len of sent: 27 40
# 24 24 28
# pos_tag, len of sent: 28 33
# 10 10 16
# pos_tag, len of sent: 16 16
# 24 24 26
# pos_tag, len of sent: 26 27
# 16 16 22
# pos_tag, len of sent: 22 22
# 23 23 28
# pos_tag, len of sent: 28 46
# 28 28 38
# pos_tag, len of sent: 38 39
# 15 15 19
# pos_tag, len of sent: 19 20
# 34 34 37
# pos_tag, len of sent: 37 36
# 18 18 19
# pos_tag, len of sent: 19 43
# 5 5 7
# pos_tag, len of sent: 7 7
# 12 12 10
# pos_tag, len of sent: 10 18
# 23 23 28
# pos_tag, len of sent: 28 29
# 25 25 29
# pos_tag, len of sent: 29 58
# 16 16 18
# pos_tag, len of sent: 18 18
# 26 26 37
# pos_tag, len of sent: 37 37
# 20 20 24
# pos_tag, len of sent: 24 27
# 14 14 20
# pos_tag, len of sent: 20 20
# 29 29 32
# pos_tag, len of sent: 32 39
# 21 21 22
# pos_tag, len of sent: 22 35
# 20 20 33
# pos_tag, len of sent: 33 41
# 25 25 25
# pos_tag, len of sent: 25 69
# 15 15 19
# pos_tag, len of sent: 19 29
# 12 12 14
# pos_tag, len of sent: 14 20
# 22 22 26
# pos_tag, len of sent: 26 37
# 17 17 25
# pos_tag, len of sent: 25 26
# 16 16 19
# pos_tag, len of sent: 19 19
# 8 8 11
# pos_tag, len of sent: 11 11
# 15 15 15
# pos_tag, len of sent: 15 15
# 11 11 12
# pos_tag, len of sent: 12 13
# 12 12 12
# pos_tag, len of sent: 12 14
# 29 29 23
# pos_tag, len of sent: 23 30
# 30 30 30
# pos_tag, len of sent: 30 33
# 8 8 13
# pos_tag, len of sent: 13 13
# 17 17 26
# pos_tag, len of sent: 26 26
# 17 17 22
# pos_tag, len of sent: 22 22
# 11 11 12
# pos_tag, len of sent: 12 12
# 34 34 30
# pos_tag, len of sent: 30 34
# 14 14 18
# pos_tag, len of sent: 18 27
# 19 19 20
# pos_tag, len of sent: 20 20
# 23 23 26
# pos_tag, len of sent: 26 31
# 17 17 20
# pos_tag, len of sent: 20 20
# 26 26 27
# pos_tag, len of sent: 27 32
# 16 16 22
# pos_tag, len of sent: 22 31
# 23 23 26
# pos_tag, len of sent: 26 27
# 21 21 34
# pos_tag, len of sent: 34 37
# 13 13 15
# pos_tag, len of sent: 15 15
# 9 9 13
# pos_tag, len of sent: 13 16
# 17 17 28
# pos_tag, len of sent: 28 29
# 15 15 26
# pos_tag, len of sent: 26 26
# 17 17 25
# pos_tag, len of sent: 25 25
# 13 13 20
# pos_tag, len of sent: 20 20
# 12 12 16
# pos_tag, len of sent: 16 16
# 11 11 15
# pos_tag, len of sent: 15 17
# 10 10 10
# pos_tag, len of sent: 10 10
# 18 18 32
# pos_tag, len of sent: 32 32
# 10 10 12
# pos_tag, len of sent: 12 14
# 7 7 10
# pos_tag, len of sent: 10 10
# 11 11 20
# pos_tag, len of sent: 20 22
# 6 6 6
# pos_tag, len of sent: 6 6
# 10 10 14
# pos_tag, len of sent: 14 14
# 6 6 8
# pos_tag, len of sent: 8 8
# 10 10 15
# pos_tag, len of sent: 15 15
# 9 9 19
# pos_tag, len of sent: 19 19
# 24 24 28
# pos_tag, len of sent: 28 30
# 17 17 28
# pos_tag, len of sent: 28 28
# 15 15 28
# pos_tag, len of sent: 28 28
# 22 22 33
# pos_tag, len of sent: 33 33
# 25 25 23
# pos_tag, len of sent: 23 29
# 22 22 24
# pos_tag, len of sent: 24 17
# 19 19 26
# pos_tag, len of sent: 26 26
# 25 25 28
# pos_tag, len of sent: 28 39
# 18 18 23
# pos_tag, len of sent: 23 24
# 15 15 23
# pos_tag, len of sent: 23 23
# 23 23 31
# pos_tag, len of sent: 31 42
# 14 14 21
# pos_tag, len of sent: 21 23
# 15 15 20
# pos_tag, len of sent: 20 20
# 23 23 25
# pos_tag, len of sent: 25 36
# 28 28 30
# pos_tag, len of sent: 30 32
# 29 29 30
# pos_tag, len of sent: 30 35
# 30 30 34
# pos_tag, len of sent: 34 41
# 21 21 22
# pos_tag, len of sent: 22 32
# 20 20 24
# pos_tag, len of sent: 24 25
# 10 10 19
# pos_tag, len of sent: 19 19
# 28 28 30
# pos_tag, len of sent: 30 32
# 15 15 20
# pos_tag, len of sent: 20 20
# 17 17 19
# pos_tag, len of sent: 19 19
# 23 23 22
# pos_tag, len of sent: 22 35
# 22 22 21
# pos_tag, len of sent: 21 26
# 7 7 11
# pos_tag, len of sent: 11 11
# 22 22 22
# pos_tag, len of sent: 22 22
# 20 20 32
# pos_tag, len of sent: 32 40
# 23 23 27
# pos_tag, len of sent: 27 49
# 25 25 30
# pos_tag, len of sent: 30 37
# 18 18 17
# pos_tag, len of sent: 17 48
# 24 24 29
# pos_tag, len of sent: 29 32
# 22 22 29
# pos_tag, len of sent: 29 43
# 20 20 23
# pos_tag, len of sent: 23 31
# 8 8 17
# pos_tag, len of sent: 17 17
# 8 8 15
# pos_tag, len of sent: 15 15
# 18 18 27
# pos_tag, len of sent: 27 27
# 14 14 21
# pos_tag, len of sent: 21 21
# 35 35 34
# pos_tag, len of sent: 34 28
# 20 20 24
# pos_tag, len of sent: 24 25
# 12 12 16
# pos_tag, len of sent: 16 16
# 12 12 13
# pos_tag, len of sent: 13 13
# 14 14 18
# pos_tag, len of sent: 18 30
# 23 23 27
# pos_tag, len of sent: 27 32
# 18 18 22
# pos_tag, len of sent: 22 23
# 24 24 29
# pos_tag, len of sent: 29 44
# 8 8 11
# pos_tag, len of sent: 11 11
# 17 17 20
# pos_tag, len of sent: 20 20
# 12 12 18
# pos_tag, len of sent: 18 23
# 50 50 56
# pos_tag, len of sent: 56 38
# 17 17 22
# pos_tag, len of sent: 22 24
# 12 12 15
# pos_tag, len of sent: 15 20
# 38 38 41
# pos_tag, len of sent: 41 27
# 22 22 32
# pos_tag, len of sent: 32 30
# 17 17 20
# pos_tag, len of sent: 20 20
# 16 16 23
# pos_tag, len of sent: 23 23
# 22 22 34
# pos_tag, len of sent: 34 37
# 14 14 20
# pos_tag, len of sent: 20 20
# 17 17 23
# pos_tag, len of sent: 23 23
# 8 8 14
# pos_tag, len of sent: 14 14
# 8 8 16
# pos_tag, len of sent: 16 16
# 9 9 17
# pos_tag, len of sent: 17 17
# 21 21 49
# pos_tag, len of sent: 49 40
# 23 23 27
# pos_tag, len of sent: 27 59
# 18 18 27
# pos_tag, len of sent: 27 29
# 10 10 16
# pos_tag, len of sent: 16 18
# 30 30 32
# pos_tag, len of sent: 32 42
# 28 28 36
# pos_tag, len of sent: 36 72
# 21 21 31
# pos_tag, len of sent: 31 42
# 22 22 29
# pos_tag, len of sent: 29 33
# 28 28 28
# pos_tag, len of sent: 28 40
# 19 19 37
# pos_tag, len of sent: 37 44
# 27 27 28
# pos_tag, len of sent: 28 29
# 18 18 22
# pos_tag, len of sent: 22 22
# 15 15 18
# pos_tag, len of sent: 18 18
# 11 11 16
# pos_tag, len of sent: 16 16
# 6 6 11
# pos_tag, len of sent: 11 11
# 14 14 19
# pos_tag, len of sent: 19 20
# 27 27 21
# pos_tag, len of sent: 21 34
# 9 9 12
# pos_tag, len of sent: 12 12
# 17 17 26
# pos_tag, len of sent: 26 26
# 18 18 25
# pos_tag, len of sent: 25 28
# 10 10 14
# pos_tag, len of sent: 14 14
# 27 27 26
# pos_tag, len of sent: 26 33
# 8 8 11
# pos_tag, len of sent: 11 11
# 21 21 20
# pos_tag, len of sent: 20 22
# 26 26 33
# pos_tag, len of sent: 33 42
# 16 16 19
# pos_tag, len of sent: 19 20
# 24 24 31
# pos_tag, len of sent: 31 37
# 16 16 19
# pos_tag, len of sent: 19 19
# 21 21 26
# pos_tag, len of sent: 26 27
# 11 11 15
# pos_tag, len of sent: 15 16
# 15 15 20
# pos_tag, len of sent: 20 31
# 13 13 19
# pos_tag, len of sent: 19 21
# 13 13 17
# pos_tag, len of sent: 17 19
# 7 7 12
# pos_tag, len of sent: 12 12
# 18 18 16
# pos_tag, len of sent: 16 16
# 21 21 25
# pos_tag, len of sent: 25 35
# 21 21 30
# pos_tag, len of sent: 30 38
# 6 6 9
# pos_tag, len of sent: 9 9
# 32 32 37
# pos_tag, len of sent: 37 40
# 7 7 9
# pos_tag, len of sent: 9 38
# 26 26 32
# pos_tag, len of sent: 32 34
# 35 35 33
# pos_tag, len of sent: 33 42
# 13 13 18
# pos_tag, len of sent: 18 18
# 18 18 20
# pos_tag, len of sent: 20 19
# 13 13 19
# pos_tag, len of sent: 19 19
# 30 30 28
# pos_tag, len of sent: 28 51
# 5 5 7
# pos_tag, len of sent: 7 7
# 34 34 30
# pos_tag, len of sent: 30 24
# 23 23 19
# pos_tag, len of sent: 19 31
# 30 30 33
# pos_tag, len of sent: 33 22
# 23 23 26
# pos_tag, len of sent: 26 28
# 27 27 34
# pos_tag, len of sent: 34 39
# 22 22 30
# pos_tag, len of sent: 30 22
# 8 8 10
# pos_tag, len of sent: 10 10
# 22 22 31
# pos_tag, len of sent: 31 40
# 16 16 16
# pos_tag, len of sent: 16 16
# 20 20 21
# pos_tag, len of sent: 21 28
# 9 9 12
# pos_tag, len of sent: 12 12
# 13 13 16
# pos_tag, len of sent: 16 16
# 28 28 27
# pos_tag, len of sent: 27 29
# 22 22 33
# pos_tag, len of sent: 33 38
# 9 9 11
# pos_tag, len of sent: 11 11
# 20 20 27
# pos_tag, len of sent: 27 27
# 24 24 28
# pos_tag, len of sent: 28 40
# 28 28 35
# pos_tag, len of sent: 35 35
# 12 12 20
# pos_tag, len of sent: 20 19
# 9 9 16
# pos_tag, len of sent: 16 16
# 22 22 25
# pos_tag, len of sent: 25 31
# 29 29 43
# pos_tag, len of sent: 43 35
# 7 7 7
# pos_tag, len of sent: 7 7
# 29 29 30
# pos_tag, len of sent: 30 52
# 13 13 19
# pos_tag, len of sent: 19 19
# 13 13 20
# pos_tag, len of sent: 20 20
# 26 26 27
# pos_tag, len of sent: 27 28
# 23 23 27
# pos_tag, len of sent: 27 36
# 29 29 30
# pos_tag, len of sent: 30 37
# 33 33 33
# pos_tag, len of sent: 33 38
# 14 14 20
# pos_tag, len of sent: 20 20
# 20 20 24
# pos_tag, len of sent: 24 25
# 16 16 19
# pos_tag, len of sent: 19 19
# 16 16 18
# pos_tag, len of sent: 18 18
# 18 18 20
# pos_tag, len of sent: 20 20
# 19 19 16
# pos_tag, len of sent: 16 16
# 22 22 26
# pos_tag, len of sent: 26 47
# 23 23 28
# pos_tag, len of sent: 28 49
# 27 27 27
# pos_tag, len of sent: 27 32
# 26 26 28
# pos_tag, len of sent: 28 36
# 9 9 11
# pos_tag, len of sent: 11 11
# 9 9 14
# pos_tag, len of sent: 14 14
# 14 14 20
# pos_tag, len of sent: 20 20
# 25 25 25
# pos_tag, len of sent: 25 19
# 7 7 5
# pos_tag, len of sent: 5 3
# 18 18 24
# pos_tag, len of sent: 24 32
# 28 28 30
# pos_tag, len of sent: 30 49
# 22 22 23
# pos_tag, len of sent: 23 24
# 20 20 27
# pos_tag, len of sent: 27 28
# 23 23 29
# pos_tag, len of sent: 29 34
# 39 39 35
# pos_tag, len of sent: 35 41
# 13 13 18
# pos_tag, len of sent: 18 18
# 12 12 18
# pos_tag, len of sent: 18 18
# 13 13 19
# pos_tag, len of sent: 19 19
# 6 6 7
# pos_tag, len of sent: 7 15
# 26 26 30
# pos_tag, len of sent: 30 30
# 20 20 23
# pos_tag, len of sent: 23 46
# 22 22 24
# pos_tag, len of sent: 24 28
# 25 25 28
# pos_tag, len of sent: 28 42
# 20 20 21
# pos_tag, len of sent: 21 37
# 23 23 28
# pos_tag, len of sent: 28 48
# 5 5 6
# pos_tag, len of sent: 6 6
# 28 28 30
# pos_tag, len of sent: 30 49
# 18 18 24
# pos_tag, len of sent: 24 24
# 22 22 26
# pos_tag, len of sent: 26 27
# 19 19 18
# pos_tag, len of sent: 18 53
# 19 19 29
# pos_tag, len of sent: 29 30
# 14 14 25
# pos_tag, len of sent: 25 25
# 29 29 27
# pos_tag, len of sent: 27 34
# 32 32 28
# pos_tag, len of sent: 28 30
# 8 8 15
# pos_tag, len of sent: 15 15
# 21 21 21
# pos_tag, len of sent: 21 25
# 24 24 26
# pos_tag, len of sent: 26 34
# 5 5 8
# pos_tag, len of sent: 8 8
# 10 10 22
# pos_tag, len of sent: 22 13
# 19 19 31
# pos_tag, len of sent: 31 31
# 14 14 14
# pos_tag, len of sent: 14 14
# 22 22 24
# pos_tag, len of sent: 24 37
# 17 17 24
# pos_tag, len of sent: 24 24
# 14 14 16
# pos_tag, len of sent: 16 16
# 9 9 13
# pos_tag, len of sent: 13 13
# 24 24 20
# pos_tag, len of sent: 20 50
# 11 11 17
# pos_tag, len of sent: 17 17
# 35 35 28
# pos_tag, len of sent: 28 34
# 13 13 15
# pos_tag, len of sent: 15 15
# 14 14 21
# pos_tag, len of sent: 21 21
# 15 15 19
# pos_tag, len of sent: 19 19
# 24 24 27
# pos_tag, len of sent: 27 28
# 48 48 42
# pos_tag, len of sent: 42 22
# 23 23 25
# pos_tag, len of sent: 25 26
# 21 21 25
# pos_tag, len of sent: 25 26
# 15 15 23
# pos_tag, len of sent: 23 24
# 5 5 6
# pos_tag, len of sent: 6 6
# 14 14 20
# pos_tag, len of sent: 20 20
# 26 26 26
# pos_tag, len of sent: 26 27
# 32 32 29
# pos_tag, len of sent: 29 38
# 24 24 26
# pos_tag, len of sent: 26 28
# 21 21 28
# pos_tag, len of sent: 28 28
# 20 20 20
# pos_tag, len of sent: 20 32
# 10 10 14
# pos_tag, len of sent: 14 14
# 17 17 17
# pos_tag, len of sent: 17 17
# 47 47 46
# pos_tag, len of sent: 46 35
# 14 14 22
# pos_tag, len of sent: 22 22
# 14 14 17
# pos_tag, len of sent: 17 17
# 9 9 11
# pos_tag, len of sent: 11 11
# 19 19 24
# pos_tag, len of sent: 24 30
# 18 18 23
# pos_tag, len of sent: 23 27
# 28 28 25
# pos_tag, len of sent: 25 34
# 17 17 20
# pos_tag, len of sent: 20 20
# 14 14 14
# pos_tag, len of sent: 14 27
# 24 24 26
# pos_tag, len of sent: 26 28
# 18 18 22
# pos_tag, len of sent: 22 22
# 27 27 35
# pos_tag, len of sent: 35 43
# 9 9 11
# pos_tag, len of sent: 11 11
# 18 18 27
# pos_tag, len of sent: 27 27
# 20 20 26
# pos_tag, len of sent: 26 31
# 27 27 30
# pos_tag, len of sent: 30 56
# 18 18 22
# pos_tag, len of sent: 22 22
# 19 19 23
# pos_tag, len of sent: 23 28
# 22 22 31
# pos_tag, len of sent: 31 44
# 27 27 29
# pos_tag, len of sent: 29 35
# 18 18 27
# pos_tag, len of sent: 27 41
# 22 22 28
# pos_tag, len of sent: 28 42
# 25 25 29
# pos_tag, len of sent: 29 37
# 25 25 21
# pos_tag, len of sent: 21 42
# 23 23 25
# pos_tag, len of sent: 25 26
# 26 26 28
# pos_tag, len of sent: 28 48
# 14 14 18
# pos_tag, len of sent: 18 18
# 31 31 39
# pos_tag, len of sent: 39 49
# 22 22 31
# pos_tag, len of sent: 31 32
# 18 18 21
# pos_tag, len of sent: 21 21
# 7 7 12
# pos_tag, len of sent: 12 12
# 24 24 25
# pos_tag, len of sent: 25 26
# 22 22 29
# pos_tag, len of sent: 29 30
# 15 15 19
# pos_tag, len of sent: 19 19
# 18 18 27
# pos_tag, len of sent: 27 27
# 24 24 29
# pos_tag, len of sent: 29 31
# 22 22 28
# pos_tag, len of sent: 28 30
# 18 18 22
# pos_tag, len of sent: 22 23
# 28 28 33
# pos_tag, len of sent: 33 36
# 27 27 32
# pos_tag, len of sent: 32 39
# 17 17 19
# pos_tag, len of sent: 19 20
# 20 20 26
# pos_tag, len of sent: 26 36
# 29 29 40
# pos_tag, len of sent: 40 41
# 17 17 25
# pos_tag, len of sent: 25 25
# 15 15 21
# pos_tag, len of sent: 21 21
# 13 13 22
# pos_tag, len of sent: 22 22
# 17 17 22
# pos_tag, len of sent: 22 22
# 11 11 14
# pos_tag, len of sent: 14 14
# 14 14 21
# pos_tag, len of sent: 21 21
# 16 16 19
# pos_tag, len of sent: 19 19
# 35 35 35
# pos_tag, len of sent: 35 30
# 15 15 19
# pos_tag, len of sent: 19 19
# 19 19 21
# pos_tag, len of sent: 21 29
# 19 19 29
# pos_tag, len of sent: 29 31
# 18 18 28
# pos_tag, len of sent: 28 28
# 9 9 14
# pos_tag, len of sent: 14 19
# 12 12 20
# pos_tag, len of sent: 20 20
# 15 15 22
# pos_tag, len of sent: 22 24
# 9 9 14
# pos_tag, len of sent: 14 14
# 15 15 25
# pos_tag, len of sent: 25 25
# 28 28 35
# pos_tag, len of sent: 35 39
# 8 8 12
# pos_tag, len of sent: 12 12
# 20 20 22
# pos_tag, len of sent: 22 32
# 19 19 22
# pos_tag, len of sent: 22 23
# 18 18 24
# pos_tag, len of sent: 24 38
# 21 21 30
# pos_tag, len of sent: 30 30
# 24 24 29
# pos_tag, len of sent: 29 55
# 26 26 29
# pos_tag, len of sent: 29 36
# 17 17 25
# pos_tag, len of sent: 25 34
# 14 14 14
# pos_tag, len of sent: 14 14
# 26 26 31
# pos_tag, len of sent: 31 40
# 17 17 16
# pos_tag, len of sent: 16 16
# 21 21 24
# pos_tag, len of sent: 24 25
# 13 13 24
# pos_tag, len of sent: 24 24
# 24 24 27
# pos_tag, len of sent: 27 28
# 20 20 30
# pos_tag, len of sent: 30 30
# 20 20 24
# pos_tag, len of sent: 24 24
# 13 13 22
# pos_tag, len of sent: 22 22
# 18 18 26
# pos_tag, len of sent: 26 26
# 25 25 31
# pos_tag, len of sent: 31 34
# 12 12 16
# pos_tag, len of sent: 16 16
# 29 29 29
# pos_tag, len of sent: 29 46
# 16 16 24
# pos_tag, len of sent: 24 33
# 13 13 18
# pos_tag, len of sent: 18 18
# 10 10 21
# pos_tag, len of sent: 21 21
# 28 28 41
# pos_tag, len of sent: 41 43
# 16 16 19
# pos_tag, len of sent: 19 19
# 11 11 19
# pos_tag, len of sent: 19 19
# 28 28 29
# pos_tag, len of sent: 29 44
# 27 27 28
# pos_tag, len of sent: 28 37
# 18 18 22
# pos_tag, len of sent: 22 26
# 13 13 15
# pos_tag, len of sent: 15 15
# 18 18 21
# pos_tag, len of sent: 21 21
# 26 26 36
# pos_tag, len of sent: 36 37
# 36 36 39
# pos_tag, len of sent: 39 45
# 13 13 17
# pos_tag, len of sent: 17 24
# 19 19 25
# pos_tag, len of sent: 25 23
# 28 28 28
# pos_tag, len of sent: 28 35
# 30 30 30
# pos_tag, len of sent: 30 46
# 22 22 32
# pos_tag, len of sent: 32 42
# 4 4 6
# pos_tag, len of sent: 6 6
# 22 22 32
# pos_tag, len of sent: 32 46
# 25 25 32
# pos_tag, len of sent: 32 48
# 28 28 24
# pos_tag, len of sent: 24 27
# 26 26 32
# pos_tag, len of sent: 32 39
# 16 16 18
# pos_tag, len of sent: 18 17
# 14 14 21
# pos_tag, len of sent: 21 20
# 19 19 29
# pos_tag, len of sent: 29 25
# 23 23 23
# pos_tag, len of sent: 23 32
# 15 15 20
# pos_tag, len of sent: 20 20
# 12 12 16
# pos_tag, len of sent: 16 16
# 24 24 35
# pos_tag, len of sent: 35 54
# 21 21 29
# pos_tag, len of sent: 29 44
# 22 22 30
# pos_tag, len of sent: 30 32
# 21 21 24
# pos_tag, len of sent: 24 37
# 27 27 25
# pos_tag, len of sent: 25 33
# 13 13 20
# pos_tag, len of sent: 20 19
# 21 21 23
# pos_tag, len of sent: 23 24
# 12 12 14
# pos_tag, len of sent: 14 14
# 20 20 35
# pos_tag, len of sent: 35 35
# 24 24 22
# pos_tag, len of sent: 22 30
# 10 10 16
# pos_tag, len of sent: 16 14
# 15 15 18
# pos_tag, len of sent: 18 19
# 25 25 35
# pos_tag, len of sent: 35 36
# 7 7 10
# pos_tag, len of sent: 10 10
# 13 13 20
# pos_tag, len of sent: 20 21
# 22 22 26
# pos_tag, len of sent: 26 27
# 10 10 12
# pos_tag, len of sent: 12 12
# 6 6 11
# pos_tag, len of sent: 11 11
# 34 34 42
# pos_tag, len of sent: 42 44
# 20 20 32
# pos_tag, len of sent: 32 37
# 24 24 30
# pos_tag, len of sent: 30 37
# 18 18 21
# pos_tag, len of sent: 21 22
# 11 11 19
# pos_tag, len of sent: 19 19
# 25 25 32
# pos_tag, len of sent: 32 39
# 7 7 13
# pos_tag, len of sent: 13 13
# 5 5 8
# pos_tag, len of sent: 8 8
# 17 17 19
# pos_tag, len of sent: 19 24
# 33 33 28
# pos_tag, len of sent: 28 45
# 30 30 28
# pos_tag, len of sent: 28 34
# 16 16 17
# pos_tag, len of sent: 17 20
# 20 20 21
# pos_tag, len of sent: 21 35
# 21 21 29
# pos_tag, len of sent: 29 30
# 21 21 40
# pos_tag, len of sent: 40 27
# 17 17 23
# pos_tag, len of sent: 23 27
# 8 8 11
# pos_tag, len of sent: 11 11
# 28 28 26
# pos_tag, len of sent: 26 43
# 21 21 27
# pos_tag, len of sent: 27 28
# 13 13 17
# pos_tag, len of sent: 17 18
# 26 26 38
# pos_tag, len of sent: 38 55
# 17 17 19
# pos_tag, len of sent: 19 24
# 23 23 25
# pos_tag, len of sent: 25 32
# 23 23 33
# pos_tag, len of sent: 33 42
# 17 17 24
# pos_tag, len of sent: 24 24
# 7 7 10
# ...
# pos_tag, len of sent: 20 20
# 11 11 15
# pos_tag, len of sent: 15 15
# 22 22 31
# pos_tag, len of sent: 31 32
# 18 18 24
# pos_tag, len of sent: 24 24
# 19 19 22
# pos_tag, len of sent: 22 29
# 16 16 20
# pos_tag, len of sent: 20 24
# 12 12 18
# pos_tag, len of sent: 18 18
# 30 30 36
# pos_tag, len of sent: 36 55
# 18 18 25
# pos_tag, len of sent: 25 25
# 23 23 19
# pos_tag, len of sent: 19 39
# 13 13 16
# pos_tag, len of sent: 16 16
# 20 20 24
# pos_tag, len of sent: 24 26
# 21 21 23
# pos_tag, len of sent: 23 53
# 22 22 26
# pos_tag, len of sent: 26 25
# 23 23 22
# pos_tag, len of sent: 22 33
# 19 19 24
# pos_tag, len of sent: 24 37
# 18 18 19
# pos_tag, len of sent: 19 20
# 26 26 19
# pos_tag, len of sent: 19 21
# 18 18 22
# pos_tag, len of sent: 22 22
# 14 14 17
# pos_tag, len of sent: 17 17
# 17 17 29
# pos_tag, len of sent: 29 31
# 26 26 32
# pos_tag, len of sent: 32 45
# 15 15 16
# pos_tag, len of sent: 16 16
# 6 6 11
# pos_tag, len of sent: 11 11
# 6 6 12
# pos_tag, len of sent: 12 12
# 23 23 25
# pos_tag, len of sent: 25 26
# 23 23 23
# pos_tag, len of sent: 23 25
# 6 6 6
# pos_tag, len of sent: 6 4
# 22 22 30
# pos_tag, len of sent: 30 31
# 20 20 19
# pos_tag, len of sent: 19 20
# 22 22 30
# pos_tag, len of sent: 30 49
# 15 15 27
# pos_tag, len of sent: 27 27
# 16 16 17
# pos_tag, len of sent: 17 18
# 30 30 36
# pos_tag, len of sent: 36 48
# 14 14 19
# pos_tag, len of sent: 19 19
# 14 14 22
# pos_tag, len of sent: 22 22
# 14 14 18
# pos_tag, len of sent: 18 18
# 27 27 27
# pos_tag, len of sent: 27 29
# 23 23 23
# pos_tag, len of sent: 23 33
# 16 16 22
# pos_tag, len of sent: 22 23
# 26 26 33
# pos_tag, len of sent: 33 23
# 20 20 26
# pos_tag, len of sent: 26 29
# 20 20 30
# pos_tag, len of sent: 30 30
# 25 25 40
# pos_tag, len of sent: 40 54
# 10 10 18
# pos_tag, len of sent: 18 21
# 40 40 37
# pos_tag, len of sent: 37 59
# 28 28 26
# pos_tag, len of sent: 26 37
# 27 27 30
# pos_tag, len of sent: 30 31
# 4 4 6
# pos_tag, len of sent: 6 6
# 11 11 12
# pos_tag, len of sent: 12 12
# 28 28 33
# pos_tag, len of sent: 33 39
# 18 18 16
# pos_tag, len of sent: 16 16
# 26 26 27
# pos_tag, len of sent: 27 68
# 27 27 30
# pos_tag, len of sent: 30 36
# 26 26 30
# pos_tag, len of sent: 30 33
# 23 23 37
# pos_tag, len of sent: 37 53
# 19 19 26
# pos_tag, len of sent: 26 27
# 20 20 21
# pos_tag, len of sent: 21 43
# 25 25 32
# pos_tag, len of sent: 32 36
# 22 22 24
# pos_tag, len of sent: 24 25
# 27 27 30
# pos_tag, len of sent: 30 36
# 29 29 27
# pos_tag, len of sent: 27 42
# 32 32 30
# pos_tag, len of sent: 30 55
# 21 21 25
# pos_tag, len of sent: 25 54
# 22 22 26
# pos_tag, len of sent: 26 34
# 21 21 22
# pos_tag, len of sent: 22 22
# 9 9 11
# pos_tag, len of sent: 11 11
# 19 19 25
# pos_tag, len of sent: 25 43
# 27 27 22
# pos_tag, len of sent: 22 31
# 26 26 34
# pos_tag, len of sent: 34 43
# 12 12 27
# pos_tag, len of sent: 27 26
# 6 6 10
# pos_tag, len of sent: 10 10
# 8 8 13
# pos_tag, len of sent: 13 13
# 5 5 8
# pos_tag, len of sent: 8 8
# 23 23 44
# pos_tag, len of sent: 44 6
# 8 8 13
# pos_tag, len of sent: 13 13
# 24 24 47
# pos_tag, len of sent: 47 5
# 5 5 10
# pos_tag, len of sent: 10 10
# 5 5 7
# pos_tag, len of sent: 7 4
# 5 5 13
# pos_tag, len of sent: 13 14
# 17 17 38
# pos_tag, len of sent: 38 4
# 10 10 21
# pos_tag, len of sent: 21 19
# 2 2 4
# pos_tag, len of sent: 4 4
# 5 5 12
# pos_tag, len of sent: 12 12
# 21 21 39
# pos_tag, len of sent: 39 3
# 6 6 11
# pos_tag, len of sent: 11 11
# 2 2 3
# pos_tag, len of sent: 3 3
# 5 5 9
# pos_tag, len of sent: 9 9
# 2 2 4
# pos_tag, len of sent: 4 4
# 5 5 9
# pos_tag, len of sent: 9 9
# 1 1 2
# pos_tag, len of sent: 2 5
# 5 5 11
# pos_tag, len of sent: 11 11
# 21 21 39
# pos_tag, len of sent: 39 3
# 4 4 8
# pos_tag, len of sent: 8 8
# 1 1 3
# pos_tag, len of sent: 3 3
# 5 5 9
# pos_tag, len of sent: 9 9
# 2 2 2
# pos_tag, len of sent: 2 2
# 10 10 19
# pos_tag, len of sent: 19 19
# 3 3 4
# pos_tag, len of sent: 4 4
# 10 10 20
# pos_tag, len of sent: 20 20
# 7 7 17
# pos_tag, len of sent: 17 5
# 11 11 20
# pos_tag, len of sent: 20 20
# 3 3 4
# pos_tag, len of sent: 4 4
# 15 15 39
# pos_tag, len of sent: 39 42
# 21 21 52
# pos_tag, len of sent: 52 6
# 8 8 15
# pos_tag, len of sent: 15 15
# 35 35 39
# pos_tag, len of sent: 39 2
# 11 11 26
# pos_tag, len of sent: 26 26
# 1 1 1
# pos_tag, len of sent: 1 6
# 13 13 20
# pos_tag, len of sent: 20 20
# 1 1 4
# pos_tag, len of sent: 4 4
# 7 7 11
# pos_tag, len of sent: 11 11
# 12 12 15
# pos_tag, len of sent: 15 9
# 8 8 14
# pos_tag, len of sent: 14 14
# 3 3 7
# pos_tag, len of sent: 7 10
# 8 8 17
# pos_tag, len of sent: 17 17
# 3 3 5
# pos_tag, len of sent: 5 5
# 10 10 18
# pos_tag, len of sent: 18 18
# 24 24 60
# pos_tag, len of sent: 60 8
# 11 11 23
# pos_tag, len of sent: 23 23
# 29 29 31
# pos_tag, len of sent: 31 42
# 21 21 24
# pos_tag, len of sent: 24 34
# 7 7 10
# pos_tag, len of sent: 10 10
# 29 29 37
# pos_tag, len of sent: 37 40
# 28 28 26
# pos_tag, len of sent: 26 15
# 9 9 8
# pos_tag, len of sent: 8 8
# 10 10 13
# pos_tag, len of sent: 13 13
# 21 21 18
# pos_tag, len of sent: 18 21
# 20 20 22
# pos_tag, len of sent: 22 30
# 21 21 29
# pos_tag, len of sent: 29 40
# 26 26 39
# pos_tag, len of sent: 39 24
# 22 22 21
# pos_tag, len of sent: 21 22
# 19 19 26
# pos_tag, len of sent: 26 27
# 16 16 21
# pos_tag, len of sent: 21 21
# 20 20 23
# pos_tag, len of sent: 23 26
# 26 26 20
# pos_tag, len of sent: 20 24
# 28 28 28
# pos_tag, len of sent: 28 51
# 22 22 32
# pos_tag, len of sent: 32 33
# 15 15 15
# pos_tag, len of sent: 15 15
# 24 24 32
# pos_tag, len of sent: 32 36
# 26 26 30
# pos_tag, len of sent: 30 31
# 20 20 21
# pos_tag, len of sent: 21 33
# 20 20 26
# pos_tag, len of sent: 26 26
# 21 21 26
# pos_tag, len of sent: 26 43
# 21 21 18
# pos_tag, len of sent: 18 15
# 13 13 21
# pos_tag, len of sent: 21 21
# 19 19 20
# pos_tag, len of sent: 20 21
# 6 6 7
# pos_tag, len of sent: 7 7
# 18 18 24
# pos_tag, len of sent: 24 24
# 17 17 17
# pos_tag, len of sent: 17 17
# 12 12 15
# pos_tag, len of sent: 15 18
# 11 11 14
# pos_tag, len of sent: 14 14
# 6 6 11
# pos_tag, len of sent: 11 11
# 12 12 18
# pos_tag, len of sent: 18 18
# 26 26 32
# pos_tag, len of sent: 32 40
# 18 18 23
# pos_tag, len of sent: 23 27
# 12 12 15
# pos_tag, len of sent: 15 15
# 20 20 26
# pos_tag, len of sent: 26 35
# 10 10 15
# pos_tag, len of sent: 15 17
# 22 22 30
# pos_tag, len of sent: 30 34
# 29 29 34
# pos_tag, len of sent: 34 38
# 20 20 27
# pos_tag, len of sent: 27 27
# 5 5 9
# pos_tag, len of sent: 9 9
# 6 6 7
# pos_tag, len of sent: 7 7
# 22 22 29
# pos_tag, len of sent: 29 30
# 17 17 17
# pos_tag, len of sent: 17 17
# 5 5 6
# pos_tag, len of sent: 6 8
# 4 4 5
# pos_tag, len of sent: 5 5
# 20 20 15
# pos_tag, len of sent: 15 17
# 14 14 16
# pos_tag, len of sent: 16 16
# 19 19 23
# pos_tag, len of sent: 23 42
# 10 10 11
# pos_tag, len of sent: 11 16
# 16 16 23
# pos_tag, len of sent: 23 24
# 18 18 19
# pos_tag, len of sent: 19 25
# 21 21 26
# pos_tag, len of sent: 26 27
# 20 20 19
# pos_tag, len of sent: 19 35
# 21 21 20
# pos_tag, len of sent: 20 20
# 33 33 36
# pos_tag, len of sent: 36 40
# 15 15 20
# pos_tag, len of sent: 20 21
# 15 15 19
# pos_tag, len of sent: 19 19
# 21 21 28
# pos_tag, len of sent: 28 29
# 17 17 30
# pos_tag, len of sent: 30 25
# 29 29 27
# pos_tag, len of sent: 27 29
# 6 6 7
# pos_tag, len of sent: 7 6
# 27 27 39
# pos_tag, len of sent: 39 54
# 15 15 21
# pos_tag, len of sent: 21 21
# 29 29 36
# pos_tag, len of sent: 36 32
# 19 19 25
# pos_tag, len of sent: 25 48
# 17 17 17
# pos_tag, len of sent: 17 17
# 19 19 15
# pos_tag, len of sent: 15 37
# 12 12 19
# pos_tag, len of sent: 19 19
# 4 4 5
# pos_tag, len of sent: 5 5
# 18 18 19
# pos_tag, len of sent: 19 19
# 17 17 22
# pos_tag, len of sent: 22 22
# 13 13 16
# pos_tag, len of sent: 16 16
# 11 11 9
# pos_tag, len of sent: 9 10
# 16 16 21
# pos_tag, len of sent: 21 21
# 6 6 10
# pos_tag, len of sent: 10 10
# 7 7 10
# pos_tag, len of sent: 10 10
# 19 19 24
# pos_tag, len of sent: 24 23
# 34 34 29
# pos_tag, len of sent: 29 39
# 16 16 30
# pos_tag, len of sent: 30 30
# 19 19 22
# pos_tag, len of sent: 22 21
# 23 23 22
# pos_tag, len of sent: 22 24
# 31 31 29
# pos_tag, len of sent: 29 43
# 27 27 22
# pos_tag, len of sent: 22 15
# 27 27 27
# pos_tag, len of sent: 27 42
# 29 29 31
# pos_tag, len of sent: 31 33
# 9 9 11
# pos_tag, len of sent: 11 11
# 18 18 25
# pos_tag, len of sent: 25 42
# 21 21 25
# pos_tag, len of sent: 25 35
# 18 18 23
# pos_tag, len of sent: 23 28
# 7 7 8
# pos_tag, len of sent: 8 8
# 25 25 20
# pos_tag, len of sent: 20 43
# 20 20 26
# pos_tag, len of sent: 26 28
# 25 25 22
# pos_tag, len of sent: 22 25
# 29 29 43
# pos_tag, len of sent: 43 43
# 18 18 21
# pos_tag, len of sent: 21 21
# 30 30 29
# pos_tag, len of sent: 29 57
# 20 20 25
# pos_tag, len of sent: 25 45
# 4 4 5
# pos_tag, len of sent: 5 5
# 22 22 24
# pos_tag, len of sent: 24 39
# 19 19 22
# pos_tag, len of sent: 22 22
# 15 15 24
# pos_tag, len of sent: 24 17
# 15 15 21
# pos_tag, len of sent: 21 21
# 9 9 17
# pos_tag, len of sent: 17 17
# 14 14 17
# pos_tag, len of sent: 17 17
# 9 9 14
# pos_tag, len of sent: 14 14
# 21 21 26
# pos_tag, len of sent: 26 46
# 9 9 14
# pos_tag, len of sent: 14 14
# 24 24 22
# pos_tag, len of sent: 22 29
# 27 27 36
# pos_tag, len of sent: 36 44
# 22 22 31
# pos_tag, len of sent: 31 32
# 11 11 16
# pos_tag, len of sent: 16 16
# 1 1 2
# pos_tag, len of sent: 2 2
# 4 4 4
# pos_tag, len of sent: 4 3
# 10 10 23
# pos_tag, len of sent: 23 24
# 13 13 15
# pos_tag, len of sent: 15 15
# 9 9 18
# pos_tag, len of sent: 18 18
# 11 11 27
# pos_tag, len of sent: 27 26
# 8 8 13
# pos_tag, len of sent: 13 13
# 20 20 27
# pos_tag, len of sent: 27 28
# 7 7 12
# pos_tag, len of sent: 12 12
# 21 21 28
# pos_tag, len of sent: 28 28
# 10 10 20
# pos_tag, len of sent: 20 20
# 17 17 25
# pos_tag, len of sent: 25 54
# 13 13 16
# pos_tag, len of sent: 16 16
# 16 16 27
# pos_tag, len of sent: 27 27
# 17 17 25
# pos_tag, len of sent: 25 29
# 17 17 25
# pos_tag, len of sent: 25 36
# 23 23 22
# pos_tag, len of sent: 22 23
# 16 16 16
# pos_tag, len of sent: 16 16
# 25 25 24
# pos_tag, len of sent: 24 29
# 24 24 22
# pos_tag, len of sent: 22 27
# 16 16 21
# pos_tag, len of sent: 21 22
# 18 18 22
# pos_tag, len of sent: 22 22
# 21 21 23
# pos_tag, len of sent: 23 27
# 15 15 20
# pos_tag, len of sent: 20 20
# 24 24 29
# pos_tag, len of sent: 29 26
# 24 24 33
# pos_tag, len of sent: 33 39
# 20 20 30
# pos_tag, len of sent: 30 34
# 17 17 18
# pos_tag, len of sent: 18 18
# 13 13 14
# pos_tag, len of sent: 14 14
# 19 19 24
# pos_tag, len of sent: 24 24
# 17 17 32
# pos_tag, len of sent: 32 42
# 12 12 18
# pos_tag, len of sent: 18 18
# 11 11 20
# pos_tag, len of sent: 20 22
# 42 42 31
# pos_tag, len of sent: 31 30
# 24 24 30
# pos_tag, len of sent: 30 31
# 28 28 24
# pos_tag, len of sent: 24 33
# 24 24 29
# pos_tag, len of sent: 29 33
# 18 18 16
# pos_tag, len of sent: 16 16
# 15 15 24
# pos_tag, len of sent: 24 24
# 28 28 39
# pos_tag, len of sent: 39 65
# 30 30 36
# pos_tag, len of sent: 36 32
# 9 9 14
# pos_tag, len of sent: 14 14
# 12 12 16
# pos_tag, len of sent: 16 15
# 20 20 30
# pos_tag, len of sent: 30 32
# 17 17 27
# pos_tag, len of sent: 27 27
# 26 26 25
# pos_tag, len of sent: 25 31
# 9 9 19
# pos_tag, len of sent: 19 20
# 22 22 25
# pos_tag, len of sent: 25 30
# 28 28 22
# pos_tag, len of sent: 22 47
# 8 8 12
# pos_tag, len of sent: 12 12
# 17 17 16
# pos_tag, len of sent: 16 16
# 11 11 19
# pos_tag, len of sent: 19 19
# 23 23 30
# pos_tag, len of sent: 30 55
# 13 13 24
# pos_tag, len of sent: 24 24
# 17 17 22
# pos_tag, len of sent: 22 42
# 16 16 16
# pos_tag, len of sent: 16 26
# 25 25 27
# pos_tag, len of sent: 27 36
# 20 20 29
# pos_tag, len of sent: 29 29
# 11 11 14
# pos_tag, len of sent: 14 14
# 44 44 54
# pos_tag, len of sent: 54 33
# 29 29 34
# pos_tag, len of sent: 34 46
# 16 16 23
# pos_tag, len of sent: 23 23
# 33 33 38
# pos_tag, len of sent: 38 29
# 29 29 31
# pos_tag, len of sent: 31 32
# 8 8 10
# pos_tag, len of sent: 10 10
# 16 16 23
# pos_tag, len of sent: 23 23
# 20 20 22
# pos_tag, len of sent: 22 22
# 23 23 30
# pos_tag, len of sent: 30 35
# 6 6 7
# pos_tag, len of sent: 7 7
# 22 22 31
# pos_tag, len of sent: 31 32
# 31 31 29
# pos_tag, len of sent: 29 35
# 13 13 17
# pos_tag, len of sent: 17 17
# 31 31 30
# pos_tag, len of sent: 30 36
# 12 12 18
# pos_tag, len of sent: 18 17
# 23 23 27
# pos_tag, len of sent: 27 27
# 21 21 25
# pos_tag, len of sent: 25 26
# 10 10 14
# pos_tag, len of sent: 14 14
# 5 5 6
# pos_tag, len of sent: 6 6
# 13 13 17
# pos_tag, len of sent: 17 17
# 24 24 24
# pos_tag, len of sent: 24 30
# 22 22 23
# pos_tag, len of sent: 23 24
# 16 16 23
# pos_tag, len of sent: 23 23
# 5 5 6
# pos_tag, len of sent: 6 6
# 15 15 23
# pos_tag, len of sent: 23 23
# 12 12 14
# pos_tag, len of sent: 14 14
# 17 17 21
# pos_tag, len of sent: 21 21
# 19 19 21
# pos_tag, len of sent: 21 25
# 10 10 12
# pos_tag, len of sent: 12 12
# 20 20 24
# pos_tag, len of sent: 24 25
# 17 17 25
# pos_tag, len of sent: 25 26
# 11 11 12
# pos_tag, len of sent: 12 12
# 20 20 22
# pos_tag, len of sent: 22 22
# 22 22 27
# pos_tag, len of sent: 27 28
# 7 7 11
# pos_tag, len of sent: 11 11
# 26 26 26
# pos_tag, len of sent: 26 26
# 4 4 4
# pos_tag, len of sent: 4 4
# 4 4 4
# pos_tag, len of sent: 4 4
# 4 4 5
# pos_tag, len of sent: 5 5
# 18 18 27
# pos_tag, len of sent: 27 27
# 21 21 16
# pos_tag, len of sent: 16 37
# 14 14 18
# pos_tag, len of sent: 18 18
# 17 17 21
# pos_tag, len of sent: 21 28
# 16 16 25
# pos_tag, len of sent: 25 36
# 33 33 30
# pos_tag, len of sent: 30 36
# 25 25 27
# pos_tag, len of sent: 27 28
# 21 21 21
# pos_tag, len of sent: 21 37
# 14 14 19
# pos_tag, len of sent: 19 19
# 19 19 24
# pos_tag, len of sent: 24 24
# 23 23 26
# pos_tag, len of sent: 26 45
# 13 13 18
# pos_tag, len of sent: 18 12
# 13 13 19
# pos_tag, len of sent: 19 19
# 17 17 20
# pos_tag, len of sent: 20 28
# 24 24 24
# pos_tag, len of sent: 24 40
# 7 7 10
# pos_tag, len of sent: 10 10
# 25 25 36
# pos_tag, len of sent: 36 38
# 8 8 9
# pos_tag, len of sent: 9 9
# 33 33 28
# pos_tag, len of sent: 28 20
# 23 23 24
# pos_tag, len of sent: 24 34
# 12 12 18
# pos_tag, len of sent: 18 18
# 26 26 24
# pos_tag, len of sent: 24 31
# 10 10 17
# pos_tag, len of sent: 17 18
# 17 17 24
# pos_tag, len of sent: 24 24
# 20 20 23
# pos_tag, len of sent: 23 24
# 9 9 13
# pos_tag, len of sent: 13 13
# 26 26 30
# pos_tag, len of sent: 30 49
# 21 21 25
# pos_tag, len of sent: 25 26
# 17 17 22
# pos_tag, len of sent: 22 22
# 13 13 18
# pos_tag, len of sent: 18 18
# 9 9 11
# pos_tag, len of sent: 11 11
# 10 10 10
# pos_tag, len of sent: 10 10
# 23 23 22
# pos_tag, len of sent: 22 29
# 25 25 29
# pos_tag, len of sent: 29 34
# 19 19 24
# pos_tag, len of sent: 24 25
# 17 17 22
# pos_tag, len of sent: 22 22
# 12 12 19
# pos_tag, len of sent: 19 19
# 4 4 7
# pos_tag, len of sent: 7 7
# 14 14 15
# pos_tag, len of sent: 15 14
# 16 16 23
# pos_tag, len of sent: 23 23
# 14 14 21
# pos_tag, len of sent: 21 21
# 6 6 7
# pos_tag, len of sent: 7 7
# 23 23 24
# pos_tag, len of sent: 24 27
# 21 21 24
# pos_tag, len of sent: 24 25
# 20 20 28
# pos_tag, len of sent: 28 29
# 22 22 32
# pos_tag, len of sent: 32 33
# 11 11 14
# pos_tag, len of sent: 14 14
# 18 18 19
# pos_tag, len of sent: 19 45
# 26 26 30
# pos_tag, len of sent: 30 31
# 28 28 46
# pos_tag, len of sent: 46 50
# 9 9 11
# pos_tag, len of sent: 11 11
# 38 38 44
# pos_tag, len of sent: 44 39
# 23 23 32
# pos_tag, len of sent: 32 32
# 19 19 19
# pos_tag, len of sent: 19 19
# 7 7 9
# pos_tag, len of sent: 9 9
# 20 20 24
# pos_tag, len of sent: 24 25
# 16 16 20
# pos_tag, len of sent: 20 20
# 28 28 28
# pos_tag, len of sent: 28 34
# 21 21 25
# pos_tag, len of sent: 25 26
# 10 10 16
# pos_tag, len of sent: 16 16
# 17 17 29
# pos_tag, len of sent: 29 29
# 7 7 7
# pos_tag, len of sent: 7 7
# 22 22 25
# pos_tag, len of sent: 25 39
# 17 17 23
# pos_tag, len of sent: 23 23
# 27 27 26
# pos_tag, len of sent: 26 33
# 11 11 15
# pos_tag, len of sent: 15 15
# 20 20 30
# pos_tag, len of sent: 30 30
# 7 7 6
# pos_tag, len of sent: 6 6
# 10 10 15
# pos_tag, len of sent: 15 15
# 20 20 25
# pos_tag, len of sent: 25 26
# 15 15 17
# pos_tag, len of sent: 17 17
# 12 12 16
# pos_tag, len of sent: 16 16
# 20 20 25
# pos_tag, len of sent: 25 27
# 20 20 29
# pos_tag, len of sent: 29 44
# 22 22 28
# pos_tag, len of sent: 28 46
# 35 35 40
# pos_tag, len of sent: 40 38
# 20 20 31
# pos_tag, len of sent: 31 31
# 23 23 24
# pos_tag, len of sent: 24 25
# 7 7 12
# pos_tag, len of sent: 12 12
# 17 17 28
# pos_tag, len of sent: 28 28
# 22 22 31
# pos_tag, len of sent: 31 55
# 11 11 12
# pos_tag, len of sent: 12 12
# 21 21 33
# pos_tag, len of sent: 33 34
# 2 2 4
# pos_tag, len of sent: 4 4
# 12 12 20
# pos_tag, len of sent: 20 20
# 27 27 31
# pos_tag, len of sent: 31 36
# 27 27 35
# pos_tag, len of sent: 35 36
# 16 16 36
# pos_tag, len of sent: 36 4
# 18 18 24
# pos_tag, len of sent: 24 24
# 24 24 30
# pos_tag, len of sent: 30 31
# 27 27 27
# pos_tag, len of sent: 27 28
# 23 23 67
# pos_tag, len of sent: 67 6
# 12 12 18
# pos_tag, len of sent: 18 18
# 16 16 25
# pos_tag, len of sent: 25 38
# 23 23 24
# pos_tag, len of sent: 24 36
# 16 16 48
# pos_tag, len of sent: 48 6
# 10 10 16
# pos_tag, len of sent: 16 16
# 11 11 17
# pos_tag, len of sent: 17 17
# 5 5 7
# pos_tag, len of sent: 7 7
# 16 16 48
# pos_tag, len of sent: 48 6
# 10 10 15
# pos_tag, len of sent: 15 15
# 19 19 25
# pos_tag, len of sent: 25 36
# 8 8 11
# pos_tag, len of sent: 11 11
# 19 19 26
# pos_tag, len of sent: 26 26
# 9 9 12
# pos_tag, len of sent: 12 12
# 13 13 23
# pos_tag, len of sent: 23 23
# 28 28 30
# pos_tag, len of sent: 30 37
# 13 13 15
# pos_tag, len of sent: 15 15
# 9 9 13
# pos_tag, len of sent: 13 13
# 2416 2416

# %%
# write the gold file of test data set for EVALB
with open('parsed_test.txt', 'a') as f_write:
    for sent in reader_test.parsed_sents():
        f_write.write(sent.__str__().replace('\n', ''))
        f_write.write('\n')

# %%
i = 0
f_read = open('./output/output_test_uni', 'r')
with open('evalb_output_test_uni.txt' ,'a') as f_write:
    for sent in f_read:
        f_write.write(post_process(sent.split(), reader_test.sents()[i]))
        f_write.write('\n')
        i += 1
f_read.close()
print(i, len(reader_test.sents()))
# Out:
# 6 6 8
# pos_tag, len of sent: 8 8
# 21 21 26
# pos_tag, len of sent: 26 41
# 18 18 26
# pos_tag, len of sent: 26 36
# 20 20 28
# pos_tag, len of sent: 28 37
# 24 24 25
# pos_tag, len of sent: 25 31
# 12 12 17
# pos_tag, len of sent: 17 17
# 15 15 29
# pos_tag, len of sent: 29 31
# 5 5 6
# pos_tag, len of sent: 6 6
# 4 4 7
# pos_tag, len of sent: 7 7
# 18 18 23
# pos_tag, len of sent: 23 38
# 23 23 20
# pos_tag, len of sent: 20 30
# 13 13 17
# pos_tag, len of sent: 17 17
# 21 21 21
# pos_tag, len of sent: 21 18
# 17 17 27
# pos_tag, len of sent: 27 28
# 16 16 23
# pos_tag, len of sent: 23 43
# 11 11 15
# pos_tag, len of sent: 15 15
# 12 12 14
# pos_tag, len of sent: 14 14
# 5 5 8
# pos_tag, len of sent: 8 8
# 18 18 23
# pos_tag, len of sent: 23 24
# 17 17 27
# pos_tag, len of sent: 27 33
# 6 6 9
# pos_tag, len of sent: 9 9
# 23 23 24
# pos_tag, len of sent: 24 39
# 16 16 25
# pos_tag, len of sent: 25 28
# 13 13 24
# pos_tag, len of sent: 24 24
# 19 19 25
# pos_tag, len of sent: 25 29
# 13 13 13
# pos_tag, len of sent: 13 15
# 20 20 25
# pos_tag, len of sent: 25 28
# 14 14 22
# pos_tag, len of sent: 22 22
# 8 8 12
# pos_tag, len of sent: 12 12
# 3 3 4
# pos_tag, len of sent: 4 4
# 14 14 19
# pos_tag, len of sent: 19 24
# 21 21 21
# pos_tag, len of sent: 21 52
# 4 4 5
# pos_tag, len of sent: 5 5
# 19 19 25
# pos_tag, len of sent: 25 26
# 20 20 20
# pos_tag, len of sent: 20 31
# 25 25 22
# pos_tag, len of sent: 22 27
# 10 10 17
# pos_tag, len of sent: 17 17
# 13 13 18
# pos_tag, len of sent: 18 18
# 14 14 22
# pos_tag, len of sent: 22 38
# 15 15 23
# pos_tag, len of sent: 23 23
# 20 20 20
# pos_tag, len of sent: 20 35
# 9 9 15
# pos_tag, len of sent: 15 15
# 25 25 23
# pos_tag, len of sent: 23 39
# 8 8 13
# pos_tag, len of sent: 13 13
# 9 9 13
# pos_tag, len of sent: 13 13
# 18 18 25
# pos_tag, len of sent: 25 38
# 19 19 28
# pos_tag, len of sent: 28 31
# 21 21 20
# pos_tag, len of sent: 20 35
# 22 22 20
# pos_tag, len of sent: 20 22
# 6 6 6
# pos_tag, len of sent: 6 6
# 9 9 15
# pos_tag, len of sent: 15 15
# 13 13 19
# pos_tag, len of sent: 19 22
# 22 22 25
# pos_tag, len of sent: 25 28
# 9 9 16
# pos_tag, len of sent: 16 17
# 24 24 22
# pos_tag, len of sent: 22 28
# 16 16 28
# pos_tag, len of sent: 28 48
# 23 23 24
# pos_tag, len of sent: 24 29
# 20 20 28
# pos_tag, len of sent: 28 30
# 6 6 8
# pos_tag, len of sent: 8 8
# 20 20 23
# pos_tag, len of sent: 23 24
# 16 16 25
# pos_tag, len of sent: 25 25
# 18 18 20
# pos_tag, len of sent: 20 19
# 17 17 20
# pos_tag, len of sent: 20 20
# 21 21 21
# pos_tag, len of sent: 21 28
# 22 22 25
# pos_tag, len of sent: 25 36
# 15 15 19
# pos_tag, len of sent: 19 19
# 29 29 26
# pos_tag, len of sent: 26 32
# 15 15 29
# pos_tag, len of sent: 29 31
# 21 21 25
# pos_tag, len of sent: 25 34
# 20 20 26
# pos_tag, len of sent: 26 39
# 13 13 14
# pos_tag, len of sent: 14 14
# 12 12 15
# pos_tag, len of sent: 15 15
# 15 15 28
# pos_tag, len of sent: 28 23
# 22 22 24
# pos_tag, len of sent: 24 31
# 4 4 6
# pos_tag, len of sent: 6 6
# 18 18 22
# pos_tag, len of sent: 22 28
# 14 14 16
# pos_tag, len of sent: 16 16
# 29 29 25
# pos_tag, len of sent: 25 38
# 12 12 13
# pos_tag, len of sent: 13 15
# 20 20 24
# pos_tag, len of sent: 24 26
# 9 9 17
# pos_tag, len of sent: 17 17
# 11 11 16
# pos_tag, len of sent: 16 16
# 20 20 20
# pos_tag, len of sent: 20 29
# 15 15 20
# pos_tag, len of sent: 20 22
# 33 33 37
# pos_tag, len of sent: 37 43
# 22 22 25
# pos_tag, len of sent: 25 26
# 18 18 23
# pos_tag, len of sent: 23 27
# 16 16 26
# pos_tag, len of sent: 26 30
# 14 14 11
# pos_tag, len of sent: 11 11
# 1 1 2
# pos_tag, len of sent: 2 2
# 23 23 21
# pos_tag, len of sent: 21 22
# 26 26 26
# pos_tag, len of sent: 26 27
# 25 25 25
# pos_tag, len of sent: 25 38
# 15 15 23
# pos_tag, len of sent: 23 21
# 26 26 25
# pos_tag, len of sent: 25 34
# 21 21 30
# pos_tag, len of sent: 30 30
# 19 19 24
# pos_tag, len of sent: 24 33
# 24 24 25
# pos_tag, len of sent: 25 35
# 20 20 26
# pos_tag, len of sent: 26 37
# 8 8 10
# pos_tag, len of sent: 10 10
# 7 7 9
# pos_tag, len of sent: 9 9
# 20 20 23
# pos_tag, len of sent: 23 24
# 15 15 22
# pos_tag, len of sent: 22 22
# 22 22 25
# pos_tag, len of sent: 25 39
# 34 34 57
# pos_tag, len of sent: 57 29
# 17 17 29
# pos_tag, len of sent: 29 22
# 16 16 27
# pos_tag, len of sent: 27 37
# 20 20 23
# pos_tag, len of sent: 23 26
# 20 20 23
# pos_tag, len of sent: 23 57
# 20 20 24
# pos_tag, len of sent: 24 25
# 16 16 18
# pos_tag, len of sent: 18 35
# 7 7 11
# pos_tag, len of sent: 11 11
# 20 20 22
# pos_tag, len of sent: 22 51
# 23 23 23
# pos_tag, len of sent: 23 28
# 20 20 24
# pos_tag, len of sent: 24 29
# 18 18 31
# pos_tag, len of sent: 31 58
# 20 20 22
# pos_tag, len of sent: 22 27
# 15 15 19
# pos_tag, len of sent: 19 32
# 24 24 25
# pos_tag, len of sent: 25 28
# 11 11 15
# pos_tag, len of sent: 15 15
# 23 23 25
# pos_tag, len of sent: 25 24
# 19 19 17
# pos_tag, len of sent: 17 25
# 14 14 19
# pos_tag, len of sent: 19 19
# 20 20 28
# pos_tag, len of sent: 28 38
# 11 11 15
# pos_tag, len of sent: 15 15
# 13 13 17
# pos_tag, len of sent: 17 17
# 25 25 26
# pos_tag, len of sent: 26 35
# 9 9 16
# pos_tag, len of sent: 16 16
# 10 10 12
# pos_tag, len of sent: 12 12
# 12 12 21
# pos_tag, len of sent: 21 21
# 21 21 25
# pos_tag, len of sent: 25 32
# 11 11 18
# pos_tag, len of sent: 18 18
# 14 14 20
# pos_tag, len of sent: 20 20
# 20 20 26
# pos_tag, len of sent: 26 35
# 17 17 19
# pos_tag, len of sent: 19 19
# 22 22 27
# pos_tag, len of sent: 27 29
# 17 17 25
# pos_tag, len of sent: 25 39
# 7 7 9
# pos_tag, len of sent: 9 9
# 4 4 6
# pos_tag, len of sent: 6 6
# 5 5 6
# pos_tag, len of sent: 6 6
# 9 9 14
# pos_tag, len of sent: 14 14
# 22 22 25
# pos_tag, len of sent: 25 26
# 17 17 21
# pos_tag, len of sent: 21 22
# 8 8 9
# pos_tag, len of sent: 9 9
# 16 16 17
# pos_tag, len of sent: 17 17
# 16 16 19
# pos_tag, len of sent: 19 19
# 18 18 31
# pos_tag, len of sent: 31 34
# 19 19 26
# pos_tag, len of sent: 26 34
# 24 24 25
# pos_tag, len of sent: 25 26
# 20 20 22
# pos_tag, len of sent: 22 32
# 7 7 11
# pos_tag, len of sent: 11 11
# 21 21 23
# pos_tag, len of sent: 23 28
# 16 16 20
# pos_tag, len of sent: 20 20
# 15 15 17
# pos_tag, len of sent: 17 17
# 16 16 24
# pos_tag, len of sent: 24 21
# 17 17 20
# pos_tag, len of sent: 20 20
# 15 15 22
# pos_tag, len of sent: 22 22
# 16 16 20
# pos_tag, len of sent: 20 31
# 17 17 16
# pos_tag, len of sent: 16 15
# 16 16 24
# pos_tag, len of sent: 24 28
# 22 22 24
# pos_tag, len of sent: 24 32
# 13 13 22
# pos_tag, len of sent: 22 22
# 18 18 23
# pos_tag, len of sent: 23 22
# 19 19 18
# pos_tag, len of sent: 18 32
# 11 11 17
# pos_tag, len of sent: 17 17
# 5 5 11
# pos_tag, len of sent: 11 11
# 8 8 9
# pos_tag, len of sent: 9 9
# 6 6 10
# pos_tag, len of sent: 10 10
# 16 16 21
# pos_tag, len of sent: 21 22
# 10 10 13
# pos_tag, len of sent: 13 13
# 7 7 9
# pos_tag, len of sent: 9 9
# 14 14 20
# pos_tag, len of sent: 20 21
# 15 15 18
# pos_tag, len of sent: 18 18
# 12 12 16
# pos_tag, len of sent: 16 16
# 18 18 23
# pos_tag, len of sent: 23 30
# 21 21 21
# pos_tag, len of sent: 21 23
# 15 15 20
# pos_tag, len of sent: 20 20
# 17 17 21
# pos_tag, len of sent: 21 34
# 7 7 10
# pos_tag, len of sent: 10 10
# 9 9 13
# pos_tag, len of sent: 13 13
# 24 24 25
# pos_tag, len of sent: 25 26
# 14 14 20
# pos_tag, len of sent: 20 20
# 20 20 26
# pos_tag, len of sent: 26 40
# 25 25 24
# pos_tag, len of sent: 24 33
# 8 8 13
# pos_tag, len of sent: 13 13
# 18 18 21
# pos_tag, len of sent: 21 21
# 20 20 20
# pos_tag, len of sent: 20 31
# 15 15 17
# pos_tag, len of sent: 17 18
# 16 16 21
# pos_tag, len of sent: 21 23
# 19 19 24
# pos_tag, len of sent: 24 28
# 17 17 25
# pos_tag, len of sent: 25 47
# 11 11 17
# pos_tag, len of sent: 17 16
# 25 25 25
# pos_tag, len of sent: 25 34
# 14 14 18
# pos_tag, len of sent: 18 18
# 24 24 24
# pos_tag, len of sent: 24 44
# 18 18 21
# pos_tag, len of sent: 21 44
# 20 20 24
# pos_tag, len of sent: 24 69
# 25 25 21
# pos_tag, len of sent: 21 61
# 13 13 13
# pos_tag, len of sent: 13 13
# 20 20 23
# pos_tag, len of sent: 23 24
# 10 10 12
# pos_tag, len of sent: 12 12
# 18 18 25
# pos_tag, len of sent: 25 40
# 23 23 29
# pos_tag, len of sent: 29 27
# 15 15 16
# pos_tag, len of sent: 16 16
# 18 18 22
# pos_tag, len of sent: 22 39
# 11 11 15
# pos_tag, len of sent: 15 15
# 22 22 29
# pos_tag, len of sent: 29 30
# 16 16 18
# pos_tag, len of sent: 18 37
# 23 23 25
# pos_tag, len of sent: 25 26
# 21 21 26
# pos_tag, len of sent: 26 25
# 20 20 21
# pos_tag, len of sent: 21 28
# 23 23 23
# pos_tag, len of sent: 23 24
# 20 20 15
# pos_tag, len of sent: 15 28
# 21 21 23
# pos_tag, len of sent: 23 41
# 21 21 36
# pos_tag, len of sent: 36 43
# 22 22 25
# pos_tag, len of sent: 25 32
# 18 18 19
# pos_tag, len of sent: 19 19
# 22 22 19
# pos_tag, len of sent: 19 42
# 8 8 14
# pos_tag, len of sent: 14 14
# 19 19 21
# pos_tag, len of sent: 21 33
# 20 20 23
# pos_tag, len of sent: 23 47
# 17 17 24
# pos_tag, len of sent: 24 25
# 28 28 28
# pos_tag, len of sent: 28 42
# 17 17 19
# pos_tag, len of sent: 19 19
# 7 7 12
# pos_tag, len of sent: 12 12
# 19 19 24
# pos_tag, len of sent: 24 41
# 21 21 26
# pos_tag, len of sent: 26 33
# 20 20 23
# pos_tag, len of sent: 23 26
# 16 16 24
# pos_tag, len of sent: 24 25
# 11 11 14
# pos_tag, len of sent: 14 14
# 16 16 18
# pos_tag, len of sent: 18 19
# 16 16 22
# pos_tag, len of sent: 22 51
# 4 4 5
# pos_tag, len of sent: 5 5
# 21 21 19
# pos_tag, len of sent: 19 33
# 15 15 26
# pos_tag, len of sent: 26 22
# 7 7 11
# pos_tag, len of sent: 11 11
# 7 7 8
# pos_tag, len of sent: 8 8
# 20 20 28
# pos_tag, len of sent: 28 32
# 5 5 7
# pos_tag, len of sent: 7 7
# 15 15 20
# pos_tag, len of sent: 20 39
# 19 19 29
# pos_tag, len of sent: 29 62
# 4 4 6
# pos_tag, len of sent: 6 6
# 11 11 14
# pos_tag, len of sent: 14 15
# 17 17 23
# pos_tag, len of sent: 23 26
# 17 17 22
# pos_tag, len of sent: 22 22
# 14 14 19
# pos_tag, len of sent: 19 19
# 24 24 22
# pos_tag, len of sent: 22 50
# 21 21 22
# pos_tag, len of sent: 22 35
# 21 21 25
# pos_tag, len of sent: 25 33
# 24 24 24
# pos_tag, len of sent: 24 32
# 23 23 31
# pos_tag, len of sent: 31 32
# 21 21 19
# pos_tag, len of sent: 19 37
# 21 21 23
# pos_tag, len of sent: 23 34
# 16 16 21
# pos_tag, len of sent: 21 21
# 20 20 33
# pos_tag, len of sent: 33 43
# 27 27 26
# pos_tag, len of sent: 26 39
# 22 22 30
# pos_tag, len of sent: 30 30
# 17 17 33
# pos_tag, len of sent: 33 39
# 21 21 20
# pos_tag, len of sent: 20 21
# 10 10 17
# pos_tag, len of sent: 17 16
# 8 8 14
# pos_tag, len of sent: 14 14
# 10 10 13
# pos_tag, len of sent: 13 13
# 22 22 21
# pos_tag, len of sent: 21 28
# 10 10 15
# pos_tag, len of sent: 15 15
# 14 14 23
# pos_tag, len of sent: 23 24
# 21 21 24
# pos_tag, len of sent: 24 29
# 22 22 32
# pos_tag, len of sent: 32 56
# 10 10 17
# pos_tag, len of sent: 17 17
# 18 18 16
# pos_tag, len of sent: 16 41
# 22 22 22
# pos_tag, len of sent: 22 54
# 26 26 23
# pos_tag, len of sent: 23 25
# 17 17 24
# pos_tag, len of sent: 24 41
# 6 6 10
# pos_tag, len of sent: 10 10
# 22 22 24
# pos_tag, len of sent: 24 41
# 23 23 22
# pos_tag, len of sent: 22 30
# 30 30 23
# pos_tag, len of sent: 23 37
# 18 18 20
# pos_tag, len of sent: 20 20
# 24 24 25
# pos_tag, len of sent: 25 33
# 14 14 20
# pos_tag, len of sent: 20 17
# 18 18 21
# pos_tag, len of sent: 21 26
# 7 7 11
# pos_tag, len of sent: 11 12
# 20 20 24
# pos_tag, len of sent: 24 44
# 18 18 25
# pos_tag, len of sent: 25 37
# 26 26 25
# pos_tag, len of sent: 25 26
# 19 19 21
# pos_tag, len of sent: 21 23
# 12 12 15
# pos_tag, len of sent: 15 15
# 21 21 22
# pos_tag, len of sent: 22 22
# 17 17 20
# pos_tag, len of sent: 20 21
# 9 9 12
# pos_tag, len of sent: 12 12
# 21 21 22
# pos_tag, len of sent: 22 26
# 18 18 25
# pos_tag, len of sent: 25 39
# 20 20 22
# pos_tag, len of sent: 22 48
# 20 20 23
# pos_tag, len of sent: 23 33
# 9 9 17
# pos_tag, len of sent: 17 17
# 13 13 24
# pos_tag, len of sent: 24 32
# 20 20 22
# pos_tag, len of sent: 22 33
# 14 14 21
# pos_tag, len of sent: 21 22
# 20 20 21
# pos_tag, len of sent: 21 28
# 14 14 21
# pos_tag, len of sent: 21 21
# 15 15 20
# pos_tag, len of sent: 20 19
# 15 15 22
# pos_tag, len of sent: 22 22
# 17 17 17
# pos_tag, len of sent: 17 17
# 21 21 21
# pos_tag, len of sent: 21 35
# 21 21 21
# pos_tag, len of sent: 21 33
# 8 8 12
# pos_tag, len of sent: 12 12
# 10 10 9
# pos_tag, len of sent: 9 9
# 19 19 21
# pos_tag, len of sent: 21 21
# 19 19 21
# pos_tag, len of sent: 21 22
# 13 13 20
# pos_tag, len of sent: 20 20
# 17 17 16
# pos_tag, len of sent: 16 24
# 4 4 4
# pos_tag, len of sent: 4 4
# 4 4 5
# pos_tag, len of sent: 5 5
# 24 24 22
# pos_tag, len of sent: 22 23
# 11 11 14
# pos_tag, len of sent: 14 14
# 15 15 22
# pos_tag, len of sent: 22 22
# 21 21 28
# pos_tag, len of sent: 28 46
# 21 21 21
# pos_tag, len of sent: 21 34
# 12 12 15
# pos_tag, len of sent: 15 15
# 19 19 24
# pos_tag, len of sent: 24 52
# 21 21 22
# pos_tag, len of sent: 22 23
# 18 18 18
# pos_tag, len of sent: 18 18
# 16 16 27
# pos_tag, len of sent: 27 27
# 16 16 17
# pos_tag, len of sent: 17 18
# 30 30 31
# pos_tag, len of sent: 31 29
# 4 4 6
# pos_tag, len of sent: 6 6
# 5 5 9
# pos_tag, len of sent: 9 10
# 12 12 18
# pos_tag, len of sent: 18 18
# 11 11 18
# pos_tag, len of sent: 18 20
# 11 11 17
# pos_tag, len of sent: 17 17
# 20 20 17
# pos_tag, len of sent: 17 28
# 18 18 21
# pos_tag, len of sent: 21 21
# 21 21 22
# pos_tag, len of sent: 22 46
# 9 9 11
# pos_tag, len of sent: 11 11
# 20 20 19
# pos_tag, len of sent: 19 26
# 16 16 24
# pos_tag, len of sent: 24 24
# 6 6 7
# pos_tag, len of sent: 7 7
# 19 19 24
# pos_tag, len of sent: 24 26
# 13 13 18
# pos_tag, len of sent: 18 18
# 13 13 17
# pos_tag, len of sent: 17 17
# 24 24 33
# pos_tag, len of sent: 33 32
# 7 7 10
# pos_tag, len of sent: 10 10
# 10 10 16
# pos_tag, len of sent: 16 13
# 14 14 13
# pos_tag, len of sent: 13 15
# 10 10 13
# pos_tag, len of sent: 13 13
# 21 21 23
# pos_tag, len of sent: 23 24
# 23 23 23
# pos_tag, len of sent: 23 39
# 24 24 23
# pos_tag, len of sent: 23 34
# 19 19 31
# pos_tag, len of sent: 31 58
# 14 14 22
# pos_tag, len of sent: 22 23
# 20 20 21
# pos_tag, len of sent: 21 48
# 23 23 31
# pos_tag, len of sent: 31 34
# 19 19 23
# pos_tag, len of sent: 23 30
# 23 23 24
# pos_tag, len of sent: 24 34
# 22 22 22
# pos_tag, len of sent: 22 32
# 22 22 24
# pos_tag, len of sent: 24 27
# 26 26 29
# pos_tag, len of sent: 29 37
# 19 19 23
# pos_tag, len of sent: 23 23
# 13 13 19
# pos_tag, len of sent: 19 19
# 21 21 23
# pos_tag, len of sent: 23 34
# 17 17 29
# pos_tag, len of sent: 29 30
# 24 24 27
# pos_tag, len of sent: 27 39
# 20 20 26
# pos_tag, len of sent: 26 27
# 21 21 22
# pos_tag, len of sent: 22 25
# 16 16 20
# pos_tag, len of sent: 20 40
# 17 17 24
# pos_tag, len of sent: 24 27
# 21 21 21
# pos_tag, len of sent: 21 21
# 19 19 26
# pos_tag, len of sent: 26 27
# 29 29 28
# pos_tag, len of sent: 28 41
# 14 14 23
# pos_tag, len of sent: 23 23
# 22 22 21
# pos_tag, len of sent: 21 41
# 21 21 23
# pos_tag, len of sent: 23 26
# 19 19 26
# pos_tag, len of sent: 26 23
# 23 23 23
# pos_tag, len of sent: 23 24
# 12 12 23
# pos_tag, len of sent: 23 23
# 21 21 25
# pos_tag, len of sent: 25 34
# 25 25 21
# pos_tag, len of sent: 21 24
# 19 19 25
# pos_tag, len of sent: 25 28
# 10 10 13
# pos_tag, len of sent: 13 13
# 16 16 20
# pos_tag, len of sent: 20 20
# 21 21 30
# pos_tag, len of sent: 30 28
# 12 12 18
# pos_tag, len of sent: 18 18
# 20 20 25
# pos_tag, len of sent: 25 26
# 19 19 25
# pos_tag, len of sent: 25 26
# 25 25 27
# pos_tag, len of sent: 27 33
# 19 19 27
# pos_tag, len of sent: 27 49
# 14 14 26
# pos_tag, len of sent: 26 31
# 15 15 26
# pos_tag, len of sent: 26 30
# 5 5 7
# pos_tag, len of sent: 7 7
# 19 19 22
# pos_tag, len of sent: 22 37
# 19 19 23
# pos_tag, len of sent: 23 28
# 20 20 18
# pos_tag, len of sent: 18 29
# 18 18 22
# pos_tag, len of sent: 22 21
# 23 23 26
# pos_tag, len of sent: 26 36
# 13 13 20
# pos_tag, len of sent: 20 20
# 18 18 23
# pos_tag, len of sent: 23 23
# 23 23 24
# pos_tag, len of sent: 24 30
# 19 19 18
# pos_tag, len of sent: 18 26
# 20 20 22
# pos_tag, len of sent: 22 35
# 16 16 25
# pos_tag, len of sent: 25 25
# 17 17 23
# pos_tag, len of sent: 23 29
# 27 27 25
# pos_tag, len of sent: 25 39
# 22 22 26
# pos_tag, len of sent: 26 27
# 27 27 28
# pos_tag, len of sent: 28 33
# 12 12 14
# pos_tag, len of sent: 14 14
# 21 21 22
# pos_tag, len of sent: 22 26
# 20 20 20
# pos_tag, len of sent: 20 21
# 18 18 24
# pos_tag, len of sent: 24 25
# 21 21 22
# pos_tag, len of sent: 22 36
# 18 18 20
# pos_tag, len of sent: 20 19
# 24 24 23
# pos_tag, len of sent: 23 36
# 9 9 12
# pos_tag, len of sent: 12 13
# 17 17 17
# pos_tag, len of sent: 17 17
# 7 7 8
# pos_tag, len of sent: 8 8
# 15 15 17
# pos_tag, len of sent: 17 17
# 25 25 27
# pos_tag, len of sent: 27 27
# 14 14 18
# pos_tag, len of sent: 18 19
# 22 22 28
# pos_tag, len of sent: 28 45
# 25 25 26
# pos_tag, len of sent: 26 38
# 26 26 23
# pos_tag, len of sent: 23 51
# 21 21 22
# pos_tag, len of sent: 22 26
# 18 18 24
# pos_tag, len of sent: 24 27
# 22 22 23
# pos_tag, len of sent: 23 31
# 28 28 24
# pos_tag, len of sent: 24 25
# 18 18 21
# pos_tag, len of sent: 21 21
# 22 22 28
# pos_tag, len of sent: 28 23
# 14 14 17
# pos_tag, len of sent: 17 16
# 23 23 24
# pos_tag, len of sent: 24 25
# 14 14 20
# pos_tag, len of sent: 20 20
# 20 20 18
# pos_tag, len of sent: 18 18
# 23 23 26
# pos_tag, len of sent: 26 33
# 21 21 21
# pos_tag, len of sent: 21 43
# 8 8 9
# pos_tag, len of sent: 9 9
# 15 15 18
# pos_tag, len of sent: 18 18
# 18 18 17
# pos_tag, len of sent: 17 20
# 15 15 27
# pos_tag, len of sent: 27 25
# 22 22 21
# pos_tag, len of sent: 21 22
# 20 20 25
# pos_tag, len of sent: 25 26
# 21 21 29
# pos_tag, len of sent: 29 30
# 19 19 23
# pos_tag, len of sent: 23 23
# 18 18 23
# pos_tag, len of sent: 23 24
# 21 21 23
# pos_tag, len of sent: 23 50
# 27 27 25
# pos_tag, len of sent: 25 36
# 14 14 14
# pos_tag, len of sent: 14 14
# 14 14 18
# pos_tag, len of sent: 18 19
# 11 11 9
# pos_tag, len of sent: 9 9
# 6 6 10
# pos_tag, len of sent: 10 10
# 19 19 20
# pos_tag, len of sent: 20 20
# 18 18 19
# pos_tag, len of sent: 19 25
# 19 19 18
# pos_tag, len of sent: 18 52
# 24 24 22
# pos_tag, len of sent: 22 31
# 16 16 21
# pos_tag, len of sent: 21 23
# 25 25 23
# pos_tag, len of sent: 23 24
# 5 5 7
# pos_tag, len of sent: 7 7
# 5 5 9
# pos_tag, len of sent: 9 9
# 12 12 15
# pos_tag, len of sent: 15 15
# 21 21 22
# pos_tag, len of sent: 22 51
# 12 12 13
# pos_tag, len of sent: 13 13
# 11 11 18
# pos_tag, len of sent: 18 18
# 24 24 27
# pos_tag, len of sent: 27 24
# 13 13 18
# pos_tag, len of sent: 18 19
# 17 17 22
# pos_tag, len of sent: 22 28
# 14 14 27
# pos_tag, len of sent: 27 23
# 20 20 21
# pos_tag, len of sent: 21 32
# 13 13 17
# pos_tag, len of sent: 17 17
# 18 18 22
# pos_tag, len of sent: 22 30
# 22 22 24
# pos_tag, len of sent: 24 26
# 9 9 12
# pos_tag, len of sent: 12 12
# 17 17 17
# pos_tag, len of sent: 17 17
# 22 22 24
# pos_tag, len of sent: 24 28
# 24 24 25
# pos_tag, len of sent: 25 27
# 22 22 20
# pos_tag, len of sent: 20 26
# 18 18 26
# pos_tag, len of sent: 26 26
# 6 6 10
# pos_tag, len of sent: 10 10
# 14 14 29
# pos_tag, len of sent: 29 28
# 16 16 24
# pos_tag, len of sent: 24 26
# 20 20 21
# pos_tag, len of sent: 21 22
# 18 18 22
# pos_tag, len of sent: 22 43
# 23 23 23
# pos_tag, len of sent: 23 31
# 24 24 28
# pos_tag, len of sent: 28 52
# 25 25 26
# pos_tag, len of sent: 26 23
# 10 10 12
# pos_tag, len of sent: 12 12
# 13 13 16
# pos_tag, len of sent: 16 16
# 12 12 23
# pos_tag, len of sent: 23 23
# 5 5 6
# pos_tag, len of sent: 6 6
# 19 19 19
# pos_tag, len of sent: 19 39
# 14 14 17
# pos_tag, len of sent: 17 17
# 7 7 10
# pos_tag, len of sent: 10 10
# 10 10 15
# pos_tag, len of sent: 15 15
# 22 22 25
# pos_tag, len of sent: 25 38
# 21 21 23
# pos_tag, len of sent: 23 36
# 25 25 27
# pos_tag, len of sent: 27 34
# 17 17 25
# pos_tag, len of sent: 25 23
# 6 6 8
# pos_tag, len of sent: 8 8
# 20 20 25
# pos_tag, len of sent: 25 26
# 14 14 22
# pos_tag, len of sent: 22 22
# 22 22 21
# pos_tag, len of sent: 21 26
# 12 12 14
# pos_tag, len of sent: 14 14
# 16 16 18
# pos_tag, len of sent: 18 18
# 7 7 11
# pos_tag, len of sent: 11 11
# 16 16 20
# pos_tag, len of sent: 20 20
# 5 5 5
# pos_tag, len of sent: 5 5
# 18 18 27
# pos_tag, len of sent: 27 23
# 7 7 7
# pos_tag, len of sent: 7 7
# 18 18 25
# pos_tag, len of sent: 25 35
# 24 24 21
# pos_tag, len of sent: 21 25
# 7 7 11
# pos_tag, len of sent: 11 11
# 16 16 19
# pos_tag, len of sent: 19 19
# 20 20 21
# pos_tag, len of sent: 21 34
# 8 8 15
# pos_tag, len of sent: 15 15
# 16 16 20
# pos_tag, len of sent: 20 20
# 18 18 22
# pos_tag, len of sent: 22 29
# 17 17 19
# pos_tag, len of sent: 19 19
# 15 15 22
# pos_tag, len of sent: 22 22
# 25 25 27
# pos_tag, len of sent: 27 32
# 16 16 18
# pos_tag, len of sent: 18 18
# 12 12 14
# pos_tag, len of sent: 14 18
# 4 4 6
# pos_tag, len of sent: 6 6
# 25 25 24
# pos_tag, len of sent: 24 30
# 10 10 14
# pos_tag, len of sent: 14 14
# 17 17 23
# pos_tag, len of sent: 23 24
# 15 15 22
# pos_tag, len of sent: 22 22
# 20 20 23
# pos_tag, len of sent: 23 25
# 18 18 25
# pos_tag, len of sent: 25 43
# 32 32 29
# pos_tag, len of sent: 29 45
# 20 20 26
# pos_tag, len of sent: 26 56
# 20 20 22
# pos_tag, len of sent: 22 23
# 26 26 27
# pos_tag, len of sent: 27 30
# 25 25 21
# pos_tag, len of sent: 21 42
# 27 27 33
# pos_tag, len of sent: 33 47
# 10 10 10
# pos_tag, len of sent: 10 10
# 14 14 18
# pos_tag, len of sent: 18 27
# 10 10 15
# pos_tag, len of sent: 15 15
# 13 13 19
# pos_tag, len of sent: 19 18
# 21 21 23
# pos_tag, len of sent: 23 24
# 22 22 23
# pos_tag, len of sent: 23 36
# 20 20 21
# pos_tag, len of sent: 21 32
# 15 15 21
# pos_tag, len of sent: 21 21
# 22 22 30
# pos_tag, len of sent: 30 38
# 25 25 28
# pos_tag, len of sent: 28 29
# 13 13 17
# pos_tag, len of sent: 17 17
# 19 19 20
# pos_tag, len of sent: 20 29
# 20 20 25
# pos_tag, len of sent: 25 26
# 20 20 21
# pos_tag, len of sent: 21 20
# 19 19 27
# pos_tag, len of sent: 27 49
# 25 25 29
# pos_tag, len of sent: 29 30
# 16 16 20
# pos_tag, len of sent: 20 20
# 23 23 24
# pos_tag, len of sent: 24 27
# 15 15 23
# pos_tag, len of sent: 23 33
# 21 21 21
# pos_tag, len of sent: 21 30
# 22 22 26
# pos_tag, len of sent: 26 40
# 23 23 24
# pos_tag, len of sent: 24 41
# 20 20 25
# pos_tag, len of sent: 25 51
# 24 24 26
# pos_tag, len of sent: 26 32
# 25 25 28
# pos_tag, len of sent: 28 39
# 19 19 21
# pos_tag, len of sent: 21 21
# 12 12 14
# pos_tag, len of sent: 14 17
# 14 14 19
# pos_tag, len of sent: 19 21
# 16 16 25
# pos_tag, len of sent: 25 23
# 6 6 8
# pos_tag, len of sent: 8 8
# 19 19 22
# pos_tag, len of sent: 22 40
# 30 30 32
# pos_tag, len of sent: 32 34
# 8 8 11
# pos_tag, len of sent: 11 11
# 25 25 30
# pos_tag, len of sent: 30 33
# 21 21 24
# pos_tag, len of sent: 24 47
# 22 22 36
# pos_tag, len of sent: 36 45
# 14 14 20
# pos_tag, len of sent: 20 20
# 16 16 17
# pos_tag, len of sent: 17 17
# 10 10 14
# pos_tag, len of sent: 14 14
# 10 10 14
# pos_tag, len of sent: 14 14
# 11 11 17
# pos_tag, len of sent: 17 14
# 13 13 14
# pos_tag, len of sent: 14 14
# 15 15 21
# pos_tag, len of sent: 21 21
# 26 26 19
# pos_tag, len of sent: 19 21
# 22 22 26
# pos_tag, len of sent: 26 37
# 21 21 24
# pos_tag, len of sent: 24 35
# 19 19 25
# pos_tag, len of sent: 25 21
# 19 19 24
# pos_tag, len of sent: 24 42
# 8 8 11
# pos_tag, len of sent: 11 11
# 10 10 12
# pos_tag, len of sent: 12 12
# 26 26 27
# pos_tag, len of sent: 27 43
# 13 13 18
# pos_tag, len of sent: 18 18
# 19 19 26
# pos_tag, len of sent: 26 30
# 23 23 26
# pos_tag, len of sent: 26 27
# 20 20 22
# pos_tag, len of sent: 22 23
# 17 17 22
# pos_tag, len of sent: 22 22
# 19 19 24
# pos_tag, len of sent: 24 35
# 21 21 22
# pos_tag, len of sent: 22 31
# 6 6 10
# pos_tag, len of sent: 10 25
# 23 23 23
# pos_tag, len of sent: 23 47
# 14 14 15
# pos_tag, len of sent: 15 15
# 18 18 24
# pos_tag, len of sent: 24 52
# 15 15 20
# pos_tag, len of sent: 20 20
# 17 17 18
# pos_tag, len of sent: 18 18
# 19 19 25
# pos_tag, len of sent: 25 38
# 21 21 33
# pos_tag, len of sent: 33 32
# 7 7 10
# pos_tag, len of sent: 10 10
# 23 23 24
# pos_tag, len of sent: 24 25
# 22 22 24
# pos_tag, len of sent: 24 32
# 18 18 21
# pos_tag, len of sent: 21 23
# 19 19 22
# pos_tag, len of sent: 22 39
# 18 18 25
# pos_tag, len of sent: 25 37
# 13 13 15
# pos_tag, len of sent: 15 15
# 20 20 20
# pos_tag, len of sent: 20 30
# 24 24 20
# pos_tag, len of sent: 20 21
# 24 24 20
# pos_tag, len of sent: 20 30
# 19 19 23
# pos_tag, len of sent: 23 24
# 12 12 18
# pos_tag, len of sent: 18 18
# 18 18 22
# pos_tag, len of sent: 22 44
# 1 1 1
# pos_tag, len of sent: 1 1
# 19 19 23
# pos_tag, len of sent: 23 31
# 20 20 23
# pos_tag, len of sent: 23 34
# 9 9 16
# pos_tag, len of sent: 16 17
# 16 16 29
# pos_tag, len of sent: 29 29
# 15 15 21
# pos_tag, len of sent: 21 21
# 18 18 25
# pos_tag, len of sent: 25 26
# 15 15 23
# pos_tag, len of sent: 23 23
# 16 16 17
# pos_tag, len of sent: 17 17
# 22 22 26
# pos_tag, len of sent: 26 24
# 23 23 24
# pos_tag, len of sent: 24 37
# 21 21 27
# pos_tag, len of sent: 27 26
# 15 15 26
# pos_tag, len of sent: 26 34
# 20 20 26
# pos_tag, len of sent: 26 26
# 18 18 25
# pos_tag, len of sent: 25 37
# 20 20 27
# pos_tag, len of sent: 27 31
# 23 23 29
# pos_tag, len of sent: 29 40
# 9 9 12
# pos_tag, len of sent: 12 12
# 20 20 24
# pos_tag, len of sent: 24 47
# 11 11 16
# pos_tag, len of sent: 16 16
# 24 24 27
# pos_tag, len of sent: 27 35
# 16 16 25
# pos_tag, len of sent: 25 25
# 20 20 23
# pos_tag, len of sent: 23 24
# 22 22 25
# pos_tag, len of sent: 25 31
# 18 18 19
# pos_tag, len of sent: 19 34
# 15 15 25
# pos_tag, len of sent: 25 39
# 26 26 26
# pos_tag, len of sent: 26 44
# 12 12 13
# pos_tag, len of sent: 13 13
# 17 17 23
# pos_tag, len of sent: 23 23
# 18 18 21
# pos_tag, len of sent: 21 35
# 20 20 26
# pos_tag, len of sent: 26 45
# 14 14 16
# pos_tag, len of sent: 16 16
# 16 16 25
# pos_tag, len of sent: 25 26
# 14 14 17
# pos_tag, len of sent: 17 20
# 23 23 25
# pos_tag, len of sent: 25 31
# 1 1 4
# pos_tag, len of sent: 4 4
# 1 1 3
# pos_tag, len of sent: 3 3
# 13 13 28
# pos_tag, len of sent: 28 28
# 9 9 20
# pos_tag, len of sent: 20 20
# 1 1 3
# pos_tag, len of sent: 3 3
# 15 15 21
# pos_tag, len of sent: 21 21
# 11 11 18
# pos_tag, len of sent: 18 18
# 1 1 3
# pos_tag, len of sent: 3 3
# 18 18 23
# pos_tag, len of sent: 23 38
# 16 16 21
# pos_tag, len of sent: 21 21
# 19 19 27
# pos_tag, len of sent: 27 42
# 1 1 3
# pos_tag, len of sent: 3 3
# 11 11 19
# pos_tag, len of sent: 19 19
# 19 19 21
# pos_tag, len of sent: 21 36
# 10 10 14
# pos_tag, len of sent: 14 14
# 14 14 17
# pos_tag, len of sent: 17 17
# 19 19 25
# pos_tag, len of sent: 25 31
# 21 21 23
# pos_tag, len of sent: 23 37
# 9 9 13
# pos_tag, len of sent: 13 13
# 25 25 26
# pos_tag, len of sent: 26 38
# 18 18 20
# pos_tag, len of sent: 20 20
# 18 18 24
# pos_tag, len of sent: 24 25
# 21 21 21
# pos_tag, len of sent: 21 21
# 19 19 35
# pos_tag, len of sent: 35 34
# 9 9 13
# pos_tag, len of sent: 13 13
# 20 20 25
# pos_tag, len of sent: 25 31
# 12 12 21
# pos_tag, len of sent: 21 21
# 21 21 25
# pos_tag, len of sent: 25 33
# 20 20 24
# pos_tag, len of sent: 24 41
# 14 14 18
# pos_tag, len of sent: 18 18
# 24 24 23
# pos_tag, len of sent: 23 24
# 21 21 25
# pos_tag, len of sent: 25 33
# 25 25 24
# pos_tag, len of sent: 24 24
# 13 13 21
# pos_tag, len of sent: 21 19
# 25 25 26
# pos_tag, len of sent: 26 29
# 18 18 19
# pos_tag, len of sent: 19 19
# 33 33 34
# pos_tag, len of sent: 34 35
# 23 23 23
# pos_tag, len of sent: 23 28
# 13 13 17
# pos_tag, len of sent: 17 17
# 23 23 24
# pos_tag, len of sent: 24 25
# 22 22 25
# pos_tag, len of sent: 25 26
# 20 20 23
# pos_tag, len of sent: 23 30
# 20 20 24
# pos_tag, len of sent: 24 33
# 20 20 22
# pos_tag, len of sent: 22 24
# 22 22 26
# pos_tag, len of sent: 26 33
# 27 27 24
# pos_tag, len of sent: 24 28
# 20 20 27
# pos_tag, len of sent: 27 29
# 25 25 24
# pos_tag, len of sent: 24 31
# 22 22 31
# pos_tag, len of sent: 31 48
# 21 21 24
# pos_tag, len of sent: 24 25
# 20 20 28
# pos_tag, len of sent: 28 29
# 16 16 21
# pos_tag, len of sent: 21 20
# 23 23 24
# pos_tag, len of sent: 24 44
# 6 6 8
# pos_tag, len of sent: 8 8
# 18 18 26
# pos_tag, len of sent: 26 38
# 13 13 20
# pos_tag, len of sent: 20 21
# 18 18 26
# pos_tag, len of sent: 26 39
# 26 26 27
# pos_tag, len of sent: 27 34
# 24 24 25
# pos_tag, len of sent: 25 44
# 21 21 31
# pos_tag, len of sent: 31 37
# 10 10 15
# pos_tag, len of sent: 15 15
# 8 8 17
# pos_tag, len of sent: 17 17
# 17 17 26
# pos_tag, len of sent: 26 26
# 12 12 19
# pos_tag, len of sent: 19 19
# 10 10 15
# pos_tag, len of sent: 15 15
# 16 16 24
# pos_tag, len of sent: 24 24
# 9 9 13
# pos_tag, len of sent: 13 13
# 4 4 11
# pos_tag, len of sent: 11 11
# 22 22 27
# pos_tag, len of sent: 27 43
# 25 25 33
# pos_tag, len of sent: 33 32
# 22 22 25
# pos_tag, len of sent: 25 30
# 16 16 23
# pos_tag, len of sent: 23 39
# 19 19 22
# pos_tag, len of sent: 22 22
# 26 26 30
# pos_tag, len of sent: 30 37
# 25 25 26
# pos_tag, len of sent: 26 28
# 20 20 30
# pos_tag, len of sent: 30 40
# 21 21 26
# pos_tag, len of sent: 26 40
# 20 20 24
# pos_tag, len of sent: 24 32
# 13 13 16
# pos_tag, len of sent: 16 16
# 11 11 18
# pos_tag, len of sent: 18 18
# 18 18 26
# pos_tag, len of sent: 26 38
# 15 15 26
# pos_tag, len of sent: 26 27
# 17 17 20
# pos_tag, len of sent: 20 44
# 18 18 22
# pos_tag, len of sent: 22 48
# 18 18 30
# pos_tag, len of sent: 30 33
# 27 27 26
# pos_tag, len of sent: 26 28
# 19 19 22
# pos_tag, len of sent: 22 30
# 22 22 27
# pos_tag, len of sent: 27 32
# 22 22 24
# pos_tag, len of sent: 24 24
# 23 23 25
# pos_tag, len of sent: 25 34
# 24 24 29
# pos_tag, len of sent: 29 32
# 23 23 22
# pos_tag, len of sent: 22 25
# 25 25 24
# pos_tag, len of sent: 24 41
# 19 19 24
# pos_tag, len of sent: 24 39
# 23 23 26
# pos_tag, len of sent: 26 48
# 22 22 28
# pos_tag, len of sent: 28 29
# 21 21 22
# pos_tag, len of sent: 22 32
# 12 12 16
# pos_tag, len of sent: 16 16
# 12 12 31
# pos_tag, len of sent: 31 31
# 18 18 23
# pos_tag, len of sent: 23 23
# 20 20 21
# pos_tag, len of sent: 21 43
# 21 21 24
# pos_tag, len of sent: 24 28
# 10 10 16
# pos_tag, len of sent: 16 16
# 21 21 22
# pos_tag, len of sent: 22 25
# 25 25 24
# pos_tag, len of sent: 24 48
# 16 16 21
# pos_tag, len of sent: 21 55
# 24 24 20
# pos_tag, len of sent: 20 20
# 23 23 25
# pos_tag, len of sent: 25 34
# 18 18 20
# pos_tag, len of sent: 20 30
# 10 10 11
# pos_tag, len of sent: 11 11
# 11 11 17
# pos_tag, len of sent: 17 17
# 23 23 30
# pos_tag, len of sent: 30 33
# 27 27 31
# pos_tag, len of sent: 31 36
# 11 11 12
# pos_tag, len of sent: 12 12
# 34 34 26
# pos_tag, len of sent: 26 27
# 5 5 12
# pos_tag, len of sent: 12 12
# 5 5 7
# pos_tag, len of sent: 7 7
# 24 24 27
# pos_tag, len of sent: 27 46
# 19 19 19
# pos_tag, len of sent: 19 27
# 19 19 24
# pos_tag, len of sent: 24 40
# 9 9 13
# pos_tag, len of sent: 13 13
# 22 22 23
# pos_tag, len of sent: 23 40
# 11 11 14
# pos_tag, len of sent: 14 14
# 16 16 27
# pos_tag, len of sent: 27 28
# 14 14 27
# pos_tag, len of sent: 27 27
# 23 23 19
# pos_tag, len of sent: 19 34
# 27 27 23
# pos_tag, len of sent: 23 32
# 10 10 12
# pos_tag, len of sent: 12 12
# 22 22 31
# pos_tag, len of sent: 31 33
# 21 21 28
# pos_tag, len of sent: 28 39
# 21 21 22
# pos_tag, len of sent: 22 26
# 7 7 10
# pos_tag, len of sent: 10 10
# 23 23 24
# pos_tag, len of sent: 24 37
# 23 23 25
# pos_tag, len of sent: 25 27
# 6 6 8
# pos_tag, len of sent: 8 8
# 12 12 14
# pos_tag, len of sent: 14 14
# 18 18 22
# pos_tag, len of sent: 22 23
# 23 23 22
# pos_tag, len of sent: 22 40
# 28 28 35
# pos_tag, len of sent: 35 35
# 21 21 27
# pos_tag, len of sent: 27 43
# 11 11 13
# pos_tag, len of sent: 13 13
# 8 8 10
# pos_tag, len of sent: 10 10
# 23 23 24
# pos_tag, len of sent: 24 35
# 22 22 31
# pos_tag, len of sent: 31 30
# 15 15 28
# pos_tag, len of sent: 28 41
# 19 19 21
# pos_tag, len of sent: 21 33
# 19 19 27
# pos_tag, len of sent: 27 43
# 19 19 27
# pos_tag, len of sent: 27 29
# 22 22 24
# pos_tag, len of sent: 24 31
# 21 21 24
# pos_tag, len of sent: 24 40
# 32 32 33
# pos_tag, len of sent: 33 56
# 23 23 25
# pos_tag, len of sent: 25 32
# 14 14 20
# pos_tag, len of sent: 20 20
# 13 13 18
# pos_tag, len of sent: 18 18
# 27 27 27
# pos_tag, len of sent: 27 29
# 18 18 23
# pos_tag, len of sent: 23 23
# 14 14 18
# pos_tag, len of sent: 18 18
# 12 12 21
# pos_tag, len of sent: 21 21
# 6 6 7
# pos_tag, len of sent: 7 7
# 22 22 29
# pos_tag, len of sent: 29 41
# 20 20 24
# pos_tag, len of sent: 24 25
# 14 14 20
# pos_tag, len of sent: 20 26
# 18 18 24
# pos_tag, len of sent: 24 24
# 14 14 22
# pos_tag, len of sent: 22 24
# 23 23 32
# pos_tag, len of sent: 32 61
# 9 9 13
# pos_tag, len of sent: 13 13
# 7 7 6
# pos_tag, len of sent: 6 6
# 21 21 26
# pos_tag, len of sent: 26 45
# 19 19 24
# pos_tag, len of sent: 24 35
# 22 22 27
# pos_tag, len of sent: 27 42
# 22 22 22
# pos_tag, len of sent: 22 29
# 24 24 25
# pos_tag, len of sent: 25 30
# 16 16 20
# pos_tag, len of sent: 20 27
# 11 11 19
# pos_tag, len of sent: 19 19
# 12 12 21
# pos_tag, len of sent: 21 21
# 6 6 9
# pos_tag, len of sent: 9 9
# 27 27 31
# pos_tag, len of sent: 31 46
# 8 8 16
# pos_tag, len of sent: 16 16
# 23 23 30
# pos_tag, len of sent: 30 30
# 21 21 27
# pos_tag, len of sent: 27 52
# 8 8 9
# pos_tag, len of sent: 9 9
# 20 20 26
# pos_tag, len of sent: 26 39
# 14 14 23
# pos_tag, len of sent: 23 24
# 13 13 14
# pos_tag, len of sent: 14 14
# 18 18 23
# pos_tag, len of sent: 23 22
# 14 14 22
# pos_tag, len of sent: 22 22
# 16 16 21
# pos_tag, len of sent: 21 29
# 18 18 23
# pos_tag, len of sent: 23 24
# 21 21 25
# pos_tag, len of sent: 25 28
# 11 11 16
# pos_tag, len of sent: 16 16
# 10 10 14
# pos_tag, len of sent: 14 14
# 14 14 25
# pos_tag, len of sent: 25 22
# 9 9 13
# pos_tag, len of sent: 13 13
# 17 17 27
# pos_tag, len of sent: 27 27
# 16 16 28
# pos_tag, len of sent: 28 30
# 20 20 28
# pos_tag, len of sent: 28 49
# 11 11 15
# pos_tag, len of sent: 15 18
# 15 15 29
# pos_tag, len of sent: 29 54
# 9 9 17
# pos_tag, len of sent: 17 18
# 23 23 21
# pos_tag, len of sent: 21 43
# 22 22 26
# pos_tag, len of sent: 26 52
# 20 20 23
# pos_tag, len of sent: 23 40
# 19 19 19
# pos_tag, len of sent: 19 29
# 13 13 18
# pos_tag, len of sent: 18 18
# 21 21 24
# pos_tag, len of sent: 24 44
# 22 22 22
# pos_tag, len of sent: 22 28
# 25 25 30
# pos_tag, len of sent: 30 29
# 21 21 19
# pos_tag, len of sent: 19 39
# 14 14 19
# pos_tag, len of sent: 19 19
# 6 6 8
# pos_tag, len of sent: 8 8
# 16 16 14
# pos_tag, len of sent: 14 36
# 17 17 22
# pos_tag, len of sent: 22 22
# 20 20 18
# pos_tag, len of sent: 18 20
# 17 17 23
# pos_tag, len of sent: 23 21
# 11 11 16
# pos_tag, len of sent: 16 16
# 27 27 25
# pos_tag, len of sent: 25 64
# 6 6 7
# pos_tag, len of sent: 7 7
# 17 17 21
# pos_tag, len of sent: 21 32
# 23 23 25
# pos_tag, len of sent: 25 27
# 16 16 24
# pos_tag, len of sent: 24 25
# 18 18 24
# pos_tag, len of sent: 24 24
# 14 14 29
# pos_tag, len of sent: 29 30
# 16 16 21
# pos_tag, len of sent: 21 24
# 20 20 22
# pos_tag, len of sent: 22 25
# 18 18 26
# pos_tag, len of sent: 26 37
# 8 8 11
# pos_tag, len of sent: 11 11
# 22 22 25
# pos_tag, len of sent: 25 47
# 25 25 23
# pos_tag, len of sent: 23 46
# 12 12 14
# pos_tag, len of sent: 14 14
# 4 4 5
# pos_tag, len of sent: 5 5
# 27 27 32
# pos_tag, len of sent: 32 43
# 21 21 22
# pos_tag, len of sent: 22 36
# 6 6 13
# pos_tag, len of sent: 13 13
# 20 20 21
# pos_tag, len of sent: 21 34
# 26 26 27
# pos_tag, len of sent: 27 32
# 22 22 24
# pos_tag, len of sent: 24 47
# 11 11 17
# pos_tag, len of sent: 17 17
# 23 23 25
# pos_tag, len of sent: 25 37
# 17 17 23
# pos_tag, len of sent: 23 25
# 13 13 20
# pos_tag, len of sent: 20 20
# 24 24 23
# pos_tag, len of sent: 23 40
# 22 22 22
# pos_tag, len of sent: 22 33
# 10 10 16
# pos_tag, len of sent: 16 16
# 23 23 25
# pos_tag, len of sent: 25 27
# 16 16 25
# pos_tag, len of sent: 25 22
# 21 21 24
# pos_tag, len of sent: 24 46
# 20 20 24
# pos_tag, len of sent: 24 39
# 15 15 19
# pos_tag, len of sent: 19 20
# 23 23 23
# pos_tag, len of sent: 23 36
# 18 18 18
# pos_tag, len of sent: 18 43
# 5 5 7
# pos_tag, len of sent: 7 7
# 17 17 19
# pos_tag, len of sent: 19 18
# 23 23 23
# pos_tag, len of sent: 23 29
# 18 18 23
# pos_tag, len of sent: 23 58
# 16 16 18
# pos_tag, len of sent: 18 18
# 15 15 23
# pos_tag, len of sent: 23 37
# 21 21 21
# pos_tag, len of sent: 21 27
# 14 14 20
# pos_tag, len of sent: 20 20
# 26 26 29
# pos_tag, len of sent: 29 39
# 21 21 22
# pos_tag, len of sent: 22 35
# 21 21 28
# pos_tag, len of sent: 28 41
# 19 19 17
# pos_tag, len of sent: 17 69
# 20 20 25
# pos_tag, len of sent: 25 29
# 19 19 21
# pos_tag, len of sent: 21 20
# 29 29 34
# pos_tag, len of sent: 34 37
# 18 18 25
# pos_tag, len of sent: 25 26
# 17 17 19
# pos_tag, len of sent: 19 19
# 9 9 11
# pos_tag, len of sent: 11 11
# 13 13 14
# pos_tag, len of sent: 14 15
# 11 11 15
# pos_tag, len of sent: 15 13
# 13 13 14
# pos_tag, len of sent: 14 14
# 22 22 19
# pos_tag, len of sent: 19 30
# 21 21 27
# pos_tag, len of sent: 27 33
# 8 8 13
# pos_tag, len of sent: 13 13
# 17 17 25
# pos_tag, len of sent: 25 26
# 17 17 22
# pos_tag, len of sent: 22 22
# 10 10 12
# pos_tag, len of sent: 12 12
# 18 18 20
# pos_tag, len of sent: 20 34
# 17 17 22
# pos_tag, len of sent: 22 27
# 22 22 18
# pos_tag, len of sent: 18 20
# 20 20 27
# pos_tag, len of sent: 27 31
# 18 18 20
# pos_tag, len of sent: 20 20
# 23 23 23
# pos_tag, len of sent: 23 32
# 19 19 32
# pos_tag, len of sent: 32 31
# 24 24 28
# pos_tag, len of sent: 28 27
# 30 30 37
# pos_tag, len of sent: 37 37
# 13 13 15
# pos_tag, len of sent: 15 15
# 9 9 16
# pos_tag, len of sent: 16 16
# 17 17 25
# pos_tag, len of sent: 25 29
# 18 18 24
# pos_tag, len of sent: 24 26
# 17 17 25
# pos_tag, len of sent: 25 25
# 13 13 20
# pos_tag, len of sent: 20 20
# 12 12 16
# pos_tag, len of sent: 16 16
# 13 13 17
# pos_tag, len of sent: 17 17
# 9 9 10
# pos_tag, len of sent: 10 10
# 16 16 29
# pos_tag, len of sent: 29 32
# 10 10 12
# pos_tag, len of sent: 12 14
# 7 7 10
# pos_tag, len of sent: 10 10
# 10 10 20
# pos_tag, len of sent: 20 22
# 6 6 6
# pos_tag, len of sent: 6 6
# 10 10 14
# pos_tag, len of sent: 14 14
# 6 6 8
# pos_tag, len of sent: 8 8
# 10 10 15
# pos_tag, len of sent: 15 15
# 9 9 19
# pos_tag, len of sent: 19 19
# 17 17 22
# pos_tag, len of sent: 22 30
# 18 18 26
# pos_tag, len of sent: 26 28
# 16 16 31
# pos_tag, len of sent: 31 28
# 16 16 26
# pos_tag, len of sent: 26 33
# 24 24 21
# pos_tag, len of sent: 21 29
# 14 14 17
# pos_tag, len of sent: 17 17
# 20 20 25
# pos_tag, len of sent: 25 26
# 24 24 32
# pos_tag, len of sent: 32 39
# 15 15 23
# pos_tag, len of sent: 23 24
# 13 13 23
# pos_tag, len of sent: 23 23
# 22 22 26
# pos_tag, len of sent: 26 42
# 14 14 23
# pos_tag, len of sent: 23 23
# 15 15 21
# pos_tag, len of sent: 21 20
# 22 22 25
# pos_tag, len of sent: 25 36
# 21 21 23
# pos_tag, len of sent: 23 32
# 28 28 24
# pos_tag, len of sent: 24 35
# 16 16 21
# pos_tag, len of sent: 21 41
# 22 22 22
# pos_tag, len of sent: 22 32
# 19 19 23
# pos_tag, len of sent: 23 25
# 11 11 19
# pos_tag, len of sent: 19 19
# 19 19 21
# pos_tag, len of sent: 21 32
# 14 14 20
# pos_tag, len of sent: 20 20
# 16 16 19
# pos_tag, len of sent: 19 19
# 24 24 23
# pos_tag, len of sent: 23 35
# 19 19 18
# pos_tag, len of sent: 18 26
# 7 7 11
# pos_tag, len of sent: 11 11
# 19 19 22
# pos_tag, len of sent: 22 22
# 16 16 18
# pos_tag, len of sent: 18 40
# 23 23 23
# pos_tag, len of sent: 23 49
# 21 21 22
# pos_tag, len of sent: 22 37
# 18 18 22
# pos_tag, len of sent: 22 48
# 19 19 29
# pos_tag, len of sent: 29 32
# 32 32 37
# pos_tag, len of sent: 37 43
# 26 26 24
# pos_tag, len of sent: 24 31
# 8 8 17
# pos_tag, len of sent: 17 17
# 7 7 15
# pos_tag, len of sent: 15 15
# 22 22 27
# pos_tag, len of sent: 27 27
# 15 15 21
# pos_tag, len of sent: 21 21
# 18 18 21
# pos_tag, len of sent: 21 28
# 21 21 24
# pos_tag, len of sent: 24 25
# 12 12 16
# pos_tag, len of sent: 16 16
# 12 12 13
# pos_tag, len of sent: 13 13
# 20 20 24
# pos_tag, len of sent: 24 30
# 22 22 25
# pos_tag, len of sent: 25 32
# 17 17 21
# pos_tag, len of sent: 21 23
# 23 23 27
# pos_tag, len of sent: 27 44
# 7 7 11
# pos_tag, len of sent: 11 11
# 17 17 20
# pos_tag, len of sent: 20 20
# 17 17 23
# pos_tag, len of sent: 23 23
# 17 17 19
# pos_tag, len of sent: 19 38
# 17 17 22
# pos_tag, len of sent: 22 24
# 16 16 20
# pos_tag, len of sent: 20 20
# 25 25 25
# pos_tag, len of sent: 25 27
# 26 26 29
# pos_tag, len of sent: 29 30
# 18 18 20
# pos_tag, len of sent: 20 20
# 17 17 23
# pos_tag, len of sent: 23 23
# 15 15 23
# pos_tag, len of sent: 23 37
# 13 13 17
# pos_tag, len of sent: 17 20
# 21 21 24
# pos_tag, len of sent: 24 23
# 8 8 14
# pos_tag, len of sent: 14 14
# 8 8 16
# pos_tag, len of sent: 16 16
# 10 10 17
# pos_tag, len of sent: 17 17
# 14 14 31
# pos_tag, len of sent: 31 40
# 16 16 19
# pos_tag, len of sent: 19 59
# 16 16 27
# pos_tag, len of sent: 27 29
# 11 11 18
# pos_tag, len of sent: 18 18
# 22 22 20
# pos_tag, len of sent: 20 42
# 20 20 24
# pos_tag, len of sent: 24 72
# 18 18 30
# pos_tag, len of sent: 30 42
# 19 19 24
# pos_tag, len of sent: 24 33
# 25 25 25
# pos_tag, len of sent: 25 40
# 14 14 27
# pos_tag, len of sent: 27 44
# 25 25 28
# pos_tag, len of sent: 28 29
# 17 17 21
# pos_tag, len of sent: 21 22
# 13 13 17
# pos_tag, len of sent: 17 18
# 12 12 16
# pos_tag, len of sent: 16 16
# 6 6 11
# pos_tag, len of sent: 11 11
# 14 14 20
# pos_tag, len of sent: 20 20
# 23 23 17
# pos_tag, len of sent: 17 34
# 9 9 12
# pos_tag, len of sent: 12 12
# 22 22 27
# pos_tag, len of sent: 27 26
# 19 19 26
# pos_tag, len of sent: 26 28
# 10 10 14
# pos_tag, len of sent: 14 14
# 22 22 21
# pos_tag, len of sent: 21 33
# 8 8 11
# pos_tag, len of sent: 11 11
# 21 21 20
# pos_tag, len of sent: 20 22
# 26 26 38
# pos_tag, len of sent: 38 42
# 19 19 18
# pos_tag, len of sent: 18 20
# 19 19 27
# pos_tag, len of sent: 27 37
# 13 13 19
# pos_tag, len of sent: 19 19
# 19 19 20
# pos_tag, len of sent: 20 27
# 11 11 15
# pos_tag, len of sent: 15 16
# 23 23 26
# pos_tag, len of sent: 26 31
# 14 14 22
# pos_tag, len of sent: 22 21
# 15 15 19
# pos_tag, len of sent: 19 19
# 9 9 12
# pos_tag, len of sent: 12 12
# 17 17 16
# pos_tag, len of sent: 16 16
# 18 18 24
# pos_tag, len of sent: 24 35
# 20 20 24
# pos_tag, len of sent: 24 38
# 6 6 9
# pos_tag, len of sent: 9 9
# 22 22 25
# pos_tag, len of sent: 25 40
# 22 22 28
# pos_tag, len of sent: 28 38
# 22 22 26
# pos_tag, len of sent: 26 34
# 24 24 22
# pos_tag, len of sent: 22 42
# 12 12 18
# pos_tag, len of sent: 18 18
# 18 18 19
# pos_tag, len of sent: 19 19
# 13 13 19
# pos_tag, len of sent: 19 19
# 28 28 24
# pos_tag, len of sent: 24 51
# 5 5 7
# pos_tag, len of sent: 7 7
# 22 22 23
# pos_tag, len of sent: 23 24
# 27 27 22
# pos_tag, len of sent: 22 31
# 15 15 19
# pos_tag, len of sent: 19 22
# 21 21 24
# pos_tag, len of sent: 24 28
# 18 18 26
# pos_tag, len of sent: 26 39
# 16 16 25
# pos_tag, len of sent: 25 22
# 9 9 10
# pos_tag, len of sent: 10 10
# 21 21 27
# pos_tag, len of sent: 27 40
# 15 15 15
# pos_tag, len of sent: 15 16
# 21 21 19
# pos_tag, len of sent: 19 28
# 9 9 12
# pos_tag, len of sent: 12 12
# 13 13 16
# pos_tag, len of sent: 16 16
# 19 19 19
# pos_tag, len of sent: 19 29
# 18 18 29
# pos_tag, len of sent: 29 38
# 9 9 11
# pos_tag, len of sent: 11 11
# 17 17 21
# pos_tag, len of sent: 21 27
# 23 23 23
# pos_tag, len of sent: 23 40
# 17 17 26
# pos_tag, len of sent: 26 35
# 10 10 19
# pos_tag, len of sent: 19 19
# 9 9 16
# pos_tag, len of sent: 16 16
# 20 20 20
# pos_tag, len of sent: 20 31
# 21 21 25
# pos_tag, len of sent: 25 35
# 7 7 7
# pos_tag, len of sent: 7 7
# 26 26 21
# pos_tag, len of sent: 21 52
# 15 15 19
# pos_tag, len of sent: 19 19
# 13 13 20
# pos_tag, len of sent: 20 20
# 23 23 23
# pos_tag, len of sent: 23 28
# 23 23 25
# pos_tag, len of sent: 25 36
# 25 25 26
# pos_tag, len of sent: 26 37
# 23 23 24
# pos_tag, len of sent: 24 38
# 14 14 20
# pos_tag, len of sent: 20 20
# 19 19 22
# pos_tag, len of sent: 22 25
# 16 16 19
# pos_tag, len of sent: 19 19
# 17 17 18
# pos_tag, len of sent: 18 18
# 18 18 18
# pos_tag, len of sent: 18 20
# 19 19 16
# pos_tag, len of sent: 16 16
# 18 18 19
# pos_tag, len of sent: 19 47
# 22 22 26
# pos_tag, len of sent: 26 49
# 30 30 27
# pos_tag, len of sent: 27 32
# 19 19 21
# pos_tag, len of sent: 21 36
# 8 8 11
# pos_tag, len of sent: 11 11
# 9 9 14
# pos_tag, len of sent: 14 14
# 13 13 20
# pos_tag, len of sent: 20 20
# 18 18 19
# pos_tag, len of sent: 19 19
# 1 1 3
# pos_tag, len of sent: 3 3
# 21 21 25
# pos_tag, len of sent: 25 32
# 25 25 24
# pos_tag, len of sent: 24 49
# 19 19 21
# pos_tag, len of sent: 21 24
# 24 24 28
# pos_tag, len of sent: 28 28
# 21 21 22
# pos_tag, len of sent: 22 34
# 21 21 22
# pos_tag, len of sent: 22 41
# 14 14 18
# pos_tag, len of sent: 18 18
# 14 14 20
# pos_tag, len of sent: 20 18
# 13 13 19
# pos_tag, len of sent: 19 19
# 13 13 15
# pos_tag, len of sent: 15 15
# 27 27 26
# pos_tag, len of sent: 26 30
# 23 23 23
# pos_tag, len of sent: 23 46
# 22 22 22
# pos_tag, len of sent: 22 28
# 21 21 23
# pos_tag, len of sent: 23 42
# 20 20 28
# pos_tag, len of sent: 28 37
# 22 22 34
# pos_tag, len of sent: 34 48
# 5 5 6
# pos_tag, len of sent: 6 6
# 22 22 23
# pos_tag, len of sent: 23 49
# 20 20 23
# pos_tag, len of sent: 23 24
# 20 20 28
# pos_tag, len of sent: 28 27
# 19 19 20
# pos_tag, len of sent: 20 53
# 18 18 25
# pos_tag, len of sent: 25 30
# 14 14 25
# pos_tag, len of sent: 25 25
# 26 26 24
# pos_tag, len of sent: 24 34
# 28 28 22
# pos_tag, len of sent: 22 30
# 9 9 15
# pos_tag, len of sent: 15 15
# 18 18 19
# pos_tag, len of sent: 19 25
# 20 20 23
# pos_tag, len of sent: 23 34
# 5 5 8
# pos_tag, len of sent: 8 8
# 5 5 13
# pos_tag, len of sent: 13 13
# 20 20 31
# pos_tag, len of sent: 31 31
# 13 13 15
# pos_tag, len of sent: 15 14
# 20 20 22
# pos_tag, len of sent: 22 37
# 17 17 24
# pos_tag, len of sent: 24 24
# 14 14 16
# pos_tag, len of sent: 16 16
# 9 9 13
# pos_tag, len of sent: 13 13
# 22 22 20
# pos_tag, len of sent: 20 50
# 11 11 17
# pos_tag, len of sent: 17 17
# 33 33 28
# pos_tag, len of sent: 28 34
# 14 14 15
# pos_tag, len of sent: 15 15
# 16 16 21
# pos_tag, len of sent: 21 21
# 15 15 19
# pos_tag, len of sent: 19 19
# 27 27 26
# pos_tag, len of sent: 26 28
# 20 20 21
# pos_tag, len of sent: 21 22
# 21 21 25
# pos_tag, len of sent: 25 26
# 22 22 25
# pos_tag, len of sent: 25 26
# 15 15 24
# pos_tag, len of sent: 24 24
# 5 5 6
# pos_tag, len of sent: 6 6
# 14 14 20
# pos_tag, len of sent: 20 20
# 27 27 26
# pos_tag, len of sent: 26 27
# 18 18 19
# pos_tag, len of sent: 19 38
# 19 19 23
# pos_tag, len of sent: 23 28
# 20 20 25
# pos_tag, len of sent: 25 28
# 25 25 24
# pos_tag, len of sent: 24 32
# 12 12 14
# pos_tag, len of sent: 14 14
# 18 18 17
# pos_tag, len of sent: 17 17
# 20 20 26
# pos_tag, len of sent: 26 35
# 15 15 22
# pos_tag, len of sent: 22 22
# 14 14 17
# pos_tag, len of sent: 17 17
# 8 8 11
# pos_tag, len of sent: 11 11
# 22 22 27
# pos_tag, len of sent: 27 30
# 26 26 30
# pos_tag, len of sent: 30 27
# 26 26 23
# pos_tag, len of sent: 23 34
# 17 17 20
# pos_tag, len of sent: 20 20
# 20 20 18
# pos_tag, len of sent: 18 27
# 24 24 27
# pos_tag, len of sent: 27 28
# 18 18 22
# pos_tag, len of sent: 22 22
# 23 23 32
# pos_tag, len of sent: 32 43
# 9 9 11
# pos_tag, len of sent: 11 11
# 19 19 27
# pos_tag, len of sent: 27 27
# 21 21 22
# pos_tag, len of sent: 22 31
# 18 18 24
# pos_tag, len of sent: 24 56
# 16 16 21
# pos_tag, len of sent: 21 22
# 23 23 25
# pos_tag, len of sent: 25 28
# 24 24 34
# pos_tag, len of sent: 34 44
# 22 22 26
# pos_tag, len of sent: 26 35
# 19 19 27
# pos_tag, len of sent: 27 41
# 18 18 17
# pos_tag, len of sent: 17 42
# 21 21 26
# pos_tag, len of sent: 26 37
# 22 22 17
# pos_tag, len of sent: 17 42
# 18 18 18
# pos_tag, len of sent: 18 26
# 20 20 23
# pos_tag, len of sent: 23 48
# 14 14 18
# pos_tag, len of sent: 18 18
# 19 19 19
# pos_tag, len of sent: 19 49
# 19 19 32
# pos_tag, len of sent: 32 32
# 18 18 20
# pos_tag, len of sent: 20 21
# 7 7 12
# pos_tag, len of sent: 12 12
# 24 24 25
# pos_tag, len of sent: 25 26
# 18 18 22
# pos_tag, len of sent: 22 30
# 15 15 19
# pos_tag, len of sent: 19 19
# 18 18 24
# pos_tag, len of sent: 24 27
# 20 20 24
# pos_tag, len of sent: 24 31
# 29 29 29
# pos_tag, len of sent: 29 30
# 19 19 23
# pos_tag, len of sent: 23 23
# 21 21 24
# pos_tag, len of sent: 24 36
# 20 20 23
# pos_tag, len of sent: 23 39
# 18 18 19
# pos_tag, len of sent: 19 20
# 16 16 19
# pos_tag, len of sent: 19 36
# 24 24 32
# pos_tag, len of sent: 32 41
# 19 19 28
# pos_tag, len of sent: 28 25
# 15 15 21
# pos_tag, len of sent: 21 21
# 13 13 21
# pos_tag, len of sent: 21 22
# 18 18 22
# pos_tag, len of sent: 22 22
# 11 11 14
# pos_tag, len of sent: 14 14
# 14 14 21
# pos_tag, len of sent: 21 21
# 16 16 19
# pos_tag, len of sent: 19 19
# 22 22 24
# pos_tag, len of sent: 24 30
# 15 15 19
# pos_tag, len of sent: 19 19
# 23 23 27
# pos_tag, len of sent: 27 29
# 17 17 26
# pos_tag, len of sent: 26 31
# 19 19 27
# pos_tag, len of sent: 27 28
# 10 10 19
# pos_tag, len of sent: 19 19
# 12 12 20
# pos_tag, len of sent: 20 20
# 18 18 22
# pos_tag, len of sent: 22 24
# 10 10 15
# pos_tag, len of sent: 15 14
# 17 17 25
# pos_tag, len of sent: 25 25
# 24 24 27
# pos_tag, len of sent: 27 39
# 8 8 12
# pos_tag, len of sent: 12 12
# 25 25 24
# pos_tag, len of sent: 24 32
# 20 20 24
# pos_tag, len of sent: 24 23
# 18 18 24
# pos_tag, len of sent: 24 38
# 22 22 30
# pos_tag, len of sent: 30 30
# 28 28 31
# pos_tag, len of sent: 31 55
# 19 19 22
# pos_tag, len of sent: 22 36
# 24 24 31
# pos_tag, len of sent: 31 34
# 14 14 14
# pos_tag, len of sent: 14 14
# 16 16 24
# pos_tag, len of sent: 24 40
# 17 17 16
# pos_tag, len of sent: 16 16
# 24 24 24
# pos_tag, len of sent: 24 25
# 11 11 24
# pos_tag, len of sent: 24 24
# 23 23 28
# pos_tag, len of sent: 28 28
# 23 23 30
# pos_tag, len of sent: 30 30
# 20 20 24
# pos_tag, len of sent: 24 24
# 13 13 22
# pos_tag, len of sent: 22 22
# 16 16 23
# pos_tag, len of sent: 23 26
# 22 22 24
# pos_tag, len of sent: 24 34
# 11 11 16
# pos_tag, len of sent: 16 16
# 20 20 22
# pos_tag, len of sent: 22 46
# 18 18 34
# pos_tag, len of sent: 34 33
# 12 12 18
# pos_tag, len of sent: 18 18
# 10 10 21
# pos_tag, len of sent: 21 21
# 18 18 31
# pos_tag, len of sent: 31 43
# 17 17 19
# pos_tag, len of sent: 19 19
# 11 11 19
# pos_tag, len of sent: 19 19
# 36 36 40
# pos_tag, len of sent: 40 44
# 26 26 25
# pos_tag, len of sent: 25 37
# 21 21 24
# pos_tag, len of sent: 24 26
# 13 13 15
# pos_tag, len of sent: 15 15
# 20 20 21
# pos_tag, len of sent: 21 21
# 20 20 22
# pos_tag, len of sent: 22 37
# 24 24 25
# pos_tag, len of sent: 25 45
# 16 16 17
# pos_tag, len of sent: 17 24
# 19 19 22
# pos_tag, len of sent: 22 23
# 28 28 25
# pos_tag, len of sent: 25 35
# 23 23 22
# pos_tag, len of sent: 22 46
# 12 12 21
# pos_tag, len of sent: 21 42
# 4 4 6
# pos_tag, len of sent: 6 6
# 19 19 24
# pos_tag, len of sent: 24 46
# 18 18 24
# pos_tag, len of sent: 24 48
# 25 25 18
# pos_tag, len of sent: 18 27
# 22 22 23
# pos_tag, len of sent: 23 39
# 14 14 17
# pos_tag, len of sent: 17 17
# 13 13 20
# pos_tag, len of sent: 20 20
# 18 18 21
# pos_tag, len of sent: 21 25
# 22 22 26
# pos_tag, len of sent: 26 32
# 15 15 20
# pos_tag, len of sent: 20 20
# 14 14 17
# pos_tag, len of sent: 17 16
# 20 20 25
# pos_tag, len of sent: 25 54
# 20 20 27
# pos_tag, len of sent: 27 44
# 20 20 25
# pos_tag, len of sent: 25 32
# 23 23 26
# pos_tag, len of sent: 26 37
# 20 20 19
# pos_tag, len of sent: 19 33
# 11 11 18
# pos_tag, len of sent: 18 19
# 7 7 3
# pos_tag, len of sent: 3 24
# 14 14 14
# pos_tag, len of sent: 14 14
# 19 19 27
# pos_tag, len of sent: 27 35
# 22 22 22
# pos_tag, len of sent: 22 30
# 8 8 11
# pos_tag, len of sent: 11 14
# 14 14 17
# pos_tag, len of sent: 17 19
# 19 19 26
# pos_tag, len of sent: 26 36
# 7 7 10
# pos_tag, len of sent: 10 10
# 11 11 21
# pos_tag, len of sent: 21 21
# 21 21 26
# pos_tag, len of sent: 26 27
# 9 9 12
# pos_tag, len of sent: 12 12
# 6 6 11
# pos_tag, len of sent: 11 11
# 17 17 26
# pos_tag, len of sent: 26 44
# 15 15 24
# pos_tag, len of sent: 24 37
# 23 23 29
# pos_tag, len of sent: 29 37
# 19 19 21
# pos_tag, len of sent: 21 22
# 11 11 17
# pos_tag, len of sent: 17 19
# 19 19 22
# pos_tag, len of sent: 22 39
# 7 7 13
# pos_tag, len of sent: 13 13
# 5 5 8
# pos_tag, len of sent: 8 8
# 18 18 21
# pos_tag, len of sent: 21 24
# 22 22 20
# pos_tag, len of sent: 20 45
# 21 21 18
# pos_tag, len of sent: 18 34
# 15 15 21
# pos_tag, len of sent: 21 20
# 18 18 20
# pos_tag, len of sent: 20 35
# 22 22 27
# pos_tag, len of sent: 27 30
# 14 14 25
# pos_tag, len of sent: 25 27
# 16 16 21
# pos_tag, len of sent: 21 27
# 8 8 11
# pos_tag, len of sent: 11 11
# 21 21 21
# pos_tag, len of sent: 21 43
# 21 21 23
# pos_tag, len of sent: 23 28
# 13 13 17
# pos_tag, len of sent: 17 18
# 19 19 26
# pos_tag, len of sent: 26 55
# 19 19 21
# pos_tag, len of sent: 21 24
# 20 20 23
# pos_tag, len of sent: 23 32
# 19 19 21
# pos_tag, len of sent: 21 42
# 18 18 23
# pos_tag, len of sent: 23 24
# 8 8 10
# ...
# 5 5 7
# pos_tag, len of sent: 7 6
# 16 16 19
# pos_tag, len of sent: 19 20
# 10 10 15
# pos_tag, len of sent: 15 15
# 19 19 29
# pos_tag, len of sent: 29 32
# 17 17 22
# pos_tag, len of sent: 22 24
# 22 22 22
# pos_tag, len of sent: 22 29
# 17 17 21
# pos_tag, len of sent: 21 24
# 12 12 18
# pos_tag, len of sent: 18 18
# 21 21 30
# pos_tag, len of sent: 30 55
# 19 19 25
# pos_tag, len of sent: 25 25
# 22 22 20
# pos_tag, len of sent: 20 39
# 13 13 16
# pos_tag, len of sent: 16 16
# 19 19 24
# pos_tag, len of sent: 24 26
# 22 22 22
# pos_tag, len of sent: 22 53
# 22 22 25
# pos_tag, len of sent: 25 25
# 23 23 21
# pos_tag, len of sent: 21 33
# 24 24 26
# pos_tag, len of sent: 26 37
# 18 18 20
# pos_tag, len of sent: 20 20
# 24 24 20
# pos_tag, len of sent: 20 21
# 16 16 22
# pos_tag, len of sent: 22 22
# 12 12 17
# pos_tag, len of sent: 17 17
# 15 15 29
# pos_tag, len of sent: 29 31
# 18 18 23
# pos_tag, len of sent: 23 45
# 16 16 16
# pos_tag, len of sent: 16 16
# 5 5 11
# pos_tag, len of sent: 11 11
# 6 6 12
# pos_tag, len of sent: 12 12
# 20 20 19
# pos_tag, len of sent: 19 26
# 25 25 25
# pos_tag, len of sent: 25 25
# 4 4 4
# pos_tag, len of sent: 4 4
# 21 21 28
# pos_tag, len of sent: 28 31
# 18 18 20
# pos_tag, len of sent: 20 20
# 22 22 22
# pos_tag, len of sent: 22 49
# 13 13 27
# pos_tag, len of sent: 27 27
# 16 16 17
# pos_tag, len of sent: 17 18
# 24 24 24
# pos_tag, len of sent: 24 48
# 15 15 19
# pos_tag, len of sent: 19 19
# 17 17 27
# pos_tag, len of sent: 27 22
# 14 14 20
# pos_tag, len of sent: 20 18
# 27 27 25
# pos_tag, len of sent: 25 29
# 23 23 22
# pos_tag, len of sent: 22 33
# 15 15 22
# pos_tag, len of sent: 22 23
# 20 20 26
# pos_tag, len of sent: 26 23
# 22 22 24
# pos_tag, len of sent: 24 29
# 16 16 25
# pos_tag, len of sent: 25 30
# 24 24 40
# pos_tag, len of sent: 40 54
# 11 11 21
# pos_tag, len of sent: 21 21
# 22 22 25
# pos_tag, len of sent: 25 59
# 25 25 22
# pos_tag, len of sent: 22 37
# 21 21 20
# pos_tag, len of sent: 20 31
# 4 4 6
# pos_tag, len of sent: 6 6
# 11 11 12
# pos_tag, len of sent: 12 12
# 24 24 24
# pos_tag, len of sent: 24 39
# 18 18 16
# pos_tag, len of sent: 16 16
# 18 18 21
# pos_tag, len of sent: 21 68
# 25 25 22
# pos_tag, len of sent: 22 36
# 16 16 21
# pos_tag, len of sent: 21 33
# 19 19 27
# pos_tag, len of sent: 27 53
# 19 19 25
# pos_tag, len of sent: 25 27
# 21 21 21
# pos_tag, len of sent: 21 43
# 17 17 16
# pos_tag, len of sent: 16 36
# 23 23 21
# pos_tag, len of sent: 21 25
# 20 20 23
# pos_tag, len of sent: 23 36
# 25 25 24
# pos_tag, len of sent: 24 42
# 22 22 23
# pos_tag, len of sent: 23 55
# 16 16 21
# pos_tag, len of sent: 21 54
# 17 17 19
# pos_tag, len of sent: 19 34
# 20 20 22
# pos_tag, len of sent: 22 22
# 9 9 11
# pos_tag, len of sent: 11 11
# 18 18 24
# pos_tag, len of sent: 24 43
# 27 27 21
# pos_tag, len of sent: 21 31
# 15 15 20
# pos_tag, len of sent: 20 43
# 15 15 30
# pos_tag, len of sent: 30 26
# 6 6 10
# pos_tag, len of sent: 10 10
# 10 10 14
# pos_tag, len of sent: 14 13
# 5 5 8
# pos_tag, len of sent: 8 8
# 1 1 6
# pos_tag, len of sent: 6 6
# 7 7 14
# pos_tag, len of sent: 14 13
# 1 1 5
# pos_tag, len of sent: 5 5
# 6 6 11
# pos_tag, len of sent: 11 10
# 1 1 4
# pos_tag, len of sent: 4 4
# 6 6 15
# pos_tag, len of sent: 15 14
# 1 1 4
# pos_tag, len of sent: 4 4
# 10 10 19
# pos_tag, len of sent: 19 19
# 1 1 4
# pos_tag, len of sent: 4 4
# 6 6 12
# pos_tag, len of sent: 12 12
# 1 1 3
# pos_tag, len of sent: 3 3
# 7 7 11
# pos_tag, len of sent: 11 11
# 1 1 3
# pos_tag, len of sent: 3 3
# 5 5 9
# pos_tag, len of sent: 9 9
# 1 1 4
# pos_tag, len of sent: 4 4
# 6 6 9
# pos_tag, len of sent: 9 9
# 1 1 5
# pos_tag, len of sent: 5 5
# 6 6 12
# pos_tag, len of sent: 12 11
# 1 1 3
# pos_tag, len of sent: 3 3
# 4 4 8
# pos_tag, len of sent: 8 8
# 1 1 3
# pos_tag, len of sent: 3 3
# 6 6 9
# pos_tag, len of sent: 9 9
# 1 1 2
# pos_tag, len of sent: 2 2
# 10 10 19
# pos_tag, len of sent: 19 19
# 3 3 4
# pos_tag, len of sent: 4 4
# 11 11 20
# pos_tag, len of sent: 20 20
# 1 1 5
# pos_tag, len of sent: 5 5
# 11 11 20
# pos_tag, len of sent: 20 20
# 3 3 4
# pos_tag, len of sent: 4 4
# 15 15 31
# pos_tag, len of sent: 31 42
# 1 1 6
# pos_tag, len of sent: 6 6
# 8 8 15
# pos_tag, len of sent: 15 15
# 1 1 2
# pos_tag, len of sent: 2 2
# 10 10 28
# pos_tag, len of sent: 28 26
# 1 1 6
# pos_tag, len of sent: 6 6
# 12 12 20
# pos_tag, len of sent: 20 20
# 1 1 4
# pos_tag, len of sent: 4 4
# 8 8 12
# pos_tag, len of sent: 12 11
# 7 7 10
# pos_tag, len of sent: 10 9
# 8 8 14
# pos_tag, len of sent: 14 14
# 4 4 10
# pos_tag, len of sent: 10 10
# 10 10 17
# pos_tag, len of sent: 17 17
# 3 3 5
# pos_tag, len of sent: 5 5
# 8 8 18
# pos_tag, len of sent: 18 18
# 3 3 12
# pos_tag, len of sent: 12 8
# 11 11 22
# pos_tag, len of sent: 22 23
# 19 19 23
# pos_tag, len of sent: 23 42
# 22 22 31
# pos_tag, len of sent: 31 34
# 7 7 10
# pos_tag, len of sent: 10 10
# 17 17 21
# pos_tag, len of sent: 21 40
# 13 13 15
# pos_tag, len of sent: 15 15
# 10 10 9
# pos_tag, len of sent: 9 8
# 10 10 13
# pos_tag, len of sent: 13 13
# 21 21 18
# pos_tag, len of sent: 18 21
# 18 18 19
# pos_tag, len of sent: 19 30
# 18 18 26
# pos_tag, len of sent: 26 40
# 16 16 24
# pos_tag, len of sent: 24 24
# 20 20 20
# pos_tag, len of sent: 20 22
# 17 17 27
# pos_tag, len of sent: 27 27
# 15 15 21
# pos_tag, len of sent: 21 21
# 20 20 23
# pos_tag, len of sent: 23 26
# 27 27 22
# pos_tag, len of sent: 22 24
# 23 23 23
# pos_tag, len of sent: 23 51
# 23 23 31
# pos_tag, len of sent: 31 33
# 14 14 15
# pos_tag, len of sent: 15 15
# 22 22 26
# pos_tag, len of sent: 26 36
# 26 26 29
# pos_tag, len of sent: 29 31
# 22 22 23
# pos_tag, len of sent: 23 33
# 20 20 26
# pos_tag, len of sent: 26 26
# 24 24 24
# pos_tag, len of sent: 24 43
# 15 15 13
# pos_tag, len of sent: 13 15
# 13 13 19
# pos_tag, len of sent: 19 21
# 20 20 21
# pos_tag, len of sent: 21 21
# 6 6 7
# pos_tag, len of sent: 7 7
# 17 17 24
# pos_tag, len of sent: 24 24
# 12 12 15
# pos_tag, len of sent: 15 17
# 13 13 17
# pos_tag, len of sent: 17 18
# 11 11 14
# pos_tag, len of sent: 14 14
# 6 6 11
# pos_tag, len of sent: 11 11
# 13 13 18
# pos_tag, len of sent: 18 18
# 18 18 22
# pos_tag, len of sent: 22 40
# 21 21 24
# pos_tag, len of sent: 24 27
# 12 12 15
# pos_tag, len of sent: 15 15
# 22 22 27
# pos_tag, len of sent: 27 35
# 15 15 17
# pos_tag, len of sent: 17 17
# 18 18 24
# pos_tag, len of sent: 24 34
# 27 27 30
# pos_tag, len of sent: 30 38
# 19 19 24
# pos_tag, len of sent: 24 27
# 5 5 9
# pos_tag, len of sent: 9 9
# 6 6 7
# pos_tag, len of sent: 7 7
# 20 20 22
# pos_tag, len of sent: 22 30
# 17 17 17
# pos_tag, len of sent: 17 17
# 7 7 9
# pos_tag, len of sent: 9 8
# 4 4 5
# pos_tag, len of sent: 5 5
# 19 19 16
# pos_tag, len of sent: 16 17
# 12 12 14
# pos_tag, len of sent: 14 16
# 23 23 25
# pos_tag, len of sent: 25 42
# 13 13 16
# pos_tag, len of sent: 16 16
# 19 19 23
# pos_tag, len of sent: 23 24
# 23 23 20
# pos_tag, len of sent: 20 25
# 23 23 26
# pos_tag, len of sent: 26 27
# 21 21 19
# pos_tag, len of sent: 19 35
# 22 22 19
# pos_tag, len of sent: 19 20
# 16 16 25
# pos_tag, len of sent: 25 40
# 17 17 21
# pos_tag, len of sent: 21 21
# 16 16 19
# pos_tag, len of sent: 19 19
# 19 19 29
# pos_tag, len of sent: 29 29
# 14 14 25
# pos_tag, len of sent: 25 25
# 22 22 24
# pos_tag, len of sent: 24 29
# 6 6 7
# pos_tag, len of sent: 7 6
# 21 21 25
# pos_tag, len of sent: 25 54
# 15 15 22
# pos_tag, len of sent: 22 21
# 17 17 27
# pos_tag, len of sent: 27 32
# 20 20 23
# pos_tag, len of sent: 23 48
# 22 22 17
# pos_tag, len of sent: 17 17
# 28 28 21
# pos_tag, len of sent: 21 37
# 14 14 19
# pos_tag, len of sent: 19 19
# 4 4 5
# pos_tag, len of sent: 5 5
# 19 19 19
# pos_tag, len of sent: 19 19
# 15 15 21
# pos_tag, len of sent: 21 22
# 15 15 17
# pos_tag, len of sent: 17 16
# 11 11 10
# pos_tag, len of sent: 10 10
# 18 18 21
# pos_tag, len of sent: 21 21
# 7 7 10
# pos_tag, len of sent: 10 10
# 8 8 10
# pos_tag, len of sent: 10 10
# 18 18 24
# pos_tag, len of sent: 24 23
# 24 24 20
# pos_tag, len of sent: 20 39
# 16 16 24
# pos_tag, len of sent: 24 30
# 18 18 21
# pos_tag, len of sent: 21 21
# 18 18 20
# pos_tag, len of sent: 20 24
# 26 26 24
# pos_tag, len of sent: 24 43
# 11 11 15
# pos_tag, len of sent: 15 15
# 21 21 23
# pos_tag, len of sent: 23 42
# 18 18 20
# pos_tag, len of sent: 20 33
# 9 9 11
# pos_tag, len of sent: 11 11
# 16 16 30
# pos_tag, len of sent: 30 42
# 20 20 26
# pos_tag, len of sent: 26 35
# 19 19 19
# pos_tag, len of sent: 19 28
# 9 9 8
# pos_tag, len of sent: 8 8
# 29 29 25
# pos_tag, len of sent: 25 43
# 21 21 25
# pos_tag, len of sent: 25 28
# 28 28 21
# pos_tag, len of sent: 21 25
# 17 17 24
# pos_tag, len of sent: 24 43
# 17 17 20
# pos_tag, len of sent: 20 21
# 20 20 23
# pos_tag, len of sent: 23 57
# 20 20 24
# pos_tag, len of sent: 24 45
# 7 7 8
# pos_tag, len of sent: 8 5
# 24 24 24
# pos_tag, len of sent: 24 39
# 19 19 22
# pos_tag, len of sent: 22 22
# 12 12 17
# pos_tag, len of sent: 17 17
# 15 15 21
# pos_tag, len of sent: 21 21
# 9 9 17
# pos_tag, len of sent: 17 17
# 14 14 17
# pos_tag, len of sent: 17 17
# 9 9 14
# pos_tag, len of sent: 14 14
# 21 21 25
# pos_tag, len of sent: 25 46
# 9 9 15
# pos_tag, len of sent: 15 14
# 23 23 19
# pos_tag, len of sent: 19 29
# 21 21 31
# pos_tag, len of sent: 31 44
# 17 17 23
# pos_tag, len of sent: 23 32
# 11 11 16
# pos_tag, len of sent: 16 16
# 3 3 4
# pos_tag, len of sent: 4 2
# 3 3 3
# pos_tag, len of sent: 3 3
# 10 10 24
# pos_tag, len of sent: 24 24
# 12 12 15
# pos_tag, len of sent: 15 15
# 12 12 22
# pos_tag, len of sent: 22 18
# 9 9 24
# pos_tag, len of sent: 24 26
# 9 9 12
# pos_tag, len of sent: 12 13
# 24 24 29
# pos_tag, len of sent: 29 28
# 7 7 12
# pos_tag, len of sent: 12 12
# 19 19 27
# pos_tag, len of sent: 27 28
# 11 11 20
# pos_tag, len of sent: 20 20
# 20 20 22
# pos_tag, len of sent: 22 54
# 13 13 16
# pos_tag, len of sent: 16 16
# 16 16 22
# pos_tag, len of sent: 22 27
# 20 20 28
# pos_tag, len of sent: 28 29
# 17 17 24
# pos_tag, len of sent: 24 36
# 17 17 18
# pos_tag, len of sent: 18 23
# 16 16 16
# pos_tag, len of sent: 16 16
# 21 21 22
# pos_tag, len of sent: 22 29
# 30 30 26
# pos_tag, len of sent: 26 27
# 16 16 21
# pos_tag, len of sent: 21 22
# 18 18 22
# pos_tag, len of sent: 22 22
# 18 18 21
# pos_tag, len of sent: 21 27
# 14 14 20
# pos_tag, len of sent: 20 20
# 18 18 26
# pos_tag, len of sent: 26 26
# 19 19 28
# pos_tag, len of sent: 28 39
# 21 21 33
# pos_tag, len of sent: 33 34
# 14 14 16
# pos_tag, len of sent: 16 18
# 13 13 14
# pos_tag, len of sent: 14 14
# 20 20 24
# pos_tag, len of sent: 24 24
# 18 18 24
# pos_tag, len of sent: 24 42
# 10 10 18
# pos_tag, len of sent: 18 18
# 12 12 21
# pos_tag, len of sent: 21 22
# 23 23 24
# pos_tag, len of sent: 24 30
# 20 20 30
# pos_tag, len of sent: 30 31
# 26 26 23
# pos_tag, len of sent: 23 33
# 19 19 20
# pos_tag, len of sent: 20 33
# 16 16 16
# pos_tag, len of sent: 16 16
# 15 15 24
# pos_tag, len of sent: 24 24
# 27 27 33
# pos_tag, len of sent: 33 65
# 20 20 23
# pos_tag, len of sent: 23 32
# 14 14 17
# pos_tag, len of sent: 17 14
# 11 11 14
# pos_tag, len of sent: 14 15
# 18 18 26
# pos_tag, len of sent: 26 32
# 18 18 22
# pos_tag, len of sent: 22 27
# 23 23 20
# pos_tag, len of sent: 20 31
# 12 12 20
# pos_tag, len of sent: 20 20
# 21 21 26
# pos_tag, len of sent: 26 30
# 21 21 22
# pos_tag, len of sent: 22 47
# 8 8 12
# pos_tag, len of sent: 12 12
# 17 17 16
# pos_tag, len of sent: 16 16
# 12 12 19
# pos_tag, len of sent: 19 19
# 21 21 26
# pos_tag, len of sent: 26 55
# 16 16 25
# pos_tag, len of sent: 25 24
# 20 20 24
# pos_tag, len of sent: 24 42
# 22 22 21
# pos_tag, len of sent: 21 26
# 20 20 22
# pos_tag, len of sent: 22 36
# 20 20 24
# pos_tag, len of sent: 24 29
# 12 12 14
# pos_tag, len of sent: 14 14
# 24 24 34
# pos_tag, len of sent: 34 33
# 20 20 23
# pos_tag, len of sent: 23 46
# 16 16 23
# pos_tag, len of sent: 23 23
# 23 23 22
# pos_tag, len of sent: 22 29
# 28 28 26
# pos_tag, len of sent: 26 32
# 8 8 10
# pos_tag, len of sent: 10 10
# 17 17 23
# pos_tag, len of sent: 23 23
# 18 18 21
# pos_tag, len of sent: 21 22
# 21 21 24
# pos_tag, len of sent: 24 35
# 6 6 7
# pos_tag, len of sent: 7 7
# 18 18 23
# pos_tag, len of sent: 23 32
# 24 24 21
# pos_tag, len of sent: 21 35
# 13 13 17
# pos_tag, len of sent: 17 17
# 32 32 28
# pos_tag, len of sent: 28 36
# 11 11 17
# pos_tag, len of sent: 17 17
# 21 21 24
# pos_tag, len of sent: 24 27
# 20 20 24
# pos_tag, len of sent: 24 26
# 10 10 15
# pos_tag, len of sent: 15 14
# 5 5 6
# pos_tag, len of sent: 6 6
# 13 13 17
# pos_tag, len of sent: 17 17
# 23 23 23
# pos_tag, len of sent: 23 30
# 16 16 20
# pos_tag, len of sent: 20 24
# 13 13 23
# pos_tag, len of sent: 23 23
# 5 5 6
# pos_tag, len of sent: 6 6
# 15 15 23
# pos_tag, len of sent: 23 23
# 12 12 14
# pos_tag, len of sent: 14 14
# 16 16 21
# pos_tag, len of sent: 21 21
# 16 16 22
# pos_tag, len of sent: 22 25
# 10 10 12
# pos_tag, len of sent: 12 12
# 19 19 25
# pos_tag, len of sent: 25 25
# 16 16 24
# pos_tag, len of sent: 24 26
# 10 10 12
# pos_tag, len of sent: 12 12
# 20 20 22
# pos_tag, len of sent: 22 22
# 19 19 23
# pos_tag, len of sent: 23 28
# 7 7 11
# pos_tag, len of sent: 11 11
# 18 18 17
# pos_tag, len of sent: 17 26
# 4 4 4
# pos_tag, len of sent: 4 4
# 4 4 4
# pos_tag, len of sent: 4 4
# 4 4 5
# pos_tag, len of sent: 5 5
# 16 16 24
# pos_tag, len of sent: 24 27
# 24 24 20
# pos_tag, len of sent: 20 37
# 14 14 18
# pos_tag, len of sent: 18 18
# 24 24 26
# pos_tag, len of sent: 26 28
# 16 16 24
# pos_tag, len of sent: 24 36
# 21 21 20
# pos_tag, len of sent: 20 36
# 20 20 21
# pos_tag, len of sent: 21 28
# 26 26 25
# pos_tag, len of sent: 25 37
# 14 14 19
# pos_tag, len of sent: 19 19
# 16 16 22
# pos_tag, len of sent: 22 24
# 28 28 31
# pos_tag, len of sent: 31 45
# 7 7 12
# pos_tag, len of sent: 12 12
# 13 13 19
# pos_tag, len of sent: 19 19
# 25 25 23
# pos_tag, len of sent: 23 28
# 19 19 19
# pos_tag, len of sent: 19 40
# 7 7 10
# pos_tag, len of sent: 10 10
# 20 20 29
# pos_tag, len of sent: 29 38
# 8 8 9
# pos_tag, len of sent: 9 9
# 16 16 21
# pos_tag, len of sent: 21 20
# 35 35 46
# pos_tag, len of sent: 46 34
# 12 12 18
# pos_tag, len of sent: 18 18
# 23 23 22
# pos_tag, len of sent: 22 31
# 9 9 14
# pos_tag, len of sent: 14 18
# 17 17 24
# pos_tag, len of sent: 24 24
# 18 18 22
# pos_tag, len of sent: 22 24
# 9 9 13
# pos_tag, len of sent: 13 13
# 22 22 26
# pos_tag, len of sent: 26 49
# 20 20 23
# pos_tag, len of sent: 23 26
# 15 15 22
# pos_tag, len of sent: 22 22
# 11 11 18
# pos_tag, len of sent: 18 18
# 9 9 11
# pos_tag, len of sent: 11 11
# 10 10 10
# pos_tag, len of sent: 10 10
# 21 21 20
# pos_tag, len of sent: 20 29
# 18 18 20
# pos_tag, len of sent: 20 34
# 18 18 24
# pos_tag, len of sent: 24 25
# 20 20 24
# pos_tag, len of sent: 24 22
# 13 13 19
# pos_tag, len of sent: 19 19
# 4 4 7
# pos_tag, len of sent: 7 7
# 13 13 15
# pos_tag, len of sent: 15 14
# 16 16 22
# pos_tag, len of sent: 22 23
# 13 13 21
# pos_tag, len of sent: 21 21
# 5 5 7
# pos_tag, len of sent: 7 7
# 22 22 27
# pos_tag, len of sent: 27 27
# 19 19 25
# pos_tag, len of sent: 25 25
# 22 22 24
# pos_tag, len of sent: 24 29
# 18 18 23
# pos_tag, len of sent: 23 33
# 10 10 13
# pos_tag, len of sent: 13 14
# 23 23 25
# pos_tag, len of sent: 25 45
# 22 22 22
# pos_tag, len of sent: 22 31
# 19 19 30
# pos_tag, len of sent: 30 50
# 9 9 11
# pos_tag, len of sent: 11 11
# 27 27 32
# pos_tag, len of sent: 32 39
# 17 17 20
# pos_tag, len of sent: 20 32
# 19 19 19
# pos_tag, len of sent: 19 19
# 7 7 9
# pos_tag, len of sent: 9 9
# 21 21 24
# pos_tag, len of sent: 24 25
# 14 14 20
# pos_tag, len of sent: 20 20
# 20 20 21
# pos_tag, len of sent: 21 34
# 22 22 25
# pos_tag, len of sent: 25 26
# 11 11 16
# pos_tag, len of sent: 16 16
# 17 17 29
# pos_tag, len of sent: 29 29
# 7 7 7
# pos_tag, len of sent: 7 7
# 22 22 24
# pos_tag, len of sent: 24 39
# 17 17 23
# pos_tag, len of sent: 23 23
# 22 22 21
# pos_tag, len of sent: 21 33
# 10 10 15
# pos_tag, len of sent: 15 15
# 20 20 25
# pos_tag, len of sent: 25 30
# 7 7 6
# pos_tag, len of sent: 6 6
# 10 10 15
# pos_tag, len of sent: 15 15
# 20 20 23
# pos_tag, len of sent: 23 26
# 13 13 17
# pos_tag, len of sent: 17 17
# 12 12 16
# pos_tag, len of sent: 16 16
# 16 16 21
# pos_tag, len of sent: 21 27
# 23 23 31
# pos_tag, len of sent: 31 44
# 23 23 25
# pos_tag, len of sent: 25 46
# 22 22 21
# pos_tag, len of sent: 21 38
# 18 18 32
# pos_tag, len of sent: 32 31
# 22 22 23
# pos_tag, len of sent: 23 25
# 9 9 12
# pos_tag, len of sent: 12 12
# 17 17 28
# pos_tag, len of sent: 28 28
# 21 21 25
# pos_tag, len of sent: 25 55
# 10 10 12
# pos_tag, len of sent: 12 12
# 19 19 33
# pos_tag, len of sent: 33 34
# 1 1 4
# pos_tag, len of sent: 4 4
# 13 13 20
# pos_tag, len of sent: 20 20
# 17 17 17
# pos_tag, len of sent: 17 36
# 20 20 25
# pos_tag, len of sent: 25 36
# 1 1 4
# pos_tag, len of sent: 4 4
# 18 18 23
# pos_tag, len of sent: 23 24
# 22 22 25
# pos_tag, len of sent: 25 31
# 23 23 21
# pos_tag, len of sent: 21 28
# 1 1 6
# pos_tag, len of sent: 6 6
# 12 12 18
# pos_tag, len of sent: 18 18
# 26 26 33
# pos_tag, len of sent: 33 38
# 20 20 19
# pos_tag, len of sent: 19 36
# 1 1 6
# pos_tag, len of sent: 6 6
# 9 9 16
# pos_tag, len of sent: 16 16
# 11 11 17
# pos_tag, len of sent: 17 17
# 5 5 7
# pos_tag, len of sent: 7 7
# 1 1 6
# pos_tag, len of sent: 6 6
# 9 9 15
# pos_tag, len of sent: 15 15
# 21 21 24
# pos_tag, len of sent: 24 36
# 8 8 11
# pos_tag, len of sent: 11 11
# 19 19 25
# pos_tag, len of sent: 25 26
# 9 9 12
# pos_tag, len of sent: 12 12
# 12 12 23
# pos_tag, len of sent: 23 23
# 30 30 34
# pos_tag, len of sent: 34 37
# 14 14 15
# pos_tag, len of sent: 15 15
# 8 8 13
# pos_tag, len of sent: 13 13
# 2416 2416
